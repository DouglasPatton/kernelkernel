# %%
#from sk_tool import SkTool,SkTool_post_fit
#assert False, 'moved to PiResult!'

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
from sklearn.pipeline import make_pipeline,Pipeline
from sklearn.linear_model import ElasticNet, LinearRegression,LassoLarsCV,LogisticRegressionCV
from sklearn.svm import LinearSVC, SVC
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.model_selection import cross_validate, train_test_split, RepeatedStratifiedKFold, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, f1_score, average_precision_score
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import GradientBoostingClassifier,HistGradientBoostingClassifier
from sklearn.datasets import make_regression
from sklearn.compose import TransformedTargetRegressor
from sk_transformers import none_T,shrinkBigKTransformer,logminus_T,exp_T,logminplus1_T,logp1_T,dropConst,binaryYTransformer
from sk_missing_value_handler import missingValHandler
#from sk_tool import SKToolInitializer
import logging
import numpy as np

# %%
from sk_estimators import sk_estimator

# %%
""" X, y= make_regression(n_samples=300,n_features=5,n_informative=3,noise=3)
y=(y-np.mean(y))
y01=binaryYTransformer().fit(y).transform(y)
X_train, X_test, y_train, y_test = train_test_split(X, y01, test_size=0.2, random_state=0)

sk_est=sk_estimator()
est_dict=sk_est.get_est_dict()
for est_name,est_setup_dict in est_dict.items():
    est=est_setup_dict['estimator']()
    est.fit(X_train,y_train)
    s=est.score(X_train,y_train)
    s_out=est.score(X_test,y_test)
    print(f'for {est_name}')
    print(f'    fit r2 score: {s}')
    print(f'    test r2 score: {s_out}')"""
# Out:
# " X, y= make_regression(n_samples=300,n_features=5,n_informative=3,noise=3)\ny=(y-np.mean(y))\ny01=binaryYTransformer().fit(y).transform(y)\nX_train, X_test, y_train, y_test = train_test_split(X, y01, test_size=0.2, random_state=0)\n\nsk_est=sk_estimator()\nest_dict=sk_est.get_est_dict()\nfor est_name,est_setup_dict in est_dict.items():\n    est=est_setup_dict['estimator']()\n    est.fit(X_train,y_train)\n    s=est.score(X_train,y_train)\n    s_out=est.score(X_test,y_test)\n    print(f'for {est_name}')\n    print(f'    fit r2 score: {s}')\n    print(f'    test r2 score: {s_out}')"

# %%
#from sk_tool import SKToolInitializer as skti

# %%
from pisces_params import PiSetup

# %%
from qcluster import RunNode

# %%
import pickle

# %%
rn=RunNode(qdict=1,local_run=1)

# %%
p=PiSetup(test=True)

# %%
runlist,hash_id_list=p.setupRunners()

# %%
len(runlist)
# Out:
# 5

# %%
runner1=runlist[1]

# %%
runner1.build()

# %%
predictresult=runner1.run()

# %%
predictresult['coef_scor_df']
# Out:
# var                           AgKffactCat                                 \
# rep_idx                                 0
# split_idx                               0      1                       2
# species          estimator
# semotilus lumbee logistic-reg       [0.0]    NaN                     NaN
#                  logistic-reg         NaN  [0.0]                     NaN
#                  logistic-reg         NaN    NaN  [0.010016603774425129]
#                  logistic-reg         NaN    NaN                     NaN
#                  logistic-reg         NaN    NaN                     NaN
#
# var                                                         AgKffactWs  \
# rep_idx                                                              0
# split_idx                          3                      4          0
# species          estimator
# semotilus lumbee logistic-reg    NaN                    NaN      [0.0]
#                  logistic-reg    NaN                    NaN        NaN
#                  logistic-reg    NaN                    NaN        NaN
#                  logistic-reg  [0.0]                    NaN        NaN
#                  logistic-reg    NaN  [0.04235621911049277]        NaN
#
# var                                                                           \
# rep_idx
# split_idx                                           1                      2
# species          estimator
# semotilus lumbee logistic-reg                     NaN                    NaN
#                  logistic-reg  [0.019292918281682534]                    NaN
#                  logistic-reg                     NaN  [0.04434456846113317]
#                  logistic-reg                     NaN                    NaN
#                  logistic-reg                     NaN                    NaN
#
# var                                                          ...  \
# rep_idx                                                      ...
# split_idx                          3                      4  ...
# species          estimator                                   ...
# semotilus lumbee logistic-reg    NaN                    NaN  ...
#                  logistic-reg    NaN                    NaN  ...
#                  logistic-reg    NaN                    NaN  ...
#                  logistic-reg  [0.0]                    NaN  ...
#                  logistic-reg    NaN  [0.04002355299720028]  ...
#
# var                           roc_auc_score_macro                          \
# rep_idx                                         0
# split_idx                                       0        1         2    3
# species          estimator
# semotilus lumbee logistic-reg            0.760526      NaN       NaN  NaN
#                  logistic-reg                 NaN  0.72561       NaN  NaN
#                  logistic-reg                 NaN      NaN  0.926829  NaN
#                  logistic-reg                 NaN      NaN       NaN  0.5
#                  logistic-reg                 NaN      NaN       NaN  NaN
#
# var                                     roc_auc_score_micro           \
# rep_idx                                                   0
# split_idx                             4                   0        1
# species          estimator
# semotilus lumbee logistic-reg       NaN            0.760526      NaN
#                  logistic-reg       NaN                 NaN  0.72561
#                  logistic-reg       NaN                 NaN      NaN
#                  logistic-reg       NaN                 NaN      NaN
#                  logistic-reg  0.845946                 NaN      NaN
#
# var
# rep_idx
# split_idx                             2    3         4
# species          estimator
# semotilus lumbee logistic-reg       NaN  NaN       NaN
#                  logistic-reg       NaN  NaN       NaN
#                  logistic-reg  0.926829  NaN       NaN
#                  logistic-reg       NaN  0.5       NaN
#                  logistic-reg       NaN  NaN  0.845946
#
# [5 rows x 1375 columns]

# %%
predictresult['yhat']
# Out:
# var                                                yhat
# rep_idx                                               0
# species          estimator    HUC12        COMID
# semotilus lumbee logistic-reg 030300030105 8868854  0.0
#                               030401040505 9210992  0.0
#                               030402030103 9125908  0.0
#                               030300030407 8874678  0.0
#                               030300040307 8850499  0.0
# ...                                                 ...
#                               030300030504 8870426  0.0
#                               030402020104 9146658  1.0
#                               030402040301 9109780  0.0
#                               030501030107 9731334  0.0
#                               030501030204 9733376  0.0
#
# [214 rows x 1 columns]
