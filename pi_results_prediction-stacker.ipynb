# %%
from pi_results import PiResults

# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '1.1.1'

# %%
import os

# %%
pr=PiResults()

# %%
stacked_predict_dict=pr.stack_predictions(rebuild=0)

# %%
keys=['y','yhat','coef_scor_df']
name=os.path.join(os.getcwd(),'results','prediction_stack.h5')

# %%
stacked_

# %%
read_test={key:pd.read_hdf(name,key) for key in keys}

# %%
coef_scor_df=stacked_predict_dict['coef_scor_df']

# %%
coef_scor_df
# Out:
# var                                                    AgKffactCat            \
# rep_idx                                                          0
# split_idx                                                        0         1
# species              estimator
# acantharchus pomotis gradient-boosting-classifier              NaN       NaN
#                      hist-gradient-boosting-classifier         NaN       NaN
#                      linear-svc                           0.415673 -0.524612
#                      logistic-reg                         0.208530 -0.073219
#                      rbf-svc                                   NaN       NaN
# ...                                                            ...       ...
# zzzno fish           gradient-boosting-classifier              NaN       NaN
#                      hist-gradient-boosting-classifier         NaN       NaN
#                      linear-svc                          -0.045892 -0.260745
#                      logistic-reg                        -0.097193  0.014460
#                      rbf-svc                                   NaN       NaN
#
# var                                                                         \
# rep_idx
# split_idx                                                      2         3
# species              estimator
# acantharchus pomotis gradient-boosting-classifier            NaN       NaN
#                      hist-gradient-boosting-classifier       NaN       NaN
#                      linear-svc                         0.668534  0.098541
#                      logistic-reg                      -0.096178  0.023534
#                      rbf-svc                                 NaN       NaN
# ...                                                          ...       ...
# zzzno fish           gradient-boosting-classifier            NaN       NaN
#                      hist-gradient-boosting-classifier       NaN       NaN
#                      linear-svc                        -0.202871 -0.082949
#                      logistic-reg                      -0.064445 -0.134730
#                      rbf-svc                                 NaN       NaN
#
# var                                                                           \
# rep_idx                                                            1
# split_idx                                                      4   0   1   2
# species              estimator
# acantharchus pomotis gradient-boosting-classifier            NaN NaN NaN NaN
#                      hist-gradient-boosting-classifier       NaN NaN NaN NaN
#                      linear-svc                         0.274002 NaN NaN NaN
#                      logistic-reg                       0.229511 NaN NaN NaN
#                      rbf-svc                                 NaN NaN NaN NaN
# ...                                                          ...  ..  ..  ..
# zzzno fish           gradient-boosting-classifier            NaN NaN NaN NaN
#                      hist-gradient-boosting-classifier       NaN NaN NaN NaN
#                      linear-svc                        -0.666775 NaN NaN NaN
#                      logistic-reg                      -0.096066 NaN NaN NaN
#                      rbf-svc                                 NaN NaN NaN NaN
#
# var                                                             ...  \
# rep_idx                                                         ...
# split_idx                                                3   4  ...
# species              estimator                                  ...
# acantharchus pomotis gradient-boosting-classifier      NaN NaN  ...
#                      hist-gradient-boosting-classifier NaN NaN  ...
#                      linear-svc                        NaN NaN  ...
#                      logistic-reg                      NaN NaN  ...
#                      rbf-svc                           NaN NaN  ...
# ...                                                     ..  ..  ...
# zzzno fish           gradient-boosting-classifier      NaN NaN  ...
#                      hist-gradient-boosting-classifier NaN NaN  ...
#                      linear-svc                        NaN NaN  ...
#                      logistic-reg                      NaN NaN  ...
#                      rbf-svc                           NaN NaN  ...
#
# var                                                    scorer:roc_auc_score_micro  \
# rep_idx                                                                         1
# split_idx                                                                       0
# species              estimator
# acantharchus pomotis gradient-boosting-classifier                             NaN
#                      hist-gradient-boosting-classifier                        NaN
#                      linear-svc                                               NaN
#                      logistic-reg                                             NaN
#                      rbf-svc                                                  NaN
# ...                                                                           ...
# zzzno fish           gradient-boosting-classifier                             NaN
#                      hist-gradient-boosting-classifier                        NaN
#                      linear-svc                                               NaN
#                      logistic-reg                                             NaN
#                      rbf-svc                                                  NaN
#
# var                                                                         \
# rep_idx                                                                  2
# split_idx                                                1   2   3   4   0
# species              estimator
# acantharchus pomotis gradient-boosting-classifier      NaN NaN NaN NaN NaN
#                      hist-gradient-boosting-classifier NaN NaN NaN NaN NaN
#                      linear-svc                        NaN NaN NaN NaN NaN
#                      logistic-reg                      NaN NaN NaN NaN NaN
#                      rbf-svc                           NaN NaN NaN NaN NaN
# ...                                                     ..  ..  ..  ..  ..
# zzzno fish           gradient-boosting-classifier      NaN NaN NaN NaN NaN
#                      hist-gradient-boosting-classifier NaN NaN NaN NaN NaN
#                      linear-svc                        NaN NaN NaN NaN NaN
#                      logistic-reg                      NaN NaN NaN NaN NaN
#                      rbf-svc                           NaN NaN NaN NaN NaN
#
# var
# rep_idx
# split_idx                                                1   2   3   4
# species              estimator
# acantharchus pomotis gradient-boosting-classifier      NaN NaN NaN NaN
#                      hist-gradient-boosting-classifier NaN NaN NaN NaN
#                      linear-svc                        NaN NaN NaN NaN
#                      logistic-reg                      NaN NaN NaN NaN
#                      rbf-svc                           NaN NaN NaN NaN
# ...                                                     ..  ..  ..  ..
# zzzno fish           gradient-boosting-classifier      NaN NaN NaN NaN
#                      hist-gradient-boosting-classifier NaN NaN NaN NaN
#                      linear-svc                        NaN NaN NaN NaN
#                      logistic-reg                      NaN NaN NaN NaN
#                      rbf-svc                           NaN NaN NaN NaN
#
# [2221 rows x 4125 columns]

# %%
scor_indices=[]
coef_indices=[]
coef_scor_cols=coef_scor_df.columns
for i,tup in enumerate(coef_scor_cols):
    if tup[0][:7]=='scorer:':
        scor_indices.append(i)
    else:
        coef_indices.append(i)
scor_df=coef_scor_df.iloc[:,scor_indices]  
coef_df=coef_scor_df.iloc[:,coef_indices]

# %%
coef_df=coef_df.dropna(axis=0,how='all')

# %%
print(scor_df.shape)
coef_df,scor_df=coef_df.align(scor_df,axis=0,join='inner')
scor_df.shape
# Out:
# (2221, 75)
# (894, 75)

# %%
'''keys=['y','yhat','coef_scor_df']
for key in keys:
    stacked_predict_dict[key].to_hdf(name,key,complevel=5)'''
# Out:
# "keys=['y','yhat','coef_scor_df']\nfor key in keys:\n    stacked_predict_dict[key].to_hdf(name,key,mode='w',complevel=5)"

# %%
y=stacked_predict_dict['y']

# %%
huc12_list=y.index.levels[1].to_list()
len(huc12_list)
# Out:
# 11850

# %%
#db=pr.getsave_postfit_db_dict(name,stacked_predict_dict)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-dc19e6d78a70> in <module>
# ----> 1 db['y']
#
# NameError: name 'db' is not defined

# %%
#pr.getsave_postfit_db_dict(name,{'data':stacked_predict_dict})

# %%
datadict=stacked_predict_dict

# %%
datadict['coef_scor_df'].loc[:,(slice(None),0,slice(None))]
# Out:
# var                                                    AgKffactCat            \
# rep_idx                                                          0
# split_idx                                                        0         1
# species              estimator
# acantharchus pomotis gradient-boosting-classifier              NaN       NaN
#                      hist-gradient-boosting-classifier         NaN       NaN
#                      linear-svc                           0.415673 -0.524612
#                      logistic-reg                         0.208530 -0.073219
#                      rbf-svc                                   NaN       NaN
# ...                                                            ...       ...
# zzzno fish           gradient-boosting-classifier              NaN       NaN
#                      hist-gradient-boosting-classifier         NaN       NaN
#                      linear-svc                          -0.045892 -0.260745
#                      logistic-reg                        -0.097193  0.014460
#                      rbf-svc                                   NaN       NaN
#
# var                                                                         \
# rep_idx
# split_idx                                                      2         3
# species              estimator
# acantharchus pomotis gradient-boosting-classifier            NaN       NaN
#                      hist-gradient-boosting-classifier       NaN       NaN
#                      linear-svc                         0.668534  0.098541
#                      logistic-reg                      -0.096178  0.023534
#                      rbf-svc                                 NaN       NaN
# ...                                                          ...       ...
# zzzno fish           gradient-boosting-classifier            NaN       NaN
#                      hist-gradient-boosting-classifier       NaN       NaN
#                      linear-svc                        -0.202871 -0.082949
#                      logistic-reg                      -0.064445 -0.134730
#                      rbf-svc                                 NaN       NaN
#
# var                                                              AgKffactWs  \
# rep_idx                                                                   0
# split_idx                                                      4          0
# species              estimator
# acantharchus pomotis gradient-boosting-classifier            NaN        NaN
#                      hist-gradient-boosting-classifier       NaN        NaN
#                      linear-svc                         0.274002   0.503738
#                      logistic-reg                       0.229511  -0.302653
#                      rbf-svc                                 NaN        NaN
# ...                                                          ...        ...
# zzzno fish           gradient-boosting-classifier            NaN        NaN
#                      hist-gradient-boosting-classifier       NaN        NaN
#                      linear-svc                        -0.666775  -0.097725
#                      logistic-reg                      -0.096066  -0.262497
#                      rbf-svc                                 NaN        NaN
#
# var                                                                         \
# rep_idx
# split_idx                                                      1         2
# species              estimator
# acantharchus pomotis gradient-boosting-classifier            NaN       NaN
#                      hist-gradient-boosting-classifier       NaN       NaN
#                      linear-svc                         1.283640 -0.524603
#                      logistic-reg                      -0.187056 -0.044057
#                      rbf-svc                                 NaN       NaN
# ...                                                          ...       ...
# zzzno fish           gradient-boosting-classifier            NaN       NaN
#                      hist-gradient-boosting-classifier       NaN       NaN
#                      linear-svc                        -1.245123  0.001233
#                      logistic-reg                       0.048506 -0.098889
#                      rbf-svc                                 NaN       NaN
#
# var                                                                         \
# rep_idx
# split_idx                                                      3         4
# species              estimator
# acantharchus pomotis gradient-boosting-classifier            NaN       NaN
#                      hist-gradient-boosting-classifier       NaN       NaN
#                      linear-svc                        -0.004106  0.188610
#                      logistic-reg                       0.123023 -0.273820
#                      rbf-svc                                 NaN       NaN
# ...                                                          ...       ...
# zzzno fish           gradient-boosting-classifier            NaN       NaN
#                      hist-gradient-boosting-classifier       NaN       NaN
#                      linear-svc                        -0.147607 -1.245396
#                      logistic-reg                      -0.114687 -0.080524
#                      rbf-svc                                 NaN       NaN
#
# var                                                     ...  \
# rep_idx                                                 ...
# split_idx                                               ...
# species              estimator                          ...
# acantharchus pomotis gradient-boosting-classifier       ...
#                      hist-gradient-boosting-classifier  ...
#                      linear-svc                         ...
#                      logistic-reg                       ...
#                      rbf-svc                            ...
# ...                                                     ...
# zzzno fish           gradient-boosting-classifier       ...
#                      hist-gradient-boosting-classifier  ...
#                      linear-svc                         ...
#                      logistic-reg                       ...
#                      rbf-svc                            ...
#
# var                                                    scorer:roc_auc_score_macro  \
# rep_idx                                                                         0
# split_idx                                                                       0
# species              estimator
# acantharchus pomotis gradient-boosting-classifier                        0.707708
#                      hist-gradient-boosting-classifier                   0.639953
#                      linear-svc                                          0.683117
#                      logistic-reg                                        0.758733
#                      rbf-svc                                             0.520584
# ...                                                                           ...
# zzzno fish           gradient-boosting-classifier                        0.516841
#                      hist-gradient-boosting-classifier                   0.642724
#                      linear-svc                                          0.717049
#                      logistic-reg                                        0.707020
#                      rbf-svc                                             0.500000
#
# var                                                                         \
# rep_idx
# split_idx                                                      1         2
# species              estimator
# acantharchus pomotis gradient-boosting-classifier       0.624329  0.653596
#                      hist-gradient-boosting-classifier  0.732492  0.718396
#                      linear-svc                         0.650784  0.611361
#                      logistic-reg                       0.771944  0.720999
#                      rbf-svc                            0.571852  0.582548
# ...                                                          ...       ...
# zzzno fish           gradient-boosting-classifier       0.543911  0.620627
#                      hist-gradient-boosting-classifier  0.527586  0.577536
#                      linear-svc                         0.585641  0.704810
#                      logistic-reg                       0.709184  0.816372
#                      rbf-svc                            0.500000  0.500000
#
# var                                                                         \
# rep_idx
# split_idx                                                      3         4
# species              estimator
# acantharchus pomotis gradient-boosting-classifier       0.654115  0.567419
#                      hist-gradient-boosting-classifier  0.660078  0.659540
#                      linear-svc                         0.601388  0.739800
#                      logistic-reg                       0.800277  0.727418
#                      rbf-svc                            0.550794  0.500000
# ...                                                          ...       ...
# zzzno fish           gradient-boosting-classifier       0.640952  0.706153
#                      hist-gradient-boosting-classifier  0.641262  0.589766
#                      linear-svc                         0.632942  0.747381
#                      logistic-reg                       0.772038  0.719383
#                      rbf-svc                            0.500000  0.498547
#
# var                                                    scorer:roc_auc_score_micro  \
# rep_idx                                                                         0
# split_idx                                                                       0
# species              estimator
# acantharchus pomotis gradient-boosting-classifier                        0.707708
#                      hist-gradient-boosting-classifier                   0.639953
#                      linear-svc                                          0.683117
#                      logistic-reg                                        0.758733
#                      rbf-svc                                             0.520584
# ...                                                                           ...
# zzzno fish           gradient-boosting-classifier                        0.516841
#                      hist-gradient-boosting-classifier                   0.642724
#                      linear-svc                                          0.717049
#                      logistic-reg                                        0.707020
#                      rbf-svc                                             0.500000
#
# var                                                                         \
# rep_idx
# split_idx                                                      1         2
# species              estimator
# acantharchus pomotis gradient-boosting-classifier       0.624329  0.653596
#                      hist-gradient-boosting-classifier  0.732492  0.718396
#                      linear-svc                         0.650784  0.611361
#                      logistic-reg                       0.771944  0.720999
#                      rbf-svc                            0.571852  0.582548
# ...                                                          ...       ...
# zzzno fish           gradient-boosting-classifier       0.543911  0.620627
#                      hist-gradient-boosting-classifier  0.527586  0.577536
#                      linear-svc                         0.585641  0.704810
#                      logistic-reg                       0.709184  0.816372
#                      rbf-svc                            0.500000  0.500000
#
# var
# rep_idx
# split_idx                                                      3         4
# species              estimator
# acantharchus pomotis gradient-boosting-classifier       0.654115  0.567419
#                      hist-gradient-boosting-classifier  0.660078  0.659540
#                      linear-svc                         0.601388  0.739800
#                      logistic-reg                       0.800277  0.727418
#                      rbf-svc                            0.550794  0.500000
# ...                                                          ...       ...
# zzzno fish           gradient-boosting-classifier       0.640952  0.706153
#                      hist-gradient-boosting-classifier  0.641262  0.589766
#                      linear-svc                         0.632942  0.747381
#                      logistic-reg                       0.772038  0.719383
#                      rbf-svc                            0.500000  0.498547
#
# [2221 rows x 1375 columns]

# %%
y=datadict['y'];yhat=datadict['yhat'];coef_scor_df=datadict['coef_scor_df']

# %%
coef_scor_df.shape
# Out:
# (2221, 4125)

# %%
coef_scor_df.dropna(axis=0,how='all').loc[:,'scorer:roc_auc_score_micro']

# %%
yhat_a,y_a=yhat.align(y,axis=0)

# %%
y.shape
# Out:
# (9635467, 1)

# %%
yhat.shape,y.shape,yhat_a.shape,y_a.shape

# %%
diff=yhat_a.subtract(y_a.values,axis=0)
diff.shape
# Out:
# (47522625, 15)

# %%
diff.iloc[0]

# %%
y,y_a
# Out:
# (                                            y
#  species              HUC12        COMID
#  acantharchus pomotis 020301030101 6245398   0
#                                    6245398   0
#                                    6245398   0
#                                    6245398   0
#                                    6245398   0
#  ...                                        ..
#  zzzno fish           181002010205 22592131  1
#                                    22592131  1
#                                    22592131  1
#                                    22592131  1
#                                    22592131  1
#
#  [9635467 rows x 1 columns],
#                                                                           y
#  species              HUC12        COMID    estimator
#  acantharchus pomotis 020301030101 6245398  gradient-boosting-classifier  0
#                                             gradient-boosting-classifier  0
#                                             gradient-boosting-classifier  0
#                                             gradient-boosting-classifier  0
#                                             gradient-boosting-classifier  0
#  ...                                                                     ..
#  zzzno fish           181002010205 22592131 rbf-svc                       1
#                                             rbf-svc                       1
#                                             rbf-svc                       1
#                                             rbf-svc                       1
#                                             rbf-svc                       1
#
#  [47522625 rows x 1 columns])

# %%
yhat

# %%
yhat_a.align(y_a,axis=1)

# %%
coef_scors=stacked_predict_dict['coef_scor_df'].dropna(axis=0)

# %%
stacked_predict_dict['coef_scor_df'].T.sum(axis=0,level=['var','rep_idx']).T

# %%
coef_scors.mean(axis=1,level=['var','rep_idx'])

# %%
reps_and_vars=stacked_predict_dict['coef_scor_df'].T.sum(level=['var','rep_idx'],min_count=1).T

# %%
reps_and_vars

# %%
reps_and_vars

# %%
reps_and_vars.iloc[0,:]

# %%
stacked_predict_dict['coef_scor_df'].head(20)
