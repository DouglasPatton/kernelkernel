# %%
import os
import kernelcompare as kc
#from importlib import reload
networkdir='o:/public/dpatton/kernel'
mydir=os.getcwd()
mydir2=os.path.join(mydir,"cluster_test")

test=kc.KernelCompare(directory=mydir2)
# Out:
# handlername:mykern-None.log

# %%
test.print_model_save(filename=os.path.join(mydir2,"condensed_model_save"))
# Out:
# DEBUG <PID 16680:MainProcess> matplotlib.wrapper(): $HOME=C:\Users\DPatton
# DEBUG <PID 16680:MainProcess> matplotlib.wrapper(): CONFIGDIR=C:\Users\DPatton\.matplotlib
# DEBUG <PID 16680:MainProcess> matplotlib.wrapper(): matplotlib data path: C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\mpl-data
# DEBUG <PID 16680:MainProcess> matplotlib.rc_params_from_file(): loaded rc file C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# DEBUG <PID 16680:MainProcess> matplotlib.<module>(): matplotlib version 3.1.1
# DEBUG <PID 16680:MainProcess> matplotlib.<module>(): interactive is False
# DEBUG <PID 16680:MainProcess> matplotlib.<module>(): platform is win32
# DEBUG <PID 16680:MainProcess> matplotlib.<module>(): loaded modules: ['sys', 'builtins', '_frozen_importlib', '_imp', '_thread', '_warnings', '_weakref', 'zipimport', '_frozen_importlib_external', '_io', 'marshal', 'nt', 'winreg', 'encodings', 'codecs', '_codecs', 'encodings.aliases', 'encodings.utf_8', '_signal', '__main__', 'encodings.latin_1', 'io', 'abc', '_abc', '_bootlocale', '_locale', 'encodings.cp1252', 'site', 'os', 'stat', '_stat', 'ntpath', 'genericpath', 'os.path', '_collections_abc', '_sitebuiltins', 'types', 'importlib', 'importlib._bootstrap', 'importlib._bootstrap_external', 'warnings', 'importlib.util', 'importlib.abc', 'importlib.machinery', 'contextlib', 'collections', 'operator', '_operator', 'keyword', 'heapq', '_heapq', 'itertools', 'reprlib', '_collections', 'functools', '_functools', 'mpl_toolkits', 'sphinxcontrib', 'runpy', 'pkgutil', 'weakref', '_weakrefset', 'ipykernel', 'ipykernel._version', 'ipykernel.connect', '__future__', 'json', 'json.decoder', 're', 'enum', 'sre_compile', '_sre', 'sre_parse', 'sre_constants', 'copyreg', 'json.scanner', '_json', 'json.encoder', 'subprocess', 'time', 'signal', 'errno', 'threading', 'traceback', 'linecache', 'tokenize', 'token', 'msvcrt', '_winapi', 'IPython', 'IPython.core', 'IPython.core.getipython', 'IPython.core.release', 'IPython.core.application', 'atexit', 'copy', 'glob', 'fnmatch', 'posixpath', 'logging', 'collections.abc', 'string', '_string', 'shutil', 'zlib', 'bz2', '_compression', '_bz2', 'lzma', '_lzma', 'traitlets', 'traitlets.traitlets', 'inspect', 'dis', 'opcode', '_opcode', 'six', 'struct', '_struct', 'traitlets.utils', 'traitlets.utils.getargspec', 'traitlets.utils.importstring', 'ipython_genutils', 'ipython_genutils._version', 'ipython_genutils.py3compat', 'ipython_genutils.encoding', 'locale', 'platform', 'traitlets.utils.sentinel', 'traitlets.utils.bunch', 'traitlets._version', 'traitlets.config', 'traitlets.config.application', 'decorator', 'traitlets.config.configurable', 'traitlets.config.loader', 'argparse', 'gettext', 'ast', '_ast', 'ipython_genutils.path', 'random', 'math', 'hashlib', '_hashlib', '_blake2', '_sha3', 'bisect', '_bisect', '_random', 'ipython_genutils.text', 'textwrap', 'ipython_genutils.importstring', 'IPython.core.crashhandler', 'pprint', 'IPython.core.ultratb', 'pydoc', 'urllib', 'urllib.parse', 'IPython.core.debugger', 'bdb', 'IPython.utils', 'IPython.utils.PyColorize', 'IPython.utils.coloransi', 'IPython.utils.ipstruct', 'IPython.utils.colorable', 'pygments', 'pygments.util', 'IPython.utils.py3compat', 'IPython.utils.encoding', 'IPython.core.excolors', 'IPython.testing', 'IPython.testing.skipdoctest', 'pdb', 'cmd', 'code', 'codeop', 'IPython.core.display_trap', 'IPython.utils.path', 'IPython.utils.process', 'IPython.utils._process_win32', 'ctypes', '_ctypes', 'ctypes._endian', 'ctypes.wintypes', 'IPython.utils._process_common', 'shlex', 'IPython.utils.decorators', 'IPython.utils.data', 'IPython.utils.terminal', 'IPython.utils.sysinfo', 'IPython.utils._sysinfo', 'IPython.core.profiledir', 'IPython.paths', 'tempfile', 'IPython.utils.importstring', 'IPython.terminal', 'IPython.terminal.embed', 'IPython.core.compilerop', 'IPython.core.magic_arguments', 'IPython.core.error', 'IPython.utils.text', 'pathlib', 'IPython.core.magic', 'getopt', 'IPython.core.oinspect', 'IPython.core.page', 'IPython.core.display', 'binascii', 'mimetypes', 'IPython.lib', 'IPython.lib.security', 'getpass', 'IPython.lib.pretty', 'datetime', '_datetime', 'IPython.utils.openpy', 'IPython.utils.dir2', 'IPython.utils.wildcard', 'pygments.lexers', 'pygments.lexers._mapping', 'pygments.modeline', 'pygments.plugin', 'pygments.lexers.python', 'pygments.lexer', 'pygments.filter', 'pygments.filters', 'pygments.token', 'pygments.regexopt', 'pygments.unistring', 'pygments.formatters', 'pygments.formatters._mapping', 'pygments.formatters.html', 'pygments.formatter', 'pygments.styles', 'IPython.core.inputtransformer2', 'typing', 'typing.io', 'typing.re', 'IPytho ...
# DEBUG <PID 16680:MainProcess> matplotlib.wrapper(): CACHEDIR=C:\Users\DPatton\.matplotlib
# DEBUG <PID 16680:MainProcess> matplotlib.font_manager.<module>(): Using fontManager instance from C:\Users\DPatton\.matplotlib\fontlist-v310.json
# len(model_save_list:218

# %%
#ykerngrid_form
ykerngrid_form_overwrite_tup=('modeldict:ykerngrid_form',('even',3))
test.overwrite_savedict('condensed_model_save',ykerngrid_form_overwrite_tup,verbose=0,overwrite=1)

# %%
NWkern_norm_overwrite_tup=('modeldict:NWnorm','none')
lossfn_overwrite_tup=('modeldict:loss_function','mse')
test.overwrite_savedict('condensed_model_save',NWkern_norm_overwrite_tup,verbose=0,overwrite=1)
test.overwrite_savedict('condensed_model_save',lossfn_overwrite_tup,verbose=0,overwrite=1)

# %%
ykerngrid_form_overwrite_tup=('modeldict:ykerngrid_form',('even',3))
test.overwrite_savedict('condensed_model_save',ykerngrid_form_overwrite_tup,verbose=0,overwrite=1)

# %%
product_kern_norm_overwrite_tup=('modeldict:product_kern_norm','across')
datagen_dict_overwrite_tup=('datagen_dict:ftype','linear')

test.overwrite_savedict('condensed_model_save',datagen_dict_overwrite_tup,verbose=1,overwrite=0,overwrite_condition='linear,quadratic')
test.print_model_save(filename=os.path.join(mydir2,"condensed_model_save-overwrite_dict"))
# Out:
# linear
# linear
# quadratic
# quadratic
# quadratic
# linear
# quadratic
# quadratic
# quadratic
# linear
# linear
# linear
# linear
# linear
# linear
# quadratic
# linear
# quadratic
# linear
# linear
# quadratic
# quadratic
# quadratic
# linear
# linear
# quadratic
# linear
# linear
# quadratic
# linear
# quadratic
# quadratic
# quadratic
# linear
# linear
# quadratic
# quadratic
# linear
# linear
# quadratic
# quadratic
# linear
# quadratic
# quadratic
# quadratic
# quadratic
# linear
# linear
# linear
# quadratic
# quadratic
# quadratic
# linear
# linear
# quadratic
# quadratic
# quadratic
# quadratic
# quadratic
# quadratic
# quadratic
# linear
# linear
# linear
# linear
# quadratic
# linear
# linear
# quadratic
# quadratic
# quadratic
# linear
# quadratic
# linear
# linear
# quadratic
# quadratic
# quadratic
# quadratic
# linear
# quadratic
# linear
# quadratic
# quadratic
# quadratic
# linear
# linear
# quadratic
# quadratic
# quadratic
# linear
# linear
# quadratic
# quadratic
# quadratic
# quadratic
# linear
# quadratic
# quadratic
# linear
# linear
# quadratic
# linear
# linear
# linear
# linear
# linear
# linear
# linear
# linear
# linear
# linear
# quadratic
# quadratic
# quadratic
# quadratic
# quadratic
# linear
# linear
# quadratic
# linear
# quadratic
# linear
# quadratic
# linear
# linear
# quadratic
# quadratic
# val is dict in datagen_dict, recursive call
# :val(linear) replaces val(linear,quadratic)
#
# vstring::key(ftype):for key:ftype, val(linear) replaces val(linear,quadratic)
#  and done2
# vstring::key(datagen_dict):key(ftype):for key:ftype, val(linear) replaces val(linear,quadratic)
#  and done2
# quadratic
# val is dict in datagen_dict, recursive call
# :val(linear) replaces val(linear,quadratic)
#
# vstring::key(ftype):for key:ftype, val(linear) replaces val(linear,quadratic)
#  and done2
# vstring::key(datagen_dict):key(ftype):for key:ftype, val(linear) replaces val(linear,quadratic)
#  and done2
# val is dict in datagen_dict, recursive call
# :val(linear) replaces val(linear,quadratic)
#
# vstring::key(ftype):for key:ftype, val(linear) replaces val(linear,quadratic)
#  and done2
# vstring::key(datagen_dict):key(ftype):for key:ftype, val(linear) replaces val(linear,quadratic)
#  and done2
# linear
# linear
# linear
# linear
# linear
# linear
# linear
# linear
# quadratic
# quadratic
# quadratic
# quadratic
# linear
# linear
# linear
# linear
# linear
# linear
# linear
# linear
# linear
# quadratic
# quadratic
# quadratic
# quadratic
# linear
# linear
# quadratic
# quadratic
# quadratic
# linear
# linear
# quadratic
# quadratic
# quadratic
# quadratic
# quadratic
# quadratic
# quadratic
# len(model_save_list:171

# %%
# Out:
# DEBUG <PID 10688:MainProcess> matplotlib.wrapper(): $HOME=C:\Users\DPatton
# DEBUG <PID 10688:MainProcess> matplotlib.wrapper(): CONFIGDIR=C:\Users\DPatton\.matplotlib
# DEBUG <PID 10688:MainProcess> matplotlib.wrapper(): matplotlib data path: C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\mpl-data
# DEBUG <PID 10688:MainProcess> matplotlib.rc_params_from_file(): loaded rc file C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# DEBUG <PID 10688:MainProcess> matplotlib.<module>(): matplotlib version 3.1.1
# DEBUG <PID 10688:MainProcess> matplotlib.<module>(): interactive is False
# DEBUG <PID 10688:MainProcess> matplotlib.<module>(): platform is win32
# DEBUG <PID 10688:MainProcess> matplotlib.<module>(): loaded modules: ['sys', 'builtins', '_frozen_importlib', '_imp', '_thread', '_warnings', '_weakref', 'zipimport', '_frozen_importlib_external', '_io', 'marshal', 'nt', 'winreg', 'encodings', 'codecs', '_codecs', 'encodings.aliases', 'encodings.utf_8', '_signal', '__main__', 'encodings.latin_1', 'io', 'abc', '_abc', '_bootlocale', '_locale', 'encodings.cp1252', 'site', 'os', 'stat', '_stat', 'ntpath', 'genericpath', 'os.path', '_collections_abc', '_sitebuiltins', 'types', 'importlib', 'importlib._bootstrap', 'importlib._bootstrap_external', 'warnings', 'importlib.util', 'importlib.abc', 'importlib.machinery', 'contextlib', 'collections', 'operator', '_operator', 'keyword', 'heapq', '_heapq', 'itertools', 'reprlib', '_collections', 'functools', '_functools', 'mpl_toolkits', 'sphinxcontrib', 'runpy', 'pkgutil', 'weakref', '_weakrefset', 'ipykernel', 'ipykernel._version', 'ipykernel.connect', '__future__', 'json', 'json.decoder', 're', 'enum', 'sre_compile', '_sre', 'sre_parse', 'sre_constants', 'copyreg', 'json.scanner', '_json', 'json.encoder', 'subprocess', 'time', 'signal', 'errno', 'threading', 'traceback', 'linecache', 'tokenize', 'token', 'msvcrt', '_winapi', 'IPython', 'IPython.core', 'IPython.core.getipython', 'IPython.core.release', 'IPython.core.application', 'atexit', 'copy', 'glob', 'fnmatch', 'posixpath', 'logging', 'collections.abc', 'string', '_string', 'shutil', 'zlib', 'bz2', '_compression', '_bz2', 'lzma', '_lzma', 'traitlets', 'traitlets.traitlets', 'inspect', 'dis', 'opcode', '_opcode', 'six', 'struct', '_struct', 'traitlets.utils', 'traitlets.utils.getargspec', 'traitlets.utils.importstring', 'ipython_genutils', 'ipython_genutils._version', 'ipython_genutils.py3compat', 'ipython_genutils.encoding', 'locale', 'platform', 'traitlets.utils.sentinel', 'traitlets.utils.bunch', 'traitlets._version', 'traitlets.config', 'traitlets.config.application', 'decorator', 'traitlets.config.configurable', 'traitlets.config.loader', 'argparse', 'gettext', 'ast', '_ast', 'ipython_genutils.path', 'random', 'math', 'hashlib', '_hashlib', '_blake2', '_sha3', 'bisect', '_bisect', '_random', 'ipython_genutils.text', 'textwrap', 'ipython_genutils.importstring', 'IPython.core.crashhandler', 'pprint', 'IPython.core.ultratb', 'pydoc', 'urllib', 'urllib.parse', 'IPython.core.debugger', 'bdb', 'IPython.utils', 'IPython.utils.PyColorize', 'IPython.utils.coloransi', 'IPython.utils.ipstruct', 'IPython.utils.colorable', 'pygments', 'pygments.util', 'IPython.utils.py3compat', 'IPython.utils.encoding', 'IPython.core.excolors', 'IPython.testing', 'IPython.testing.skipdoctest', 'pdb', 'cmd', 'code', 'codeop', 'IPython.core.display_trap', 'IPython.utils.path', 'IPython.utils.process', 'IPython.utils._process_win32', 'ctypes', '_ctypes', 'ctypes._endian', 'ctypes.wintypes', 'IPython.utils._process_common', 'shlex', 'IPython.utils.decorators', 'IPython.utils.data', 'IPython.utils.terminal', 'IPython.utils.sysinfo', 'IPython.utils._sysinfo', 'IPython.core.profiledir', 'IPython.paths', 'tempfile', 'IPython.utils.importstring', 'IPython.terminal', 'IPython.terminal.embed', 'IPython.core.compilerop', 'IPython.core.magic_arguments', 'IPython.core.error', 'IPython.utils.text', 'pathlib', 'IPython.core.magic', 'getopt', 'IPython.core.oinspect', 'IPython.core.page', 'IPython.core.display', 'binascii', 'mimetypes', 'IPython.lib', 'IPython.lib.security', 'getpass', 'IPython.lib.pretty', 'datetime', '_datetime', 'IPython.utils.openpy', 'IPython.utils.dir2', 'IPython.utils.wildcard', 'pygments.lexers', 'pygments.lexers._mapping', 'pygments.modeline', 'pygments.plugin', 'pygments.lexers.python', 'pygments.lexer', 'pygments.filter', 'pygments.filters', 'pygments.token', 'pygments.regexopt', 'pygments.unistring', 'pygments.formatters', 'pygments.formatters._mapping', 'pygments.formatters.html', 'pygments.formatter', 'pygments.styles', 'IPython.core.inputtransformer2', 'typing', 'typing.io', 'typing.re', 'IPytho ...
# DEBUG <PID 10688:MainProcess> matplotlib.wrapper(): CACHEDIR=C:\Users\DPatton\.matplotlib
# DEBUG <PID 10688:MainProcess> matplotlib.font_manager.<module>(): Using fontManager instance from C:\Users\DPatton\.matplotlib\fontlist-v310.json
# len(model_save_list:171

# %%
test.recursive_merge(mydir2,overwrite=0,verbose=0)
# Out:
# writing new_model_list length:87 to newfile:<_io.BufferedWriter name='C:\\Users\\DPatton\\gits\\kernelkernel\\cluster_test\\mergedfiles\\condensed_model_save'>
# writing new_model_list length:87 to newfile:<_io.BufferedWriter name='C:\\Users\\DPatton\\gits\\kernelkernel\\cluster_test\\mergedfiles\\condensed_model_save'>
# 0 models found in save_directory:{merge_directory} when merging
# writing new_model_list length:87 to newfile:<_io.BufferedWriter name='C:\\Users\\DPatton\\gits\\kernelkernel\\cluster_test\\mergedfiles\\condensed_model_save'>
# 0 models found in save_directory:{merge_directory} when merging
# 0 models found in save_directory:{merge_directory} when merging
# 0 models found in save_directory:{merge_directory} when merging
# 0 models found in save_directory:{merge_directory} when merging
# warning!saved_model_listC:\Users\DPatton\gits\kernelkernel\cluster_test\node20571630-1\model_save could not pickle.load
# ERROR <PID 4624:MainProcess> mkLogger.merge_and_condense_saved_models(): error in kernelcompare
# Traceback (most recent call last):
#   File "C:\Users\DPatton\gits\kernelkernel\kernelcompare.py", line 372, in merge_and_condense_saved_models
#     saved_model_list=pickle.load(savedfile)
# _pickle.UnpicklingError: invalid load key, '\x00'.
# writing new_model_list length:87 to newfile:<_io.BufferedWriter name='C:\\Users\\DPatton\\gits\\kernelkernel\\cluster_test\\mergedfiles\\condensed_model_save'>
# warning!saved_model_listC:\Users\DPatton\gits\kernelkernel\cluster_test\node20571630-11\model_save could not pickle.load
# ERROR <PID 4624:MainProcess> mkLogger.merge_and_condense_saved_models(): error in kernelcompare
# Traceback (most recent call last):
#   File "C:\Users\DPatton\gits\kernelkernel\kernelcompare.py", line 372, in merge_and_condense_saved_models
#     saved_model_list=pickle.load(savedfile)
# _pickle.UnpicklingError: invalid load key, '\x00'.
# writing new_model_list length:87 to newfile:<_io.BufferedWriter name='C:\\Users\\DPatton\\gits\\kernelkernel\\cluster_test\\mergedfiles\\condensed_model_save'>
# warning!saved_model_listC:\Users\DPatton\gits\kernelkernel\cluster_test\node20571630-13\model_save could not pickle.load
# ERROR <PID 4624:MainProcess> mkLogger.merge_and_condense_saved_models(): error in kernelcompare
# Traceback (most recent call last):
#   File "C:\Users\DPatton\gits\kernelkernel\kernelcompare.py", line 372, in merge_and_condense_saved_models
#     saved_model_list=pickle.load(savedfile)
# _pickle.UnpicklingError: invalid load key, '\x00'.
# writing new_model_list length:87 to newfile:<_io.BufferedWriter name='C:\\Users\\DPatton\\gits\\kernelkernel\\cluster_test\\mergedfiles\\condensed_model_save'>
# warning!saved_model_listC:\Users\DPatton\gits\kernelkernel\cluster_test\node20571630-18\model_save could not pickle.load
# ERROR <PID 4624:MainProcess> mkLogger.merge_and_condense_saved_models(): error in kernelcompare
# Traceback (most recent call last):
#   File "C:\Users\DPatton\gits\kernelkernel\kernelcompare.py", line 372, in merge_and_condense_saved_models
#     saved_model_list=pickle.load(savedfile)
# _pickle.UnpicklingError: invalid load key, '\x00'.
# writing new_model_list length:87 to newfile:<_io.BufferedWriter name='C:\\Users\\DPatton\\gits\\kernelkernel\\cluster_test\\mergedfiles\\condensed_model_save'>
# writing new_model_list length:87 to newfile:<_io.BufferedWriter name='C:\\Users\\DPatton\\gits\\kernelkernel\\cluster_test\\mergedfiles\\condensed_model_save'>
# 0 models found in save_directory:{merge_directory} when merging
# 0 models found in save_directory:{merge_directory} when merging
# 0 models found in save_directory:{merge_directory} when merging
# 0 models found in save_directory:{merge_directory} when merging
# writing new_model_list length:87 to newfile:<_io.BufferedWriter name='C:\\Users\\DPatton\\gits\\kernelkernel\\cluster_test\\mergedfiles\\condensed_model_save'>
# writing new_model_list length:87 to newfile:<_io.BufferedWriter name='C:\\Users\\DPatton\\gits\\kernelkernel\\cluster_test\\mergedfiles\\condensed_model_save'>

# %%
#test.open_condense_resave('model_save',verbose=0)
test.merge_and_condense_saved_models(merge_directory=mydir2,save_directory=mydir,condense=1,verbose=1)
# Out:
# file_i:C:\Users\DPatton\gits\kernelkernel\cluster_test\condensed_model_save has 521 saved model(s)
%,52.60115606936416%,53.179190751445084%,53.75722543352601%,54.335260115606935%,54.91329479768786%,55.49132947976879%,56.06936416184971%,56.64739884393064%,57.225433526011564%,57.80346820809248%,58.38150289017341%,58.959537572254334%,59.53757225433526%,60.115606936416185%,60.69364161849711%,61.27167630057804%,61.84971098265896%,62.42774566473989%,63.005780346820806%,63.58381502890173%,64.16184971098266%,64.73988439306359%,65.3179190751445%,65.89595375722543%,66.47398843930635%,67.05202312138728%,67.6300578034682%,68.20809248554913%,68.78612716763006%,69.36416184971098%,69.94219653179191%,70.52023121387283%,71.09826589595376%,71.67630057803468%,72.25433526011561%,72.83236994219654%,73.41040462427746%,73.98843930635839%,74.56647398843931%,75.14450867052022%,75.72254335260115%,76.30057803468208%,76.878612716763%,77.45664739884393%,78.03468208092485%,78.61271676300578%,79.1907514450867%,79.76878612716763%,80.34682080924856%,80.92485549132948%,81.5028901734104%,82.08092485549133%,82.65895953757226%,83.23699421965318%,83.81502890173411%,84.39306358381504%,84.97109826589596%,85.54913294797687%,86.1271676300578%,86.70520231213872%,87.28323699421965%,87.86127167630057%,88.4393063583815%,89.01734104046243%,89.59537572254335%,90.17341040462428%,90.7514450867052%,91.32947976878613%,91.90751445086705%,92.48554913294798%,93.0635838150289%,93.64161849710983%,94.21965317919076%,94.79768786127168%,95.3757225433526%,95.95375722543352%,96.53179190751445%,97.10982658959537%,97.6878612716763%,98.26589595375722%,98.84393063583815%,99.42196531791907%,len(final_keep_list):87
# writing new_model_list length:87 to newfile:<_io.BufferedWriter name='C:\\Users\\DPatton\\gits\\kernelkernel\\condensed_model_save'>

# %%
test.print_model_save(filename=os.path.join(mydir2,"condensed_model_save"))
# Out:
# DEBUG <PID 8920:MainProcess> matplotlib.wrapper(): $HOME=C:\Users\DPatton
# DEBUG <PID 8920:MainProcess> matplotlib.wrapper(): CONFIGDIR=C:\Users\DPatton\.matplotlib
# DEBUG <PID 8920:MainProcess> matplotlib.wrapper(): matplotlib data path: C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\mpl-data
# DEBUG <PID 8920:MainProcess> matplotlib.rc_params_from_file(): loaded rc file C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc
# DEBUG <PID 8920:MainProcess> matplotlib.<module>(): matplotlib version 3.1.1
# DEBUG <PID 8920:MainProcess> matplotlib.<module>(): interactive is False
# DEBUG <PID 8920:MainProcess> matplotlib.<module>(): platform is win32
# DEBUG <PID 8920:MainProcess> matplotlib.<module>(): loaded modules: ['sys', 'builtins', '_frozen_importlib', '_imp', '_thread', '_warnings', '_weakref', 'zipimport', '_frozen_importlib_external', '_io', 'marshal', 'nt', 'winreg', 'encodings', 'codecs', '_codecs', 'encodings.aliases', 'encodings.utf_8', '_signal', '__main__', 'encodings.latin_1', 'io', 'abc', '_abc', '_bootlocale', '_locale', 'encodings.cp1252', 'site', 'os', 'stat', '_stat', 'ntpath', 'genericpath', 'os.path', '_collections_abc', '_sitebuiltins', 'types', 'importlib', 'importlib._bootstrap', 'importlib._bootstrap_external', 'warnings', 'importlib.util', 'importlib.abc', 'importlib.machinery', 'contextlib', 'collections', 'operator', '_operator', 'keyword', 'heapq', '_heapq', 'itertools', 'reprlib', '_collections', 'functools', '_functools', 'mpl_toolkits', 'sphinxcontrib', 'runpy', 'pkgutil', 'weakref', '_weakrefset', 'ipykernel', 'ipykernel._version', 'ipykernel.connect', '__future__', 'json', 'json.decoder', 're', 'enum', 'sre_compile', '_sre', 'sre_parse', 'sre_constants', 'copyreg', 'json.scanner', '_json', 'json.encoder', 'subprocess', 'time', 'signal', 'errno', 'threading', 'traceback', 'linecache', 'tokenize', 'token', 'msvcrt', '_winapi', 'IPython', 'IPython.core', 'IPython.core.getipython', 'IPython.core.release', 'IPython.core.application', 'atexit', 'copy', 'glob', 'fnmatch', 'posixpath', 'logging', 'collections.abc', 'string', '_string', 'shutil', 'zlib', 'bz2', '_compression', '_bz2', 'lzma', '_lzma', 'traitlets', 'traitlets.traitlets', 'inspect', 'dis', 'opcode', '_opcode', 'six', 'struct', '_struct', 'traitlets.utils', 'traitlets.utils.getargspec', 'traitlets.utils.importstring', 'ipython_genutils', 'ipython_genutils._version', 'ipython_genutils.py3compat', 'ipython_genutils.encoding', 'locale', 'platform', 'traitlets.utils.sentinel', 'traitlets.utils.bunch', 'traitlets._version', 'traitlets.config', 'traitlets.config.application', 'decorator', 'traitlets.config.configurable', 'traitlets.config.loader', 'argparse', 'gettext', 'ast', '_ast', 'ipython_genutils.path', 'random', 'math', 'hashlib', '_hashlib', '_blake2', '_sha3', 'bisect', '_bisect', '_random', 'ipython_genutils.text', 'textwrap', 'ipython_genutils.importstring', 'IPython.core.crashhandler', 'pprint', 'IPython.core.ultratb', 'pydoc', 'urllib', 'urllib.parse', 'IPython.core.debugger', 'bdb', 'IPython.utils', 'IPython.utils.PyColorize', 'IPython.utils.coloransi', 'IPython.utils.ipstruct', 'IPython.utils.colorable', 'pygments', 'pygments.util', 'IPython.utils.py3compat', 'IPython.utils.encoding', 'IPython.core.excolors', 'IPython.testing', 'IPython.testing.skipdoctest', 'pdb', 'cmd', 'code', 'codeop', 'IPython.core.display_trap', 'IPython.utils.path', 'IPython.utils.process', 'IPython.utils._process_win32', 'ctypes', '_ctypes', 'ctypes._endian', 'ctypes.wintypes', 'IPython.utils._process_common', 'shlex', 'IPython.utils.decorators', 'IPython.utils.data', 'IPython.utils.terminal', 'IPython.utils.sysinfo', 'IPython.utils._sysinfo', 'IPython.core.profiledir', 'IPython.paths', 'tempfile', 'IPython.utils.importstring', 'IPython.terminal', 'IPython.terminal.embed', 'IPython.core.compilerop', 'IPython.core.magic_arguments', 'IPython.core.error', 'IPython.utils.text', 'pathlib', 'IPython.core.magic', 'getopt', 'IPython.core.oinspect', 'IPython.core.page', 'IPython.core.display', 'binascii', 'mimetypes', 'IPython.lib', 'IPython.lib.security', 'getpass', 'IPython.lib.pretty', 'datetime', '_datetime', 'IPython.utils.openpy', 'IPython.utils.dir2', 'IPython.utils.wildcard', 'pygments.lexers', 'pygments.lexers._mapping', 'pygments.modeline', 'pygments.plugin', 'pygments.lexers.python', 'pygments.lexer', 'pygments.filter', 'pygments.filters', 'pygments.token', 'pygments.regexopt', 'pygments.unistring', 'pygments.formatters', 'pygments.formatters._mapping', 'pygments.formatters.html', 'pygments.formatter', 'pygments.styles', 'IPython.core.inputtransformer2', 'typing', 'typing.io', 'typing.re', 'IPython ...
# DEBUG <PID 8920:MainProcess> matplotlib.wrapper(): CACHEDIR=C:\Users\DPatton\.matplotlib
# DEBUG <PID 8920:MainProcess> matplotlib.font_manager.<module>(): Using fontManager instance from C:\Users\DPatton\.matplotlib\fontlist-v310.json
# len(model_save_list:171

# %%
test.open_condense_resave(os.path.join(mydir2,"condensed_model_save"),verbose=1)
# Out:
