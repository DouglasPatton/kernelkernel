# %%
from pi_results import PiResults

# %%
pr=PiResults()

# %%
pr.plot_basic_hists(log_bins=True,bin_count=30)

# %%
pr.plot_basic_scatter(log_scale=True)

# %%
pr.plot_basic_scatter(log_scale=False)
