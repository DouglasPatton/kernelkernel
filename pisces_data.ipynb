# %%
import pisces_data_huc12 as pdh12

# %%
'''import importlib
importlib.reload(pdh12)'''
# Out:
# 'import importlib\nimportlib.reload(pdh12)'

# %%
datatool=pdh12.PiscesDataTool()

# %%
datatool.getfishdata()
# Out:
# opening surveydata.csv with length:347981 and type:<class 'list'>
# [OrderedDict([('genus_species', 'cyprinus carpio'), ('lat_dd', '33.47634212'), ('lon_dd', '-114.6053022'), ('HUC', '15030104'), ('COMID', '10003816.A')]), OrderedDict([('genus_species', 'ictalurus punctatus'), ('lat_dd', '33.47634212'), ('lon_dd', '-114.6053022'), ('HUC', '15030104'), ('COMID', '10003816.A')]), OrderedDict([('genus_species', 'lepomis macrochirus'), ('lat_dd', '33.47634212'), ('lon_dd', '-114.6053022'), ('HUC', '15030104'), ('COMID', '10003816.A')]), OrderedDict([('genus_species', 'micropterus dolomieu'), ('lat_dd', '33.47634212'), ('lon_dd', '-114.6053022'), ('HUC', '15030104'), ('COMID', '10003816.A')]), OrderedDict([('genus_species', 'micropterus salmoides'), ('lat_dd', '33.47634212'), ('lon_dd', '-114.6053022'), ('HUC', '15030104'), ('COMID', '10003816.A')])]

# %%
datatool.getsitedata()
# Out:
# opening siteinfo.csv with length:39073 and type:<class 'list'>
# [OrderedDict([('COMID', '12664.A'), ('HUC8', '10190006'), ('WA', '31.0599'), ('Elev', '1558.498368'), ('BMMI', ''), ('IWI', '0.142121814'), ('Slope', '0.00376068')]), OrderedDict([('COMID', '13584.A'), ('HUC8', '10190006'), ('WA', '103.8159'), ('Elev', '3230.255404'), ('BMMI', ''), ('IWI', '0.247456983'), ('Slope', '0.04717076')]), OrderedDict([('COMID', '79368.A'), ('HUC8', '3090206'), ('WA', '300.6252'), ('Elev', '1.480710958'), ('BMMI', '0.226666667'), ('IWI', '0.700217294'), ('Slope', '0.00001')]), OrderedDict([('COMID', '89748.A'), ('HUC8', '3090202'), ('WA', '7984.0449'), ('Elev', '3.225136491'), ('BMMI', ''), ('IWI', '0.305446198'), ('Slope', '0.00001')]), OrderedDict([('COMID', '89748.B'), ('HUC8', '3090202'), ('WA', '7984.0449'), ('Elev', '3.225136491'), ('BMMI', ''), ('IWI', '0.305446198'), ('Slope', '0.00001')])]

# %%
datatool.getfishhucs()
# Out:
# opening fishhucs.csv with length:99612 and type:<class 'list'>
# [OrderedDict([('Scientific_name', 'acantharchus pomotis'), ('Common_name', 'mud sunfish'), ('ID', '1'), ('HUC', '2030103'), ('Provenance', 'NS')]), OrderedDict([('Scientific_name', 'acantharchus pomotis'), ('Common_name', 'mud sunfish'), ('ID', '1'), ('HUC', '2030104'), ('Provenance', 'NS')]), OrderedDict([('Scientific_name', 'acantharchus pomotis'), ('Common_name', 'mud sunfish'), ('ID', '1'), ('HUC', '2030105'), ('Provenance', 'NS')]), OrderedDict([('Scientific_name', 'acantharchus pomotis'), ('Common_name', 'mud sunfish'), ('ID', '1'), ('HUC', '2040105'), ('Provenance', 'NS')]), OrderedDict([('Scientific_name', 'acantharchus pomotis'), ('Common_name', 'mud sunfish'), ('ID', '1'), ('HUC', '2040201'), ('Provenance', 'NS')])]

# %%
datatool.gethucdata()
# Out:
#            COMID         HUC12       REACHCODE         TOHUC       Length
# 0        6712081  010400020910  01040002000162  010400021005   634.137222
# 1        6712083  010400020910  01040002000163  010400021005  1807.060164
# 2        6712085  010400020908  01040002000164  010400020910  2065.504156
# 3        6712077  010400020908  01040002000165  010400020910  3943.881141
# 4        6712065  010400020908  01040002000166  010400020910   490.857440
# ...          ...           ...             ...           ...          ...
# 2968701  7961217  180200040208  18020004001376  180200040403     0.000000
# 2968702  7961213  180200040208  18020004001378  180200040403     0.000000
# 2968703  7961211  180200040208  18020004001379  180200040403     0.000000
# 2968704  7961205  180200040208  18020004001382  180200040403     0.000000
# 2968705  7961225  180200040208  18020004001387  180200040403     0.000000
#
# [2968706 rows x 5 columns]
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
datatool.getNHDplus()
# Out:
#            COMID         HUC12       REACHCODE         TOHUC       Length
# 0        6712081  010400020910  01040002000162  010400021005   634.137222
# 1        6712083  010400020910  01040002000163  010400021005  1807.060164
# 2        6712085  010400020908  01040002000164  010400020910  2065.504156
# 3        6712077  010400020908  01040002000165  010400020910  3943.881141
# 4        6712065  010400020908  01040002000166  010400020910   490.857440
# ...          ...           ...             ...           ...          ...
# 2968701  7961217  180200040208  18020004001376  180200040403     0.000000
# 2968702  7961213  180200040208  18020004001378  180200040403     0.000000
# 2968703  7961211  180200040208  18020004001379  180200040403     0.000000
# 2968704  7961205  180200040208  18020004001382  180200040403     0.000000
# 2968705  7961225  180200040208  18020004001387  180200040403     0.000000
#
# [2968706 rows x 5 columns]

# %%
datatool.buildspecieslist()
# Out:
# opening /home/dp/gits/kernelkernel/data_tool2/specieslistfiles with length:9 and type:<class 'tuple'>

# %%
datatool.buildspecieshuc8list()
# Out:
# opening /home/dp/gits/kernelkernel/data_tool2/specieshuc8files with length:4 and type:<class 'tuple'>

# %%
datatool.buildCOMIDlist()
# Out:
# opening /home/dp/gits/kernelkernel/data_tool2/comidlist with length:2 and has first item length: 28741 and type:<class 'list'>

# %%
datatool.buildCOMIDsiteinfo()
# Out:
# INFO:/home/dp/gits/kernelkernel/log/PiscesDataTool.log:buildCOMIDsiteinfo opened /home/dp/gits/kernelkernel/data_tool2/sitedatacomid_dict, type: <class 'tuple'>, length:4
# INFO:/home/dp/gits/kernelkernel/log/PiscesDataTool.log:first item has type: <class 'dict'>, length:28741
# opening /home/dp/gits/kernelkernel/data_tool2/sitedatacomid_dict with length:4 and has first item length: 28741 and type:<class 'dict'>

# %%
datatool.buildspeciesdata01_file()
# Out:
# pool starting at 1591031213.8781269
# ERROR:pisces_data_huc1230720:problem came up for species number 0,lampetra aepyptera
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230719:problem came up for species number 0,cyprinus carpio
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230719:problem came up for species number 1,ictalurus punctatus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230721:problem came up for species number 0,lepisosteus oculatus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230721:problem came up for species number 1,lepomis punctatus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230721:problem came up for species number 2,lythrurus fumeus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230721:problem came up for species number 3,notropis atrocaudalis
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230721:problem came up for species number 4,percina carbonaria
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230721:problem came up for species number 5,percina sciera
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230721:problem came up for species number 6,pomoxis nigromaculatus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230721:problem came up for species number 7,catostomus ardens
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 0,moxostoma breviceps
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 1,notropis micropteryx
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 2,ictalurus furcatus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 3,notropis rubellus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 4,chrosomus erythrogaster
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 5,etheostoma atripinne
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 6,nocomis micropogon
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 7,etheostoma tippecanoe
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 8,ameiurus platycephalus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 9,etheostoma virgatum
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 10,notropis boops
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 11,etheostoma proeliare
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 12,notropis chalybaeus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 13,micropterus coosae
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 14,notropis telescopus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 15,etheostoma sanguifluum
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 16,etheostoma lawrencei
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 17,etheostoma obeyense
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 18,etheostoma coosae
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 19,chrosomus cumberlandensis
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 20,etheostoma kennicotti
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 21,etheostoma sagitta
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 22,etheostoma baileyi
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 23,etheostoma susanae
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 24,lethenteron appendix
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230723:problem came up for species number 0,lepisosteus platyrhincus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230723:problem came up for species number 1,lucania goodei
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230723:problem came up for species number 2,menidia beryllina
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230723:problem came up for species number 3,mugil cephalus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230723:problem came up for species number 4,notropis maculatus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230723:problem came up for species number 5,notropis petersoni
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230723:problem came up for species number 6,poecilia latipinna
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230723:problem came up for species number 7,strongylura marina
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230723:problem came up for species number 8,trinectes maculatus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230723:problem came up for species number 9,morone chrysops
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230723:problem came up for species number 10,ammocrypta pellucida
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230723:problem came up for species number 11,sander canadensis
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230723:problem came up for species number 12,oncorhynchus clarkii utah
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 25,sander vitreus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230723:problem came up for species number 13,ictiobus niger
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230723:problem came up for species number 14,catostomus catostomus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230723:problem came up for species number 15,fundulus diaphanus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230722:problem came up for species number 26,carpiodes cyprinus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230723:problem came up for species number 16,ichthyomyzon castaneus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230723:problem came up for species number 17,noturus eleutherus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# ...
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230719:problem came up for species number 38,noturus gyrinus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230719:problem came up for species number 39,semotilus corporalis
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230719:problem came up for species number 40,etheostoma olmstedi
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230719:problem came up for species number 41,nocomis leptocephalus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230719:problem came up for species number 42,notropis procne
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230719:problem came up for species number 43,pimephales notatus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230719:problem came up for species number 44,semotilus atromaculatus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230719:problem came up for species number 45,gambusia holbrooki
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230719:problem came up for species number 46,acantharchus pomotis
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230719:problem came up for species number 47,ameiurus nebulosus
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230719:problem came up for species number 48,clinostomus funduloides
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230719:problem came up for species number 49,noturus insignis
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# ERROR:pisces_data_huc1230719:problem came up for species number 50,cyprinella analostana
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 748, in mp_buildspeciesdata01_file
#     self.specieshuc_allcomid
# AttributeError: 'PiscesDataTool' object has no attribute 'specieshuc_allcomid'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 752, in mp_buildspeciesdata01_file
#     specieshuc_allcomid_list,species01list_list=self.buildspecieshuccomidlist(species_idx_list=[idx])
#   File "/home/dp/gits/kernelkernel/pisces_data_huc12.py", line 657, in buildspecieshuccomidlist
#     comid_visit_count=self.comid_visit_count_dict[comid]
# AttributeError: 'PiscesDataTool' object has no attribute 'comid_visit_count_dict'
# WARNING:pisces_data_huc1230719:succesful completion. len(speciesidx_list): 51, recordfailcount: 51
