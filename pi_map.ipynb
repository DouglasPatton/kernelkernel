# %%
from pi_map import Mapper

# %%
mpr=Mapper()

# %%
mpr.make_weights(rebuild=0)

# %%
mpr.diff_a.iloc[-200:,:].sum(axis=0)
# Out:
# scorer-0    0.0
# scorer-1    0.0
# scorer-2    0.0
# scorer-3    0.0
# scorer-4    0.0
# scorer-5    0.0
# scorer-6    0.0
# scorer-7    0.0
# scorer-8    0.0
# scorer-9    0.0
# yhat_0      7.0
# yhat_1      3.0
# dtype: float64

# %%
mpr.spec_est_scor_df_a.sum(axis=0)
# Out:
# scorer-0    429557.066100
# scorer-1    417731.236184
# scorer-2    428651.642223
# scorer-3    430877.814475
# scorer-4    427599.505527
# scorer-5    431519.737075
# scorer-6    429144.444511
# scorer-7    427522.097699
# scorer-8    428733.823027
# scorer-9    429584.282034
# yhat_0           0.000000
# yhat_1           0.000000
# dtype: float64

# %%
#mpr.draw_huc12_truefalse(rebuild=0)
