# %%
from pi_map import Mapper

# %%
mpr=Mapper()

# %%
mpr.draw_huc12_truefalse(rebuild=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-db7e44e23837> in <module>
# ----> 1 mpr.draw_huc12_truefalse(rebuild=0)
#
# ~/hdd2/gits/kernelkernel/pi_map.py in draw_huc12_truefalse(self, rebuild)
#      70         cax = divider.append_axes("right", size="5%", pad=0.1)
#      71
# ---> 72         err_geo_df.plot(column='err',ax=ax,cax=cax,legend=True,cmap='brg',alpha=rvrs_abs_diff_geo_df)#,legend_kwds={'orientation':'vertical'})
#      73         ax2=fig.add_subplot(2,1,2)
#      74         nofish_err_geo_df.plot(column='err',ax=ax2,cax=cax,legend=True,cmap='brg',alpha=rvrs_nofish_abs_diff_geo_df)
#
# ~/anaconda3/envs/kernel/lib/python3.8/site-packages/geopandas/geodataframe.py in plot(self, *args, **kwargs)
#     604         from there.
#     605         """
# --> 606         return plot_dataframe(self, *args, **kwargs)
#     607
# ...
