# %%
import mycluster

# %%
mycluster.run_cluster(mytype='T3600node',local_test='yes')
# Out:
# self.savedirectoryC:\Users\DPatton\gits\kernelkernel\cluster_test
# mydir:{mydir} doesn't exist, so creating it
# T3600node ischecking for jobs
# Traceback (most recent call last):
#   File "C:\Users\DPatton\gits\kernelkernel\mycluster.py", line 341, in check_for_opt_job
#     with open(my_job_file,'rb') as myjob_save:
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\DPatton\\gits\\kernelkernel\\cluster_test\\T3600node\\T3600node_job'
#
# Traceback (most recent call last):
#   File "C:\Users\DPatton\gits\kernelkernel\mycluster.py", line 341, in check_for_opt_job
#     with open(my_job_file,'rb') as myjob_save:
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\DPatton\\gits\\kernelkernel\\cluster_test\\T3600node\\T3600node_job'
#
# Traceback (most recent call last):
#   File "C:\Users\DPatton\gits\kernelkernel\mycluster.py", line 341, in check_for_opt_job
#     with open(my_job_file,'rb') as myjob_save:
# ...
