# %%
#from sk_tool import SKToolInitializer as skti

# %%
from pisces_params import PiSetup

# %%
from qcluster import RunNode

# %%
import pickle

# %%
rn=RunNode(qdict=1,local_run=1)

# %%
p=PiSetup(test=True)

# %%
runlist,hash_id_list=p.setupRunners()

# %%
len(runlist)
# Out:
# 21

# %%
#runlist[0].rundict

# %%
#runner1=runlist[4]

# %%
predictresult_list=[]
for runner in runlist[:1]:
    runner.build()
    predictresult_list.append(runner.run())

# %%
predictresult=predictresult_list[0]

# %%
type(predictresult['coef_scor_df'])
# Out:
# pandas.core.frame.DataFrame

# %%
predictresult['coef_scor_df']#.sum(axis=1,level='rep_idx')
# Out:
# var                            scorer:f1_micro scorer:roc_auc_score_macro  \
# rep_idx                                      0                          0
# split_idx                                    0                          0
# species           estimator
# etheostoma mariae logistic-reg             0.9                     0.9375
#
# var                            scorer:roc_auc_score_micro  \
# rep_idx                                                 0
# split_idx                                               0
# species           estimator
# etheostoma mariae logistic-reg                     0.9375
#
# var                            scorer:precision_micro scorer:recall_micro  \
# rep_idx                                             0                   0
# split_idx                                           0                   0
# species           estimator
# etheostoma mariae logistic-reg                    0.9                 0.9
#
# var                            AgKffactCat AgKffactWs  Al2O3Cat Al2O3Ws  \
# rep_idx                                  0          0         0       0
# split_idx                                0          0         0       0
# species           estimator
# etheostoma mariae logistic-reg         0.0        0.0 -0.005351     0.0
#
# var                            BFICat  ... WCONN_v2_1 WHABT_v2_1 WHYD_v2_1  \
# rep_idx                             0  ...          1          1         1
# split_idx                           0  ...          4          4         4
# species           estimator            ...
# etheostoma mariae logistic-reg    0.0  ...        0.0        0.0       0.0
#
# var                            WSED_v2_1 WTEMP_v2_1 WetIndexCat WetIndexWs  \
# rep_idx                                1          1           1          1
# split_idx                              4          4           4          4
# species           estimator
# etheostoma mariae logistic-reg  0.048291        0.0         0.0        0.0
#
# var                            WtDepCat WtDepWs  prG_BMMI
# rep_idx                               1       1         1
# split_idx                             4       4         4
# species           estimator
# etheostoma mariae logistic-reg      0.0     0.0  0.038426
#
# [1 rows x 2750 columns]

# %%
predictresult['yhat'].sum(axis=1,level='rep_idx')
# Out:
# rep_idx                                                0    1
# species           estimator    HUC12        COMID
# etheostoma mariae logistic-reg 030402040303 9109774  0.0  1.0
#                                030402010303 9167552  0.0  0.0
#                                030402010301 9165154  0.0  0.0
#                                030402010401 9169724  0.0  0.0
#                                030402011202 9179526  0.0  0.0
#                                030402040302 9110340  1.0  1.0
#                                030402040101 9109734  1.0  1.0
#                                030402010710 9173814  0.0  0.0
#                                030402010102 9164108  1.0  0.0
#                                030402010902 9174894  0.0  0.0
#                                030402030901 9128028  0.0  0.0
#                                030402010305 9165758  0.0  0.0
#                                030402030206 9129024  1.0  1.0
