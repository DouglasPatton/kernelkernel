# %%
from pi_results import PiResults

# %%
pr=PiResults()

# %%
pr.build_scor_est_spec_dict(rebuild=0)

# %%
#pr.scor_est_spec_dict

# %%
pr.plot_species_estimator_scores()
