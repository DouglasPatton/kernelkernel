# %%
import mycluster
import kernelcompare as kc

# %%
data_gen_variation_list=[kc.KernelCompare().build_quadratic_datagen_dict_override()]
Ndiff_type_variations=('modeldict:Ndiff_type',['recursive','product'])
max_bw_Ndiff_variations=('modeldict:max_bw_Ndiff',[2])
Ndiff_start_variations=('modeldict:Ndiff_start',[0])
product_kern_norm_variations=('modeldict:product_kern_norm',['self','own_n'])#include None too?
normalize_Ndiffwtsum_variations=('modeldict:normalize_Ndiffwtsum',['own_n','across'])
optdict_variation_list=[Ndiff_type_variations,max_bw_Ndiff_variations,Ndiff_start_variations]
# Out:
# here []
# no models found when merging

# %%
#opt_model_variation_list=
mycluster.run_cluster(mytype='master',optdict_variation_list=optdict_variation_list)
# Out:
# here []
# no models found when merging
# ------no start value overrides encountered------
# newoptimizedict1{'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.01, 'fatol': 0.1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.3, 0.3]), 'x_bandscale': array([1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.5])}, 'modeldict': {'Ndiff_type': 'product', 'param_count': 2, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}}
# ------no start value overrides encountered------
# newoptimizedict1{'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.01, 'fatol': 0.1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.3, 0.3]), 'x_bandscale': array([1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.5])}, 'modeldict': {'Ndiff_type': 'product', 'param_count': 2, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}}
# Traceback (most recent call last):
#   File "C:\Users\DPatton\gits\kernelkernel\mycluster.py", line 271, in check_node_job_status
#     with open(nodes_job_filename,'rb') as saved_job_file:
# FileNotFoundError: [Errno 2] No such file or directory: 'O:/Public/DPatton/kernel/node11/node11_job'
#
# job_time:20191115-161701,job_status:no file found
# about to setup the job for node:('node11', [('20191115-161656', 'created')])
# job setup for node:node11
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161701', 'ready for node'), ('20191115-161701', 'accepted')]
# nodesjob_dict['node_status'][-1]:('20191115-161701', 'accepted')
# job_time:20191115-161701,job_status:accepted
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161701', 'ready for node'), ('20191115-161701', 'accepted'), ('20191115-161706', 'starting')]
# nodesjob_dict['node_status'][-1]:('20191115-161706', 'starting')
# job_time:20191115-161706,job_status:starting
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161701', 'ready for node'), ('20191115-161701', 'accepted'), ('20191115-161706', 'starting')]
# nodesjob_dict['node_status'][-1]:('20191115-161706', 'starting')
# job_time:20191115-161706,job_status:starting
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161701', 'ready for node'), ('20191115-161701', 'accepted'), ('20191115-161706', 'starting')]
# nodesjob_dict['node_status'][-1]:('20191115-161706', 'starting')
# job_time:20191115-161706,job_status:starting
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161701', 'ready for node'), ('20191115-161701', 'accepted'), ('20191115-161706', 'starting')]
# nodesjob_dict['node_status'][-1]:('20191115-161706', 'starting')
# job_time:20191115-161706,job_status:starting
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161701', 'ready for node'), ('20191115-161701', 'accepted'), ('20191115-161706', 'starting')]
# nodesjob_dict['node_status'][-1]:('20191115-161706', 'starting')
# job_time:20191115-161706,job_status:starting
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161701', 'ready for node'), ('20191115-161701', 'accepted'), ('20191115-161706', 'starting')]
# nodesjob_dict['node_status'][-1]:('20191115-161706', 'starting')
# job_time:20191115-161706,job_status:starting
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161701', 'ready for node'), ('20191115-161701', 'accepted'), ('20191115-161706', 'starting')]
# nodesjob_dict['node_status'][-1]:('20191115-161706', 'starting')
# job_time:20191115-161706,job_status:starting
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161701', 'ready for node'), ('20191115-161701', 'accepted'), ('20191115-161706', 'starting')]
# nodesjob_dict['node_status'][-1]:('20191115-161706', 'starting')
# job_time:20191115-161706,job_status:starting
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161701', 'ready for node'), ('20191115-161701', 'accepted'), ('20191115-161706', 'starting')]
# nodesjob_dict['node_status'][-1]:('20191115-161706', 'starting')
# job_time:20191115-161706,job_status:starting
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161701', 'ready for node'), ('20191115-161701', 'accepted'), ('20191115-161706', 'starting')]
# nodesjob_dict['node_status'][-1]:('20191115-161706', 'starting')
# job_time:20191115-161706,job_status:starting
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161701', 'ready for node'), ('20191115-161701', 'accepted'), ('20191115-161706', 'starting')]
# nodesjob_dict['node_status'][-1]:('20191115-161706', 'starting')
# job_time:20191115-161706,job_status:starting
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161701', 'ready for node'), ('20191115-161701', 'accepted'), ('20191115-161706', 'starting')]
# nodesjob_dict['node_status'][-1]:('20191115-161706', 'starting')
# job_time:20191115-161706,job_status:starting
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161701', 'ready for node'), ('20191115-161701', 'accepted'), ('20191115-161706', 'starting')]
# nodesjob_dict['node_status'][-1]:('20191115-161706', 'starting')
# job_time:20191115-161706,job_status:starting
# Traceback (most recent call last):
#   File "C:\Users\DPatton\gits\kernelkernel\mycluster.py", line 271, in check_node_job_status
#     with open(nodes_job_filename,'rb') as saved_job_file:
# FileNotFoundError: [Errno 2] No such file or directory: 'O:/Public/DPatton/kernel/node2/node2_job'
#
# job_time:20191115-161800,job_status:no file found
# about to setup the job for node:('node2', [('20191115-161757', 'created'), ('20191115-161758', None), ('20191115-161759', None)])
# job setup for node:node2
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161701', 'ready for node'), ('20191115-161701', 'accepted'), ('20191115-161706', 'starting')]
# nodesjob_dict['node_status'][-1]:('20191115-161706', 'starting')
# job_time:20191115-161706,job_status:starting
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161701', 'ready for node'), ('20191115-161701', 'accepted'), ('20191115-161706', 'starting')]
# nodesjob_dict['node_status'][-1]:('20191115-161706', 'starting')
# job_time:20191115-161706,job_status:starting
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161701', 'ready for node'), ('20191115-161701', 'accepted'), ('20191115-161706', 'starting')]
# nodesjob_dict['node_status'][-1]:('20191115-161706', 'starting')
# job_time:20191115-161706,job_status:starting
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# [WinError 32] The process cannot access the file because it is being used by another process: 'node11'
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# check_node_job_status found: nodes_jobdict["status"]:[('20191115-161800', 'ready for node')]
# nodesjob_dict['node_status'][-1]:('20191115-161800', 'ready for node')
# job_time:20191115-161800,job_status:ready for node
# [WinError 145] The directory is not empty: 'node2'
