# %% [markdown]
# ### kernel density estimation and kernel regression for prediction
# This notebook is my first attempt to write down the ddiff and dddiff models that I have been working on

# %% [markdown]
# mixed recursive/iterative approach (rather than vectorized approach that is harder to generalize
# - create separate submodules for KDE and KDreg
#     - develop a system for storing differenced but unweighted data and the appropriate mask to lessen memory usage.
#         -1's or 0's depending on i/j/k/l/.... values
#     - figure out the deepest level requested by the user and levels that are less deep are just slices of the deeper model.
#         -scout out the tree to build the differenced dataset.
#
#
#  plot and compare
# on synthetic data, 1, 2, 3+ mixed distributions
# 1d - Ndiff vs gaussian kernel vs kernel_tunneling
# 2d -
#
#
# multidimensional x problem
# e.g., parameter treatment
# "product kernel approach" vs l2 "el two" (radial basis?)distance

# %% [markdown]
# #### generate a simple linear dataset y=xb+e
# ##### store validation data from same dataset too

# %% [markdown]
# ### create modeldict
# - 'loss_function':
#   - 'mse'
#   - cross_mse
#   - cross_msei
#   - batch_crossval
#   - batchnorm_crossval
# - 'Ndiff_type': refers to the mathematical form of Ndiff
#   - 'product'-Ndiff1 multiplied by Ndiff2
#   - 'recursive'-Ndiff1's bw is Ndiff 2
# - max_bw_Ndiff: is the depth of Ndiffs applied in estimating the bandwidth.
# - 'normalize_Ndiffwtsum':
#   - 'across' means sum across own level of kernelized-Ndiffs and divide by that sum (CDF approach)
#   - 'own_n' means for (n+k)diff where n+K=max_bw_Ndiff
# - 'NWnorm
#   - 'across1' prior to 1/15 when mistake identified in summation dimension for NWnorm across
#   - 'across' correct implementation, where for each prediciton, the sum of the weights applied to the yout is normalized to 1.
#   - 'none'
# - Ndiff_bw_kern:
#   - rbfkern means use the radial basis function kernel
#   - 'product' means use product kernel like as in liu and yang eq1.
# - 'regression_model':
#   - 'NW' means use nadaraya-watson kernel regression
#   - 'NW-rbf' means use NW but calculate p(y,x) using rbf kernel rather than product kernel
#   - 'NW-rbf2' means NW-rbf plus euclidean distance logic (i.e. subtraction) for p(y,x)/p(y)
#   - 'full_logit' means local logit with all variables entering linearly
#   - 'rbf_logit' means local logit with 1 parameters: scaled l2 norm centered on zero
#  (globally or by i?). Is this a new idea?
# - outer_x_bw_form: if x is separated into blocks of rvars that are combined within a block using rbf kernel,
#   - 'one_for_all' - use same hx bw for all blocks
#   - 'one_per_block' - each block or rvars gets an hx (not developed)
# - ykerngrid_form
#   - ('even',4),then create 'ykern_grid' evnely spaced values from -4 to 4
#   - ('exp',4), then create'ykern_grid' exponentially spaced (more near zero) values from -4 to 4
#   - ('binary') a continuous spread of 'ykern_grid' values from 0 to 1, inclusive
# - ykern_grid
#   - 'no' means use original data points (self is masked when predicting self)
#   - an integer specifies the number of values to use in 'ykerngrid_form'
# - xkern_grid
#   - much like ykern_grid, but used less frequently since x's are typically pre-specified
# - product_kern_norm: when multiplying kernels across random variables, this parameter determines if each random variable has its kernels normalized before the product or not
#   - 'self' means each random variable has its kernels divided by the sum of kernels across the nout axis (the number of possibile values y is averaged over, whose probabilities sum to 1)
#   - 'own_n' means same as self, but divided by count of non-masked items in second to last, nout lenght dimension
#   - 'none' means no normalization prior to taking products across rvar kernels
# - hyper_param_form_dict is a nested dictionary
#   - Ndiff_exponent is the exponent wrapped around typically a sum of kernels for each Ndiff level
# after level 1 (i.e., (i-j) or centered, obvious/conventional level.)
#   - x_bandscale is the parameter specific to each variable (each x in X) used for prediction (y)
#   - Ndiff_depth_bw is used as the kernel's bandwidth (h) at each level of Ndiff including at level 1
#   - outer_x_bw vanilla bandwidth for the rbf or product kernel
#   - outer_y_bw vanilla bandwidth for y

# %%
import os
import kernelcompare as kc
#from importlib import reload
networkdir='o:/public/dpatton/kernel'
mydir=os.getcwd()
#mydir2=os.path.join(mydir,"old models without datagen")
test=kc.KernelCompare(directory=mydir)

# %%
pisces_datagen_dict=test.setdata('pisces')
pisces_datagen_dict
# Out:
# {'source': 'pisces',
#  'batch_n': 32,
#  'batchcount': 10,
#  'sample_replace': 'no',
#  'species': 'all',
#  'missing': 'drop_row',
#  'floatselecttup': (2, 3, 5, 6),
#  'spatialselecttup': (8,),
#  'param_count': 5}

# %%
n=32
ykerngrid_form_variations=('modeldict:ykerngrid_form',[('binary',)])
lossfn_variations=('modeldict:loss_function',['batchnorm_crossval'])
#lossfn_variations=('modeldict:loss_function',['batch_crossval'])
#lossfn_variations=('modeldict:loss_function',['mse'])
#Ndiff_type_variations=('modeldict:Ndiff_type',['recursive'])
Ndiff_type_variations=('modeldict:Ndiff_type',['product'])
max_bw_Ndiff_variations=('modeldict:max_bw_Ndiff',[2])
NWnorm_variations=('modeldict:NWnorm',['none'])
Ndiff_start_variations=('modeldict:Ndiff_start',[1])
ykern_grid_variations=('modeldict:ykern_grid',[2])
standardization_variations=('modeldict:std_data',[([],'float')])
regression_model_variations=('modeldict:regression_model',['NW-rbf'])
#product_kern_norm_variations=('modeldict:product_kern_norm',['self','own_n'])#include None too?
#normalize_Ndiffwtsum_variations=('modeldict:normalize_Ndiffwtsum',['own_n','across'])
optdict_variation_list=[NWnorm_variations,
                        ykerngrid_form_variations, 
                        lossfn_variations,
                        regression_model_variations,
                        Ndiff_type_variations,
                        ykern_grid_variations,
                        max_bw_Ndiff_variations,
                        standardization_variations,
                        Ndiff_start_variations
                       ]  #,product_kern_norm_variations,normalize_Ndiffwtsum_variations]

# %%
#species_variations=('species',[4,5])
batch_n_variations=('batch_n',[n])
datagen_variation_list=[batch_n_variations]

# %%
testrun=test.prep_model_list(optdict_variation_list=optdict_variation_list,datagen_variation_list=datagen_variation_list,datagen_dict=pisces_datagen_dict,verbose=0)
'''print(f'len(testrun){len(testrun)}')
print(f'testrun[0]{testrun[0:2]}')
print('--------------')
print(f'testrun[-1]{testrun[-4:]}')'''
# Out:
# opening C:\Users\DPatton\gits\kernelkernel\data_tool\specieslistfiles with length:7 and type:<class 'tuple'>
# len(datagen_dict_list):565
# "print(f'len(testrun){len(testrun)}')\nprint(f'testrun[0]{testrun[0:2]}')\nprint('--------------')\nprint(f'testrun[-1]{testrun[-4:]}')"

# %%
import traceback
#from random import shuffle
#shuffle(testrun)
#testrun=testrun[-1::]
#a_rundict=testrun[100]#this produced the Ndiff_exponent error for recursive Ndiff
for idx in range(0,565,1):#len(testrun)):
    print(f'~~~~~~~run number:{idx}`~~~~~~~')
    a_rundict=testrun[idx]
    print(f'a_rundict{a_rundict}')
    optimizedict=a_rundict['optimizedict']
    datagen_dict=a_rundict['datagen_dict']

    try:
        test.do_monte_opt(optimizedict,datagen_dict,force_start_params=1)
        test.open_condense_resave('model_save',verbose=0)
        test.merge_and_condense_saved_models(merge_directory=None,save_directory=None,condense=None,verbose=None)
    except:
        print('traceback for run',idx)
        print(traceback.format_exc())
# Out:
# ~~~~~~~run number:0`~~~~~~~
# a_rundict{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.5, 'fatol': 1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}, 'modeldict': {'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'cyprinus carpio', 'ykerngrid_form': ('binary',)}}, 'datagen_dict': {'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'cyprinus carpio', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5}}
# opening C:\Users\DPatton\gits\kernelkernel\data_tool\specieslistfiles with length:7 and type:<class 'tuple'>
# <class 'list'>
# <class 'list'>
# species_n: 25313
# self.xvarname_list: ['WA', 'Elev', 'IWI', 'Slope', 'HUC12(spatial)']
# datagen_dict:{'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'cyprinus carpio', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5} for directory,C:\Users\DPatton\gits\kernelkernel
# INFO <PID 19480:MainProcess> myKernLogger.__init__(): optimizedict for None:{'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.5, 'fatol': 1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}, 'modeldict': {'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'cyprinus carpio', 'ykerngrid_form': ('binary',)}, 'datagen_dict': {'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'cyprinus carpio', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5}}
# param_valdict:{'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}
# INFO <PID 19480:MainProcess> myKernLogger.setup_fixed_or_free(): setup_fixed_or_free_paramdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 7)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 9)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (9, 10)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (10, 11)}, 'y_bandscale': {'fixed_or_free': 'fixed', 'const': 'fixed', 'location_idx': (0, 1)}, 'free_params': 'outside', 'fixed_params': array([1.])}
# self.npr 288
# mykern modeldict:{'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'cyprinus carpio', 'ykerngrid_form': ('binary',)}
# self.batchbatchcount 80
# batchbatchidx: 0
# traceback for run 0
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 801, in MPwrapperKDEpredict
#     KDEpredict_tup=self.MY_KDEpredict(yin, yout, xin, xpr, modeldict, fixed_or_free_paramdict)
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 403, in MY_KDEpredict
#     xbw = self.BWmaker(fixed_or_free_paramdict, diffdict, modeldict,'x')
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 345, in BWmaker
#     return self.NdiffBWmaker(modeldict['max_bw_Ndiff'], fixed_or_free_paramdict, diffdict, modeldict,xory)
#   File "C:\Users\DPatton\gits\kernelkernel\Ndiff.py", line 83, in NdiffBWmaker
#     this_depth_data=self.Ndiff_datastacker(indiffs,outdiffs,depth)
#   File "C:\Users\DPatton\gits\kernelkernel\Ndiff.py", line 151, in Ndiff_datastacker
#     np.transpose(indiffs,indiffshape)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py", line 639, in transpose
#     return _wrapfunc(a, 'transpose', axes)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py", line 56, in _wrapfunc
#     return getattr(obj, method)(*args, **kwds)
# numpy.AxisError: axis 32 is out of bounds for array of dimension 2
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-6-2a15468e7be7>", line 14, in <module>
#     test.do_monte_opt(optimizedict,datagen_dict,force_start_params=1)
#   File "C:\Users\DPatton\gits\kernelkernel\kernelcompare.py", line 52, in do_monte_opt
#     mk.optimize_free_params(datagen_obj,optimizedict,savedir=self.kc_savedirectory,myname=self.name)
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 994, in __init__
#     self.minimize_obj=minimize(self.MY_KDEpredictMSE, free_params, args=args_tuple, method=method, options=opt_method_options)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\_minimize.py", line 588, in minimize
#     return _minimize_neldermead(fun, x0, args, callback, **options)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py", line 585, in _minimize_neldermead
#     fsim[k] = func(sim[k])
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py", line 326, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 704, in MY_KDEpredictMSE
#     yhat_unstd_outtup_list=pool.map(self.MPwrapperKDEpredict,arglistlist)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 268, in map
#     return self._map_async(func, iterable, mapstar, chunksize).get()
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 657, in get
#     raise self._value
# numpy.AxisError: axis 32 is out of bounds for array of dimension 2
#
# ~~~~~~~run number:1`~~~~~~~
# a_rundict{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.5, 'fatol': 1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}, 'modeldict': {'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'ictalurus punctatus', 'ykerngrid_form': ('binary',)}}, 'datagen_dict': {'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'ictalurus punctatus', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5}}
# opening C:\Users\DPatton\gits\kernelkernel\data_tool\specieslistfiles with length:7 and type:<class 'tuple'>
# <class 'list'>
# <class 'list'>
# species_n: 22604
# self.xvarname_list: ['WA', 'Elev', 'IWI', 'Slope', 'HUC12(spatial)']
# datagen_dict:{'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'ictalurus punctatus', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5} for directory,C:\Users\DPatton\gits\kernelkernel
# INFO <PID 19480:MainProcess> myKernLogger.__init__(): optimizedict for None:{'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.5, 'fatol': 1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}, 'modeldict': {'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'ictalurus punctatus', 'ykerngrid_form': ('binary',)}, 'datagen_dict': {'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'ictalurus punctatus', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5}}
# param_valdict:{'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}
# INFO <PID 19480:MainProcess> myKernLogger.setup_fixed_or_free(): setup_fixed_or_free_paramdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 7)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 9)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (9, 10)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (10, 11)}, 'y_bandscale': {'fixed_or_free': 'fixed', 'const': 'fixed', 'location_idx': (0, 1)}, 'free_params': 'outside', 'fixed_params': array([1.])}
# self.npr 288
# mykern modeldict:{'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'ictalurus punctatus', 'ykerngrid_form': ('binary',)}
# self.batchbatchcount 71
# batchbatchidx: 0
# traceback for run 1
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 801, in MPwrapperKDEpredict
#     KDEpredict_tup=self.MY_KDEpredict(yin, yout, xin, xpr, modeldict, fixed_or_free_paramdict)
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 403, in MY_KDEpredict
#     xbw = self.BWmaker(fixed_or_free_paramdict, diffdict, modeldict,'x')
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 345, in BWmaker
#     return self.NdiffBWmaker(modeldict['max_bw_Ndiff'], fixed_or_free_paramdict, diffdict, modeldict,xory)
#   File "C:\Users\DPatton\gits\kernelkernel\Ndiff.py", line 83, in NdiffBWmaker
#     this_depth_data=self.Ndiff_datastacker(indiffs,outdiffs,depth)
#   File "C:\Users\DPatton\gits\kernelkernel\Ndiff.py", line 151, in Ndiff_datastacker
#     np.transpose(indiffs,indiffshape)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py", line 639, in transpose
#     return _wrapfunc(a, 'transpose', axes)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py", line 56, in _wrapfunc
#     return getattr(obj, method)(*args, **kwds)
# numpy.AxisError: axis 32 is out of bounds for array of dimension 2
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-6-2a15468e7be7>", line 14, in <module>
#     test.do_monte_opt(optimizedict,datagen_dict,force_start_params=1)
#   File "C:\Users\DPatton\gits\kernelkernel\kernelcompare.py", line 52, in do_monte_opt
#     mk.optimize_free_params(datagen_obj,optimizedict,savedir=self.kc_savedirectory,myname=self.name)
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 994, in __init__
#     self.minimize_obj=minimize(self.MY_KDEpredictMSE, free_params, args=args_tuple, method=method, options=opt_method_options)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\_minimize.py", line 588, in minimize
#     return _minimize_neldermead(fun, x0, args, callback, **options)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py", line 585, in _minimize_neldermead
#     fsim[k] = func(sim[k])
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py", line 326, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 704, in MY_KDEpredictMSE
#     yhat_unstd_outtup_list=pool.map(self.MPwrapperKDEpredict,arglistlist)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 268, in map
#     return self._map_async(func, iterable, mapstar, chunksize).get()
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 657, in get
#     raise self._value
# numpy.AxisError: axis 32 is out of bounds for array of dimension 2
#
# ~~~~~~~run number:2`~~~~~~~
# a_rundict{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.5, 'fatol': 1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}, 'modeldict': {'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'lepomis macrochirus', 'ykerngrid_form': ('binary',)}}, 'datagen_dict': {'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'lepomis macrochirus', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5}}
# opening C:\Users\DPatton\gits\kernelkernel\data_tool\specieslistfiles with length:7 and type:<class 'tuple'>
# <class 'list'>
# <class 'list'>
# species_n: 26232
# self.xvarname_list: ['WA', 'Elev', 'IWI', 'Slope', 'HUC12(spatial)']
# datagen_dict:{'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'lepomis macrochirus', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5} for directory,C:\Users\DPatton\gits\kernelkernel
# INFO <PID 19480:MainProcess> myKernLogger.__init__(): optimizedict for None:{'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.5, 'fatol': 1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}, 'modeldict': {'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'lepomis macrochirus', 'ykerngrid_form': ('binary',)}, 'datagen_dict': {'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'lepomis macrochirus', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5}}
# param_valdict:{'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}
# INFO <PID 19480:MainProcess> myKernLogger.setup_fixed_or_free(): setup_fixed_or_free_paramdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 7)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 9)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (9, 10)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (10, 11)}, 'y_bandscale': {'fixed_or_free': 'fixed', 'const': 'fixed', 'location_idx': (0, 1)}, 'free_params': 'outside', 'fixed_params': array([1.])}
# self.npr 288
# mykern modeldict:{'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'lepomis macrochirus', 'ykerngrid_form': ('binary',)}
# self.batchbatchcount 82
# batchbatchidx: 0
# traceback for run 2
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 801, in MPwrapperKDEpredict
#     KDEpredict_tup=self.MY_KDEpredict(yin, yout, xin, xpr, modeldict, fixed_or_free_paramdict)
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 403, in MY_KDEpredict
#     xbw = self.BWmaker(fixed_or_free_paramdict, diffdict, modeldict,'x')
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 345, in BWmaker
#     return self.NdiffBWmaker(modeldict['max_bw_Ndiff'], fixed_or_free_paramdict, diffdict, modeldict,xory)
#   File "C:\Users\DPatton\gits\kernelkernel\Ndiff.py", line 83, in NdiffBWmaker
#     this_depth_data=self.Ndiff_datastacker(indiffs,outdiffs,depth)
#   File "C:\Users\DPatton\gits\kernelkernel\Ndiff.py", line 151, in Ndiff_datastacker
#     np.transpose(indiffs,indiffshape)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py", line 639, in transpose
#     return _wrapfunc(a, 'transpose', axes)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py", line 56, in _wrapfunc
#     return getattr(obj, method)(*args, **kwds)
# numpy.AxisError: axis 32 is out of bounds for array of dimension 2
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-6-2a15468e7be7>", line 14, in <module>
#     test.do_monte_opt(optimizedict,datagen_dict,force_start_params=1)
#   File "C:\Users\DPatton\gits\kernelkernel\kernelcompare.py", line 52, in do_monte_opt
#     mk.optimize_free_params(datagen_obj,optimizedict,savedir=self.kc_savedirectory,myname=self.name)
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 994, in __init__
#     self.minimize_obj=minimize(self.MY_KDEpredictMSE, free_params, args=args_tuple, method=method, options=opt_method_options)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\_minimize.py", line 588, in minimize
#     return _minimize_neldermead(fun, x0, args, callback, **options)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py", line 585, in _minimize_neldermead
#     fsim[k] = func(sim[k])
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py", line 326, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 704, in MY_KDEpredictMSE
#     yhat_unstd_outtup_list=pool.map(self.MPwrapperKDEpredict,arglistlist)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 268, in map
#     return self._map_async(func, iterable, mapstar, chunksize).get()
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 657, in get
#     raise self._value
# numpy.AxisError: axis 32 is out of bounds for array of dimension 2
#
# ~~~~~~~run number:3`~~~~~~~
# a_rundict{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.5, 'fatol': 1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}, 'modeldict': {'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'micropterus dolomieu', 'ykerngrid_form': ('binary',)}}, 'datagen_dict': {'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'micropterus dolomieu', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5}}
# opening C:\Users\DPatton\gits\kernelkernel\data_tool\specieslistfiles with length:7 and type:<class 'tuple'>
# <class 'list'>
# <class 'list'>
# species_n: 23115
# self.xvarname_list: ['WA', 'Elev', 'IWI', 'Slope', 'HUC12(spatial)']
# datagen_dict:{'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'micropterus dolomieu', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5} for directory,C:\Users\DPatton\gits\kernelkernel
# INFO <PID 19480:MainProcess> myKernLogger.__init__(): optimizedict for None:{'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.5, 'fatol': 1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}, 'modeldict': {'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'micropterus dolomieu', 'ykerngrid_form': ('binary',)}, 'datagen_dict': {'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'micropterus dolomieu', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5}}
# param_valdict:{'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}
# INFO <PID 19480:MainProcess> myKernLogger.setup_fixed_or_free(): setup_fixed_or_free_paramdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 7)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 9)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (9, 10)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (10, 11)}, 'y_bandscale': {'fixed_or_free': 'fixed', 'const': 'fixed', 'location_idx': (0, 1)}, 'free_params': 'outside', 'fixed_params': array([1.])}
# self.npr 288
# mykern modeldict:{'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'micropterus dolomieu', 'ykerngrid_form': ('binary',)}
# self.batchbatchcount 73
# batchbatchidx: 0
# traceback for run 3
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 801, in MPwrapperKDEpredict
#     KDEpredict_tup=self.MY_KDEpredict(yin, yout, xin, xpr, modeldict, fixed_or_free_paramdict)
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 403, in MY_KDEpredict
#     xbw = self.BWmaker(fixed_or_free_paramdict, diffdict, modeldict,'x')
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 345, in BWmaker
#     return self.NdiffBWmaker(modeldict['max_bw_Ndiff'], fixed_or_free_paramdict, diffdict, modeldict,xory)
#   File "C:\Users\DPatton\gits\kernelkernel\Ndiff.py", line 83, in NdiffBWmaker
#     this_depth_data=self.Ndiff_datastacker(indiffs,outdiffs,depth)
#   File "C:\Users\DPatton\gits\kernelkernel\Ndiff.py", line 151, in Ndiff_datastacker
#     np.transpose(indiffs,indiffshape)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py", line 639, in transpose
#     return _wrapfunc(a, 'transpose', axes)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py", line 56, in _wrapfunc
#     return getattr(obj, method)(*args, **kwds)
# numpy.AxisError: axis 32 is out of bounds for array of dimension 2
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-6-2a15468e7be7>", line 14, in <module>
#     test.do_monte_opt(optimizedict,datagen_dict,force_start_params=1)
#   File "C:\Users\DPatton\gits\kernelkernel\kernelcompare.py", line 52, in do_monte_opt
#     mk.optimize_free_params(datagen_obj,optimizedict,savedir=self.kc_savedirectory,myname=self.name)
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 994, in __init__
#     self.minimize_obj=minimize(self.MY_KDEpredictMSE, free_params, args=args_tuple, method=method, options=opt_method_options)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\_minimize.py", line 588, in minimize
#     return _minimize_neldermead(fun, x0, args, callback, **options)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py", line 585, in _minimize_neldermead
#     fsim[k] = func(sim[k])
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py", line 326, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 704, in MY_KDEpredictMSE
#     yhat_unstd_outtup_list=pool.map(self.MPwrapperKDEpredict,arglistlist)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 268, in map
#     return self._map_async(func, iterable, mapstar, chunksize).get()
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 657, in get
#     raise self._value
# numpy.AxisError: axis 32 is out of bounds for array of dimension 2
#
# ~~~~~~~run number:4`~~~~~~~
# a_rundict{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.5, 'fatol': 1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}, 'modeldict': {'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'micropterus salmoides', 'ykerngrid_form': ('binary',)}}, 'datagen_dict': {'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'micropterus salmoides', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5}}
# opening C:\Users\DPatton\gits\kernelkernel\data_tool\specieslistfiles with length:7 and type:<class 'tuple'>
# <class 'list'>
# <class 'list'>
# species_n: 26565
# self.xvarname_list: ['WA', 'Elev', 'IWI', 'Slope', 'HUC12(spatial)']
# datagen_dict:{'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'micropterus salmoides', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5} for directory,C:\Users\DPatton\gits\kernelkernel
# INFO <PID 19480:MainProcess> myKernLogger.__init__(): optimizedict for None:{'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.5, 'fatol': 1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}, 'modeldict': {'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'micropterus salmoides', 'ykerngrid_form': ('binary',)}, 'datagen_dict': {'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'micropterus salmoides', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5}}
# param_valdict:{'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}
# INFO <PID 19480:MainProcess> myKernLogger.setup_fixed_or_free(): setup_fixed_or_free_paramdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 7)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 9)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (9, 10)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (10, 11)}, 'y_bandscale': {'fixed_or_free': 'fixed', 'const': 'fixed', 'location_idx': (0, 1)}, 'free_params': 'outside', 'fixed_params': array([1.])}
# self.npr 288
# mykern modeldict:{'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'micropterus salmoides', 'ykerngrid_form': ('binary',)}
# self.batchbatchcount 84
# batchbatchidx: 0
# traceback for run 4
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 801, in MPwrapperKDEpredict
#     KDEpredict_tup=self.MY_KDEpredict(yin, yout, xin, xpr, modeldict, fixed_or_free_paramdict)
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 403, in MY_KDEpredict
#     xbw = self.BWmaker(fixed_or_free_paramdict, diffdict, modeldict,'x')
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 345, in BWmaker
#     return self.NdiffBWmaker(modeldict['max_bw_Ndiff'], fixed_or_free_paramdict, diffdict, modeldict,xory)
#   File "C:\Users\DPatton\gits\kernelkernel\Ndiff.py", line 83, in NdiffBWmaker
#     this_depth_data=self.Ndiff_datastacker(indiffs,outdiffs,depth)
#   File "C:\Users\DPatton\gits\kernelkernel\Ndiff.py", line 151, in Ndiff_datastacker
#     np.transpose(indiffs,indiffshape)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py", line 639, in transpose
#     return _wrapfunc(a, 'transpose', axes)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py", line 56, in _wrapfunc
#     return getattr(obj, method)(*args, **kwds)
# numpy.AxisError: axis 32 is out of bounds for array of dimension 2
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-6-2a15468e7be7>", line 14, in <module>
#     test.do_monte_opt(optimizedict,datagen_dict,force_start_params=1)
#   File "C:\Users\DPatton\gits\kernelkernel\kernelcompare.py", line 52, in do_monte_opt
#     mk.optimize_free_params(datagen_obj,optimizedict,savedir=self.kc_savedirectory,myname=self.name)
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 994, in __init__
#     self.minimize_obj=minimize(self.MY_KDEpredictMSE, free_params, args=args_tuple, method=method, options=opt_method_options)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\_minimize.py", line 588, in minimize
#     return _minimize_neldermead(fun, x0, args, callback, **options)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py", line 585, in _minimize_neldermead
#     fsim[k] = func(sim[k])
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py", line 326, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 704, in MY_KDEpredictMSE
#     yhat_unstd_outtup_list=pool.map(self.MPwrapperKDEpredict,arglistlist)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 268, in map
#     return self._map_async(func, iterable, mapstar, chunksize).get()
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 657, in get
#     raise self._value
# numpy.AxisError: axis 32 is out of bounds for array of dimension 2
#
# ~~~~~~~run number:5`~~~~~~~
# a_rundict{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.5, 'fatol': 1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}, 'modeldict': {'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'pylodictis olivaris', 'ykerngrid_form': ('binary',)}}, 'datagen_dict': {'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'pylodictis olivaris', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5}}
# opening C:\Users\DPatton\gits\kernelkernel\data_tool\specieslistfiles with length:7 and type:<class 'tuple'>
# <class 'list'>
# <class 'list'>
# species_n: 15980
# self.xvarname_list: ['WA', 'Elev', 'IWI', 'Slope', 'HUC12(spatial)']
# datagen_dict:{'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'pylodictis olivaris', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5} for directory,C:\Users\DPatton\gits\kernelkernel
# INFO <PID 19480:MainProcess> myKernLogger.__init__(): optimizedict for None:{'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.5, 'fatol': 1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}, 'modeldict': {'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'pylodictis olivaris', 'ykerngrid_form': ('binary',)}, 'datagen_dict': {'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'pylodictis olivaris', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5}}
# param_valdict:{'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}
# INFO <PID 19480:MainProcess> myKernLogger.setup_fixed_or_free(): setup_fixed_or_free_paramdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 7)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 9)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (9, 10)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (10, 11)}, 'y_bandscale': {'fixed_or_free': 'fixed', 'const': 'fixed', 'location_idx': (0, 1)}, 'free_params': 'outside', 'fixed_params': array([1.])}
# self.npr 288
# mykern modeldict:{'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'pylodictis olivaris', 'ykerngrid_form': ('binary',)}
# self.batchbatchcount 50
# batchbatchidx: 0
# traceback for run 5
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 801, in MPwrapperKDEpredict
#     KDEpredict_tup=self.MY_KDEpredict(yin, yout, xin, xpr, modeldict, fixed_or_free_paramdict)
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 403, in MY_KDEpredict
#     xbw = self.BWmaker(fixed_or_free_paramdict, diffdict, modeldict,'x')
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 345, in BWmaker
#     return self.NdiffBWmaker(modeldict['max_bw_Ndiff'], fixed_or_free_paramdict, diffdict, modeldict,xory)
#   File "C:\Users\DPatton\gits\kernelkernel\Ndiff.py", line 83, in NdiffBWmaker
#     this_depth_data=self.Ndiff_datastacker(indiffs,outdiffs,depth)
#   File "C:\Users\DPatton\gits\kernelkernel\Ndiff.py", line 151, in Ndiff_datastacker
#     np.transpose(indiffs,indiffshape)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py", line 639, in transpose
#     return _wrapfunc(a, 'transpose', axes)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py", line 56, in _wrapfunc
#     return getattr(obj, method)(*args, **kwds)
# numpy.AxisError: axis 32 is out of bounds for array of dimension 2
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-6-2a15468e7be7>", line 14, in <module>
#     test.do_monte_opt(optimizedict,datagen_dict,force_start_params=1)
#   File "C:\Users\DPatton\gits\kernelkernel\kernelcompare.py", line 52, in do_monte_opt
#     mk.optimize_free_params(datagen_obj,optimizedict,savedir=self.kc_savedirectory,myname=self.name)
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 994, in __init__
#     self.minimize_obj=minimize(self.MY_KDEpredictMSE, free_params, args=args_tuple, method=method, options=opt_method_options)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\_minimize.py", line 588, in minimize
#     return _minimize_neldermead(fun, x0, args, callback, **options)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py", line 585, in _minimize_neldermead
#     fsim[k] = func(sim[k])
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py", line 326, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 704, in MY_KDEpredictMSE
#     yhat_unstd_outtup_list=pool.map(self.MPwrapperKDEpredict,arglistlist)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 268, in map
#     return self._map_async(func, iterable, mapstar, chunksize).get()
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 657, in get
#     raise self._value
# ...
# traceback for run 67
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 801, in MPwrapperKDEpredict
#     KDEpredict_tup=self.MY_KDEpredict(yin, yout, xin, xpr, modeldict, fixed_or_free_paramdict)
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 403, in MY_KDEpredict
#     xbw = self.BWmaker(fixed_or_free_paramdict, diffdict, modeldict,'x')
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 345, in BWmaker
#     return self.NdiffBWmaker(modeldict['max_bw_Ndiff'], fixed_or_free_paramdict, diffdict, modeldict,xory)
#   File "C:\Users\DPatton\gits\kernelkernel\Ndiff.py", line 83, in NdiffBWmaker
#     this_depth_data=self.Ndiff_datastacker(indiffs,outdiffs,depth)
#   File "C:\Users\DPatton\gits\kernelkernel\Ndiff.py", line 151, in Ndiff_datastacker
#     np.transpose(indiffs,indiffshape)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py", line 639, in transpose
#     return _wrapfunc(a, 'transpose', axes)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py", line 56, in _wrapfunc
#     return getattr(obj, method)(*args, **kwds)
# numpy.AxisError: axis 32 is out of bounds for array of dimension 2
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-6-2a15468e7be7>", line 14, in <module>
#     test.do_monte_opt(optimizedict,datagen_dict,force_start_params=1)
#   File "C:\Users\DPatton\gits\kernelkernel\kernelcompare.py", line 52, in do_monte_opt
#     mk.optimize_free_params(datagen_obj,optimizedict,savedir=self.kc_savedirectory,myname=self.name)
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 994, in __init__
#     self.minimize_obj=minimize(self.MY_KDEpredictMSE, free_params, args=args_tuple, method=method, options=opt_method_options)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\_minimize.py", line 588, in minimize
#     return _minimize_neldermead(fun, x0, args, callback, **options)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py", line 585, in _minimize_neldermead
#     fsim[k] = func(sim[k])
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py", line 326, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 704, in MY_KDEpredictMSE
#     yhat_unstd_outtup_list=pool.map(self.MPwrapperKDEpredict,arglistlist)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 268, in map
#     return self._map_async(func, iterable, mapstar, chunksize).get()
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 657, in get
#     raise self._value
# numpy.AxisError: axis 32 is out of bounds for array of dimension 2
#
# ~~~~~~~run number:68`~~~~~~~
# a_rundict{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.5, 'fatol': 1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}, 'modeldict': {'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'notropis stramineus', 'ykerngrid_form': ('binary',)}}, 'datagen_dict': {'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'notropis stramineus', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5}}
# opening C:\Users\DPatton\gits\kernelkernel\data_tool\specieslistfiles with length:7 and type:<class 'tuple'>
# <class 'list'>
# <class 'list'>
# species_n: 13989
# self.xvarname_list: ['WA', 'Elev', 'IWI', 'Slope', 'HUC12(spatial)']
# datagen_dict:{'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'notropis stramineus', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5} for directory,C:\Users\DPatton\gits\kernelkernel
# INFO <PID 19480:MainProcess> myKernLogger.__init__(): optimizedict for None:{'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.5, 'fatol': 1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}, 'modeldict': {'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'notropis stramineus', 'ykerngrid_form': ('binary',)}, 'datagen_dict': {'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'notropis stramineus', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5}}
# param_valdict:{'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}
# INFO <PID 19480:MainProcess> myKernLogger.setup_fixed_or_free(): setup_fixed_or_free_paramdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 7)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 9)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (9, 10)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (10, 11)}, 'y_bandscale': {'fixed_or_free': 'fixed', 'const': 'fixed', 'location_idx': (0, 1)}, 'free_params': 'outside', 'fixed_params': array([1.])}
# self.npr 288
# mykern modeldict:{'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'notropis stramineus', 'ykerngrid_form': ('binary',)}
# self.batchbatchcount 44
# batchbatchidx: 0
# traceback for run 68
# multiprocessing.pool.RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 801, in MPwrapperKDEpredict
#     KDEpredict_tup=self.MY_KDEpredict(yin, yout, xin, xpr, modeldict, fixed_or_free_paramdict)
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 403, in MY_KDEpredict
#     xbw = self.BWmaker(fixed_or_free_paramdict, diffdict, modeldict,'x')
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 345, in BWmaker
#     return self.NdiffBWmaker(modeldict['max_bw_Ndiff'], fixed_or_free_paramdict, diffdict, modeldict,xory)
#   File "C:\Users\DPatton\gits\kernelkernel\Ndiff.py", line 83, in NdiffBWmaker
#     this_depth_data=self.Ndiff_datastacker(indiffs,outdiffs,depth)
#   File "C:\Users\DPatton\gits\kernelkernel\Ndiff.py", line 151, in Ndiff_datastacker
#     np.transpose(indiffs,indiffshape)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py", line 639, in transpose
#     return _wrapfunc(a, 'transpose', axes)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py", line 56, in _wrapfunc
#     return getattr(obj, method)(*args, **kwds)
# numpy.AxisError: axis 32 is out of bounds for array of dimension 2
# """
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "<ipython-input-6-2a15468e7be7>", line 14, in <module>
#     test.do_monte_opt(optimizedict,datagen_dict,force_start_params=1)
#   File "C:\Users\DPatton\gits\kernelkernel\kernelcompare.py", line 52, in do_monte_opt
#     mk.optimize_free_params(datagen_obj,optimizedict,savedir=self.kc_savedirectory,myname=self.name)
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 994, in __init__
#     self.minimize_obj=minimize(self.MY_KDEpredictMSE, free_params, args=args_tuple, method=method, options=opt_method_options)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\_minimize.py", line 588, in minimize
#     return _minimize_neldermead(fun, x0, args, callback, **options)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py", line 585, in _minimize_neldermead
#     fsim[k] = func(sim[k])
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py", line 326, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "C:\Users\DPatton\gits\kernelkernel\mykern.py", line 704, in MY_KDEpredictMSE
#     yhat_unstd_outtup_list=pool.map(self.MPwrapperKDEpredict,arglistlist)
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 268, in map
#     return self._map_async(func, iterable, mapstar, chunksize).get()
#   File "C:\Users\DPatton\AppData\Local\Continuum\anaconda3\lib\multiprocessing\pool.py", line 657, in get
#     raise self._value
# numpy.AxisError: axis 32 is out of bounds for array of dimension 2
#
# ~~~~~~~run number:69`~~~~~~~
# a_rundict{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.5, 'fatol': 1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}, 'modeldict': {'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'noturus flavus', 'ykerngrid_form': ('binary',)}}, 'datagen_dict': {'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'noturus flavus', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5}}
# opening C:\Users\DPatton\gits\kernelkernel\data_tool\specieslistfiles with length:7 and type:<class 'tuple'>
# <class 'list'>
# <class 'list'>
# species_n: 13188
# self.xvarname_list: ['WA', 'Elev', 'IWI', 'Slope', 'HUC12(spatial)']
# datagen_dict:{'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'noturus flavus', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5} for directory,C:\Users\DPatton\gits\kernelkernel
# INFO <PID 19480:MainProcess> myKernLogger.__init__(): optimizedict for None:{'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.5, 'fatol': 1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}, 'modeldict': {'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'noturus flavus', 'ykerngrid_form': ('binary',)}, 'datagen_dict': {'source': 'pisces', 'batch_n': 32, 'batchcount': 10, 'sample_replace': 'no', 'species': 'noturus flavus', 'missing': 'drop_row', 'floatselecttup': (2, 3, 5, 6), 'spatialselecttup': (8,), 'param_count': 5}}
# param_valdict:{'Ndiff_exponent': array([0.0001, 0.0001]), 'x_bandscale': array([1., 1., 1., 1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.])}
# INFO <PID 19480:MainProcess> myKernLogger.setup_fixed_or_free(): setup_fixed_or_free_paramdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 7)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 9)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (9, 10)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (10, 11)}, 'y_bandscale': {'fixed_or_free': 'fixed', 'const': 'fixed', 'location_idx': (0, 1)}, 'free_params': 'outside', 'fixed_params': array([1.])}
# self.npr 288
# mykern modeldict:{'std_data': ([], 'float'), 'loss_function': 'batchnorm_crossval', 'Ndiff_type': 'product', 'param_count': 5, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'NWnorm': 'none', 'xkern_grid': 'no', 'ykern_grid': 2, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW-rbf', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'fixed'}, 'species': 'noturus flavus', 'ykerngrid_form': ('binary',)}
# self.batchbatchcount 42
# batchbatchidx: 0
