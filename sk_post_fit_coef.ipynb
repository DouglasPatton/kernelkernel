# %%
from pi_results import PiResults

# %%
pr=PiResults()

# %%
pr.build_spec_est_coef_df(rebuild=0)
# Out:
# SqliteDict(/home/dp/hdd2/gits/kernelkernel/results/postfitDB.sqlite)

# %%
pr.coef_df
# Out:
#                                                cv_0  cv_1  cv_2  cv_3  cv_4  \
# species              estimator    x_var
# acantharchus pomotis linear-svc   AgKffactCat   NaN   NaN   NaN   NaN   NaN
#                                   AgKffactWs    NaN   NaN   NaN   NaN   NaN
#                                   Al2O3Cat      NaN   NaN   NaN   NaN   NaN
#                                   Al2O3Ws       NaN   NaN   NaN   NaN   NaN
#                                   BFICat        NaN   NaN   NaN   NaN   NaN
# ...                                             ...   ...   ...   ...   ...
# zzzno fish           logistic-reg WetIndexCat   NaN   NaN   NaN   NaN   NaN
#                                   WetIndexWs    NaN   NaN   NaN   NaN   NaN
#                                   WtDepCat      NaN   NaN   NaN   NaN   NaN
#                                   WtDepWs       NaN   NaN   NaN   NaN   NaN
#                                   prG_BMMI      NaN   NaN   NaN   NaN   NaN
#
#                                                cv_0  cv_1  cv_2  cv_3  cv_4  \
# species              estimator    x_var
# acantharchus pomotis linear-svc   AgKffactCat   NaN   NaN   NaN   NaN   NaN
#                                   AgKffactWs    NaN   NaN   NaN   NaN   NaN
#                                   Al2O3Cat      NaN   NaN   NaN   NaN   NaN
#                                   Al2O3Ws       NaN   NaN   NaN   NaN   NaN
#                                   BFICat        NaN   NaN   NaN   NaN   NaN
# ...                                             ...   ...   ...   ...   ...
# zzzno fish           logistic-reg WetIndexCat   NaN   NaN   NaN   NaN   NaN
#                                   WetIndexWs    NaN   NaN   NaN   NaN   NaN
#                                   WtDepCat      NaN   NaN   NaN   NaN   NaN
#                                   WtDepWs       NaN   NaN   NaN   NaN   NaN
#                                   prG_BMMI      NaN   NaN   NaN   NaN   NaN
#
#                                                ...  cv_0  cv_1  cv_2  cv_3  \
# species              estimator    x_var        ...
# acantharchus pomotis linear-svc   AgKffactCat  ...   NaN   NaN   NaN   NaN
#                                   AgKffactWs   ...   NaN   NaN   NaN   NaN
#                                   Al2O3Cat     ...   NaN   NaN   NaN   NaN
#                                   Al2O3Ws      ...   NaN   NaN   NaN   NaN
#                                   BFICat       ...   NaN   NaN   NaN   NaN
# ...                                            ...   ...   ...   ...   ...
# zzzno fish           logistic-reg WetIndexCat  ...   NaN   NaN   NaN   NaN
#                                   WetIndexWs   ...   NaN   NaN   NaN   NaN
#                                   WtDepCat     ...   NaN   NaN   NaN   NaN
#                                   WtDepWs      ...   NaN   NaN   NaN   NaN
#                                   prG_BMMI     ...   NaN   NaN   NaN   NaN
#
#                                                cv_4  cv_0  cv_1  cv_2  cv_3  \
# species              estimator    x_var
# acantharchus pomotis linear-svc   AgKffactCat   NaN   NaN   NaN   NaN   NaN
#                                   AgKffactWs    NaN   NaN   NaN   NaN   NaN
#                                   Al2O3Cat      NaN   NaN   NaN   NaN   NaN
#                                   Al2O3Ws       NaN   NaN   NaN   NaN   NaN
#                                   BFICat        NaN   NaN   NaN   NaN   NaN
# ...                                             ...   ...   ...   ...   ...
# zzzno fish           logistic-reg WetIndexCat   NaN   NaN   NaN   NaN   NaN
#                                   WetIndexWs    NaN   NaN   NaN   NaN   NaN
#                                   WtDepCat      NaN   NaN   NaN   NaN   NaN
#                                   WtDepWs       NaN   NaN   NaN   NaN   NaN
#                                   prG_BMMI      NaN   NaN   NaN   NaN   NaN
#
#                                                cv_4
# species              estimator    x_var
# acantharchus pomotis linear-svc   AgKffactCat   NaN
#                                   AgKffactWs    NaN
#                                   Al2O3Cat      NaN
#                                   Al2O3Ws       NaN
#                                   BFICat        NaN
# ...                                             ...
# zzzno fish           logistic-reg WetIndexCat   NaN
#                                   WetIndexWs    NaN
#                                   WtDepCat      NaN
#                                   WtDepWs       NaN
#                                   prG_BMMI      NaN
#
# [240840 rows x 4460 columns]

# %%
assert False,'halt'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-69815fc482af> in <module>
# ----> 1 assert False,'halt'
#
# AssertionError: halt

# %%
from pi_db_tool import DBTool

# %%
import numpy as np

# %%
from datagen import dataGenerator

# %%
dbt=DBTool()

# %%
hash_id_list = list(dbt.resultsDBdict().keys())

# %%
a_model_dict=dbt.resultsDBdict()[hash_id_list[1]]

# %%
#data=dataGenerator(a_model_dict['data_gen'])

# %%
#del a_model_dict['model']['estimator'][0].est

# %%
coef_df=pr.get_cv_coef_df(a_model_dict)

# %%
mean_coef=coef_df.mean(axis=1)

# %%
sorted=np.argsort(mean_coef.abs(),axis=0)

# %%
sorted_mean_coef=mean_coef.iloc[sorted[::-1]]

# %%
sorted_mean_coef.head(30)

# %%
pr.fit_est_list

# %%
est0=pr.fit_est_list[0]

# %%
est0.predict()

# %%
est0
