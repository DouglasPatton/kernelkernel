# %%
from pi_results import PiResults

# %%
pr=PiResults()

# %%
spec_est_coef_df=pr.build_spec_est_coef_df(rebuild=1)

# %%
spec_est_coef_df.shape
# Out:
# (52, 2700)

# %%
import numpy as np
meancoef=pr.coef_df.mean(axis=1,level='x_var')
meancoef
#order=np.argsort(meancoef.abs().T)
#meancoef.iloc[(slice(None)),order[::-1]]
# Out:
# x_var                                          AgKffactCat  AgKffactWs  \
# species                          estimator
# etheostoma mariae                logistic-reg     0.000000    0.000000
#                                  linear-svc      -0.004066   -0.017569
# percina rex                      logistic-reg    -0.011697   -0.018535
# moxostoma ariommum               logistic-reg    -0.000026   -0.033443
# etheostoma longimanum            logistic-reg    -0.008376    0.014039
# percina rex                      linear-svc      -0.013211   -0.043897
# moxostoma ariommum               linear-svc       0.002088   -0.011793
# etheostoma longimanum            linear-svc      -0.015468    0.030418
# hypentelium roanokense           logistic-reg    -0.261048    0.006036
# etheostoma collis                logistic-reg    -0.001191    0.365588
# hypentelium roanokense           linear-svc      -0.313045    0.068948
# etheostoma kanawhae              logistic-reg    -0.030509   -0.011703
# fundulus rathbuni                logistic-reg     0.120399   -0.036324
# etheostoma collis                linear-svc      -0.129039    0.085564
# etheostoma kanawhae              linear-svc      -0.069604   -0.049583
# oncorhynchus clarkii pleuriticus logistic-reg     0.046629   -0.048807
# catostomus discobolus            logistic-reg    -0.078395    0.270756
# oncorhynchus clarkii pleuriticus linear-svc       0.020294   -0.054929
# catostomus discobolus            linear-svc      -0.054520    0.229463
# rhinichthys osculus              logistic-reg     0.129958   -0.014386
# catostomus platyrhynchus         logistic-reg     0.101924   -0.151126
# zzzno fish                       logistic-reg    -0.060825   -0.087394
# rhinichthys osculus              linear-svc       0.190971   -0.088058
# oncorhynchus clarkii             logistic-reg     0.000000    0.000000
# zzzno fish                       linear-svc      -0.472655   -0.560428
# catostomus platyrhynchus         linear-svc       0.287564   -0.488696
# catostomus clarkii               logistic-reg    -0.023095    0.002177
#                                  linear-svc      -0.025627    0.001583
# oncorhynchus clarkii             linear-svc      -0.432342    0.451370
# cyprinella lutrensis             logistic-reg     0.030783   -0.102108
# lepomis microlophus              logistic-reg     0.067163   -0.038804
# cyprinella lutrensis             linear-svc      -0.026398   -0.424627
# salvelinus fontinalis            logistic-reg    -0.145077    0.011788
# salmo trutta                     logistic-reg    -0.069970    0.239949
# ameiurus melas                   logistic-reg    -0.072222   -0.011198
# pimephales promelas              logistic-reg     0.069823   -0.126185
# lepomis cyanellus                logistic-reg     0.027449   -0.268412
# pylodictis olivaris              logistic-reg    -0.016586   -0.196356
# lepomis microlophus              linear-svc      -0.010286   -0.022473
# salvelinus fontinalis            linear-svc      -0.080631   -0.498032
# ameiurus melas                   linear-svc       0.030125    0.203455
# pylodictis olivaris              linear-svc      -0.090518   -0.776168
# pimephales promelas              linear-svc       0.383256   -0.480139
# micropterus salmoides            logistic-reg    -0.023500   -0.038777
# salmo trutta                     linear-svc      -0.260883    0.929604
# lepomis cyanellus                linear-svc       0.041262   -0.464351
# micropterus dolomieu             logistic-reg    -0.215145   -0.299883
# lepomis macrochirus              logistic-reg     0.019266   -0.003122
# micropterus dolomieu             linear-svc      -0.253181   -0.123687
# micropterus salmoides            linear-svc      -0.040628   -0.032239
# lepomis macrochirus              linear-svc       0.072129   -0.110629
# ictalurus punctatus              logistic-reg     0.216634   -0.182535
#
# x_var                                          Al2O3Cat   Al2O3Ws    BFICat  \
# species                          estimator
# etheostoma mariae                logistic-reg -0.037955  0.000000  0.000000
#                                  linear-svc   -0.047240 -0.004621  0.009129
# percina rex                      logistic-reg -0.039041 -0.055272 -0.000150
# moxostoma ariommum               logistic-reg -0.159323 -0.004993  0.085332
# etheostoma longimanum            logistic-reg  0.020909 -0.087487  0.096074
# percina rex                      linear-svc   -0.081865 -0.058023 -0.028271
# moxostoma ariommum               linear-svc   -0.134602 -0.017728  0.019174
# etheostoma longimanum            linear-svc    0.022459 -0.110707  0.146558
# hypentelium roanokense           logistic-reg -0.003782  0.167929  0.135494
# etheostoma collis                logistic-reg -0.286607 -0.087165 -0.326799
# hypentelium roanokense           linear-svc   -0.062631  0.052022  0.092039
# etheostoma kanawhae              logistic-reg -0.098585  0.123456 -0.059323
# fundulus rathbuni                logistic-reg  0.031319  0.236962 -0.257511
# etheostoma collis                linear-svc   -0.172230 -0.171730 -0.216217
# etheostoma kanawhae              linear-svc   -0.187118  0.082305 -0.099993
# oncorhynchus clarkii pleuriticus logistic-reg  0.192903  0.077096  0.108504
# catostomus discobolus            logistic-reg  0.424202 -0.171728  0.160435
# oncorhynchus clarkii pleuriticus linear-svc    0.052573  0.090529  0.054011
# catostomus discobolus            linear-svc    0.353415 -0.125929  0.163289
# rhinichthys osculus              logistic-reg -0.197960  0.122971  0.196661
# catostomus platyrhynchus         logistic-reg -0.089961  0.229970  0.380645
# zzzno fish                       logistic-reg -0.046605 -0.115902  0.028026
# rhinichthys osculus              linear-svc   -0.209641  0.154910  0.206888
# oncorhynchus clarkii             logistic-reg  0.043089  0.075803  0.015667
# zzzno fish                       linear-svc    0.186775 -0.641713 -0.159715
# catostomus platyrhynchus         linear-svc    0.239801 -0.053296  0.533987
# catostomus clarkii               logistic-reg  0.031832 -0.030238 -0.018055
#                                  linear-svc    0.026867 -0.047761  0.010538
# oncorhynchus clarkii             linear-svc    0.046408  0.377891  0.322031
# cyprinella lutrensis             logistic-reg -0.039677  0.202949 -0.402651
# lepomis microlophus              logistic-reg -0.148239 -0.376425  0.102809
# cyprinella lutrensis             linear-svc   -0.056310  0.112649 -0.120367
# salvelinus fontinalis            logistic-reg  0.007591 -0.008562  0.236783
# salmo trutta                     logistic-reg  0.163246 -0.234328  0.243644
# ameiurus melas                   logistic-reg  0.092117 -0.008231  0.145311
# pimephales promelas              logistic-reg  0.059822  0.062766 -0.009982
# lepomis cyanellus                logistic-reg -0.132225 -0.021530 -0.212253
# pylodictis olivaris              logistic-reg -0.282713  0.045716  0.138678
# lepomis microlophus              linear-svc    0.083201 -0.222178  0.011427
# salvelinus fontinalis            linear-svc    0.013437 -0.016358  0.229466
# ameiurus melas                   linear-svc    0.032134 -0.015080  0.148499
# pylodictis olivaris              linear-svc   -0.211048  0.126551 -0.106695
# pimephales promelas              linear-svc   -0.003704  0.033881  0.024304
# micropterus salmoides            logistic-reg  0.033800 -0.082363  0.067084
# salmo trutta                     linear-svc    0.121849 -0.185567  0.095643
# lepomis cyanellus                linear-svc   -0.063872  0.033923 -0.047519
# micropterus dolomieu             logistic-reg  0.018090  0.062350 -0.131192
# lepomis macrochirus              logistic-reg -0.045963  0.003634 -0.005542
# micropterus dolomieu             linear-svc    0.008417 -0.012953 -0.057608
# micropterus salmoides            linear-svc    0.035252 -0.081291  0.044562
# lepomis macrochirus              linear-svc   -0.097962  0.026442  0.016308
# ictalurus punctatus              logistic-reg -0.223735  0.017857 -0.050667
#
# x_var                                             BFIWs   CBNFCat    CBNFWs  \
# species                          estimator
# etheostoma mariae                logistic-reg  0.000000  0.000000  0.000000
#                                  linear-svc   -0.011759 -0.008955 -0.008456
# percina rex                      logistic-reg -0.002431  0.040569 -0.015624
# moxostoma ariommum               logistic-reg -0.002841  0.022809 -0.001821
# etheostoma longimanum            logistic-reg  0.037845 -0.079439 -0.064136
# percina rex                      linear-svc    0.000137  0.083968 -0.035398
# moxostoma ariommum               linear-svc   -0.015059  0.052632  0.026638
# etheostoma longimanum            linear-svc    0.050214 -0.064077 -0.005779
# hypentelium roanokense           logistic-reg  0.089712 -0.179228 -0.242306
# etheostoma collis                logistic-reg -0.520048  0.018245  0.082732
# hypentelium roanokense           linear-svc    0.074641 -0.151568 -0.135802
# etheostoma kanawhae              logistic-reg  0.099207 -0.064638 -0.017284
# fundulus rathbuni                logistic-reg -0.064572 -0.107594 -0.384616
# etheostoma collis                linear-svc   -0.077600 -0.074008 -0.022961
# etheostoma kanawhae              linear-svc    0.140887 -0.042845 -0.048828
# oncorhynchus clarkii pleuriticus logistic-reg  0.058904 -0.107032 -0.114638
# catostomus discobolus            logistic-reg -0.032235  0.180821  0.165664
# oncorhynchus clarkii pleuriticus linear-svc    0.106183 -0.126489 -0.146522
# catostomus discobolus            linear-svc   -0.097548  0.162690  0.021338
# rhinichthys osculus              logistic-reg -0.084536 -0.013881 -0.031729
# catostomus platyrhynchus         logistic-reg -0.382736  0.051994  0.514881
# zzzno fish                       logistic-reg -0.043615  0.218754  0.080635
# rhinichthys osculus              linear-svc   -0.172195 -0.018685  0.000763
# oncorhynchus clarkii             logistic-reg  0.000000  0.000000  0.000000
# zzzno fish                       linear-svc    0.171031  0.040120  0.146950
# catostomus platyrhynchus         linear-svc   -0.486980 -0.012212  0.376896
# catostomus clarkii               logistic-reg -0.055951 -0.006369  0.007948
#                                  linear-svc   -0.022978 -0.005224  0.001642
# oncorhynchus clarkii             linear-svc   -0.480491  0.076931 -0.285910
# cyprinella lutrensis             logistic-reg  0.141402 -0.250405 -0.014287
# lepomis microlophus              logistic-reg  0.248921 -0.004473  0.173090
# cyprinella lutrensis             linear-svc    0.012179 -0.120866  0.003589
# salvelinus fontinalis            logistic-reg -0.139757  0.154448  0.007569
# salmo trutta                     logistic-reg  0.182048  0.002252 -0.173001
# ameiurus melas                   logistic-reg -0.287275  0.152431 -0.248562
# pimephales promelas              logistic-reg -0.267499  0.051520 -0.027402
# lepomis cyanellus                logistic-reg -0.213370 -0.058026  0.188383
# pylodictis olivaris              logistic-reg  0.597369  0.029136  0.267817
# lepomis microlophus              linear-svc    0.062692 -0.000495 -0.003291
# salvelinus fontinalis            linear-svc   -0.167103  0.064292  0.011564
# ameiurus melas                   linear-svc   -0.204602  0.019724 -0.060138
# pylodictis olivaris              linear-svc    0.345948 -0.000894  0.030144
# pimephales promelas              linear-svc   -0.112052  0.005244 -0.064186
# micropterus salmoides            logistic-reg  0.012322 -0.041103  0.026142
# salmo trutta                     linear-svc    0.064980  0.015404 -0.103458
# lepomis cyanellus                linear-svc   -0.117263 -0.077139  0.129876
# micropterus dolomieu             logistic-reg  0.624614 -0.131326  0.036154
# lepomis macrochirus              logistic-reg  0.012629 -0.026703  0.021469
# micropterus dolomieu             linear-svc    0.267078 -0.069018  0.031656
# micropterus salmoides            linear-svc    0.014076 -0.048074  0.037242
# lepomis macrochirus              linear-svc    0.003952 -0.069772  0.070646
# ictalurus punctatus              logistic-reg  0.786136 -0.203000  0.137566
#
# x_var                                          CCHEM_v2_1  CCONN_v2_1  ...  \
# species                          estimator                             ...
# etheostoma mariae                logistic-reg    0.000152    0.000000  ...
#                                  linear-svc      0.030201    0.021829  ...
# percina rex                      logistic-reg   -0.002740   -0.015022  ...
# moxostoma ariommum               logistic-reg   -0.072430    0.039294  ...
# etheostoma longimanum            logistic-reg    0.026400   -0.081407  ...
# percina rex                      linear-svc     -0.012282    0.024477  ...
# moxostoma ariommum               linear-svc     -0.075586    0.050950  ...
# etheostoma longimanum            linear-svc      0.028648   -0.006629  ...
# hypentelium roanokense           logistic-reg   -0.188477   -0.009154  ...
# etheostoma collis                logistic-reg    0.405649    0.160753  ...
# hypentelium roanokense           linear-svc     -0.092963    0.027037  ...
# etheostoma kanawhae              logistic-reg   -0.141433    0.018246  ...
# fundulus rathbuni                logistic-reg    0.183216   -0.206747  ...
# etheostoma collis                linear-svc      0.445943    0.095375  ...
# etheostoma kanawhae              linear-svc     -0.110244    0.012280  ...
# oncorhynchus clarkii pleuriticus logistic-reg   -0.180534    0.127876  ...
# catostomus discobolus            logistic-reg   -0.054284    0.021362  ...
# oncorhynchus clarkii pleuriticus linear-svc     -0.126437    0.127371  ...
# catostomus discobolus            linear-svc      0.000055   -0.028773  ...
# rhinichthys osculus              logistic-reg   -0.054000    0.000131  ...
# catostomus platyrhynchus         logistic-reg    0.148933   -0.075979  ...
# zzzno fish                       logistic-reg   -0.019242   -0.009650  ...
# rhinichthys osculus              linear-svc     -0.075750   -0.107484  ...
# oncorhynchus clarkii             logistic-reg    0.000000    0.000000  ...
# zzzno fish                       linear-svc     -0.018499   -0.482755  ...
# catostomus platyrhynchus         linear-svc      0.220093   -0.794462  ...
# catostomus clarkii               logistic-reg    0.038114   -0.013341  ...
#                                  linear-svc      0.053298   -0.000599  ...
# oncorhynchus clarkii             linear-svc      0.564893    0.678388  ...
# cyprinella lutrensis             logistic-reg    0.081081    0.022442  ...
# lepomis microlophus              logistic-reg    0.036173    0.003802  ...
# cyprinella lutrensis             linear-svc      0.091437    0.133678  ...
# salvelinus fontinalis            logistic-reg   -0.087872   -0.017618  ...
# salmo trutta                     logistic-reg   -0.020955   -0.056149  ...
# ameiurus melas                   logistic-reg   -0.049320   -0.000311  ...
# pimephales promelas              logistic-reg    0.007719    0.097960  ...
# lepomis cyanellus                logistic-reg    0.062535    0.002796  ...
# pylodictis olivaris              logistic-reg   -0.072224    0.055178  ...
# lepomis microlophus              linear-svc      0.046895    0.070571  ...
# salvelinus fontinalis            linear-svc     -0.169197    0.018424  ...
# ameiurus melas                   linear-svc     -0.031364   -0.162824  ...
# pylodictis olivaris              linear-svc     -0.141214   -0.249452  ...
# pimephales promelas              linear-svc      0.062424   -0.128593  ...
# micropterus salmoides            logistic-reg   -0.007495   -0.059673  ...
# salmo trutta                     linear-svc      0.003238   -0.339680  ...
# lepomis cyanellus                linear-svc      0.081630   -0.239256  ...
# micropterus dolomieu             logistic-reg    0.245546   -0.013840  ...
# lepomis macrochirus              logistic-reg   -0.015171   -0.002997  ...
# micropterus dolomieu             linear-svc      0.287248    0.107955  ...
# micropterus salmoides            linear-svc      0.045747    0.038207  ...
# lepomis macrochirus              linear-svc      0.009585    0.037287  ...
# ictalurus punctatus              logistic-reg   -0.199772    0.018894  ...
#
# x_var                                          WCONN_v2_1  WHABT_v2_1  \
# species                          estimator
# etheostoma mariae                logistic-reg    0.002046    0.000000
#                                  linear-svc      0.002147    0.003172
# percina rex                      logistic-reg    0.032734    0.047882
# moxostoma ariommum               logistic-reg    0.001349    0.101872
# etheostoma longimanum            logistic-reg    0.005993    0.010363
# percina rex                      linear-svc      0.015740    0.040655
# moxostoma ariommum               linear-svc     -0.001521    0.033368
# etheostoma longimanum            linear-svc     -0.013381    0.011255
# hypentelium roanokense           logistic-reg    0.231335   -0.005490
# etheostoma collis                logistic-reg    0.273833   -0.004881
# hypentelium roanokense           linear-svc      0.159868    0.002409
# etheostoma kanawhae              logistic-reg    0.022315    0.042859
# fundulus rathbuni                logistic-reg   -0.062416   -0.004079
# etheostoma collis                linear-svc      0.193993    0.012452
# etheostoma kanawhae              linear-svc      0.018821    0.080514
# oncorhynchus clarkii pleuriticus logistic-reg    0.098609   -0.015281
# catostomus discobolus            logistic-reg    0.113846   -0.030130
# oncorhynchus clarkii pleuriticus linear-svc      0.114721   -0.059308
# catostomus discobolus            linear-svc      0.068864   -0.007698
# rhinichthys osculus              logistic-reg    0.001240   -0.003235
# catostomus platyrhynchus         logistic-reg   -0.088916    0.069022
# zzzno fish                       logistic-reg   -0.018675    0.045944
# rhinichthys osculus              linear-svc     -0.133055    0.041475
# oncorhynchus clarkii             logistic-reg    0.000000    0.000000
# zzzno fish                       linear-svc     -0.165310   -0.048342
# catostomus platyrhynchus         linear-svc     -0.042044    0.212216
# catostomus clarkii               logistic-reg    0.006415    0.006475
#                                  linear-svc      0.023479    0.015290
# oncorhynchus clarkii             linear-svc      1.078916    0.271355
# cyprinella lutrensis             logistic-reg    0.039803    0.009383
# lepomis microlophus              logistic-reg    0.039414    0.104156
# cyprinella lutrensis             linear-svc      0.055096    0.236682
# salvelinus fontinalis            logistic-reg   -0.016735   -0.026206
# salmo trutta                     logistic-reg    0.118514   -0.000176
# ameiurus melas                   logistic-reg   -0.100979   -0.027580
# pimephales promelas              logistic-reg    0.082134   -0.025929
# lepomis cyanellus                logistic-reg   -0.083770   -0.020934
# pylodictis olivaris              logistic-reg   -0.151503    0.066732
# lepomis microlophus              linear-svc      0.575496    0.701603
# salvelinus fontinalis            linear-svc      0.132022    0.432645
# ameiurus melas                   linear-svc      0.106513   -0.822102
# pylodictis olivaris              linear-svc      0.044677   -0.123702
# pimephales promelas              linear-svc      0.482955    1.542468
# micropterus salmoides            logistic-reg   -0.008747   -0.011462
# salmo trutta                     linear-svc      0.288067    2.708503
# lepomis cyanellus                linear-svc      0.163525   -1.414649
# micropterus dolomieu             logistic-reg    0.020219   -0.088797
# lepomis macrochirus              logistic-reg   -0.004777   -0.000881
# micropterus dolomieu             linear-svc      0.131294    0.846734
# micropterus salmoides            linear-svc     -0.093221   -0.191554
# lepomis macrochirus              linear-svc      0.142070   -0.160334
# ictalurus punctatus              logistic-reg   -0.248683    0.020164
#
# x_var                                          WHYD_v2_1  WSED_v2_1  \
# species                          estimator
# etheostoma mariae                logistic-reg   0.006933   0.016356
#                                  linear-svc     0.009969   0.009364
# percina rex                      logistic-reg   0.031429   0.061058
# moxostoma ariommum               logistic-reg   0.073630   0.096644
# etheostoma longimanum            logistic-reg   0.001504   0.032071
# percina rex                      linear-svc     0.040264   0.056716
# moxostoma ariommum               linear-svc     0.034454   0.020648
# etheostoma longimanum            linear-svc    -0.005557   0.009887
# hypentelium roanokense           logistic-reg   0.000589  -0.060667
# etheostoma collis                logistic-reg  -0.126060   0.122767
# hypentelium roanokense           linear-svc    -0.034398  -0.152694
# etheostoma kanawhae              logistic-reg   0.010091   0.019620
# fundulus rathbuni                logistic-reg   0.098088   0.014304
# etheostoma collis                linear-svc    -0.072941   0.184468
# etheostoma kanawhae              linear-svc     0.035132   0.040018
# oncorhynchus clarkii pleuriticus logistic-reg   0.109540   0.197754
# catostomus discobolus            logistic-reg  -0.051385  -0.168116
# oncorhynchus clarkii pleuriticus linear-svc     0.057206  -0.026789
# catostomus discobolus            linear-svc    -0.033776  -0.164053
# rhinichthys osculus              logistic-reg  -0.008066   0.041723
# catostomus platyrhynchus         logistic-reg   0.036089   0.030397
# zzzno fish                       logistic-reg  -0.042541   0.114953
# rhinichthys osculus              linear-svc     0.152987   0.202213
# oncorhynchus clarkii             logistic-reg   0.000000   0.000000
# zzzno fish                       linear-svc    -0.151236   0.048332
# catostomus platyrhynchus         linear-svc    -0.618532  -0.913854
# catostomus clarkii               logistic-reg   0.004600   0.020108
#                                  linear-svc     0.006801   0.021055
# oncorhynchus clarkii             linear-svc     0.409993   0.773656
# cyprinella lutrensis             logistic-reg   0.107545   0.005903
# lepomis microlophus              logistic-reg   0.044524   0.145021
# cyprinella lutrensis             linear-svc     0.210806  -0.416932
# salvelinus fontinalis            logistic-reg  -0.004426  -0.145987
# salmo trutta                     logistic-reg  -0.015012  -0.117822
# ameiurus melas                   logistic-reg  -0.044189   0.043607
# pimephales promelas              logistic-reg  -0.015119   0.074395
# lepomis cyanellus                logistic-reg   0.009768   0.198810
# pylodictis olivaris              logistic-reg   0.091637   0.011009
# lepomis microlophus              linear-svc    -0.371732   0.115849
# salvelinus fontinalis            linear-svc     0.099443  -0.635498
# ameiurus melas                   linear-svc     0.466240   0.388227
# pylodictis olivaris              linear-svc     0.094395  -0.839461
# pimephales promelas              linear-svc    -0.718798  -0.376425
# micropterus salmoides            logistic-reg  -0.002802   0.043718
# salmo trutta                     linear-svc    -1.313235   0.629910
# lepomis cyanellus                linear-svc     0.609465  -0.153592
# micropterus dolomieu             logistic-reg  -0.135008   0.202847
# lepomis macrochirus              logistic-reg   0.011716  -0.002620
# micropterus dolomieu             linear-svc    -0.454428   0.271074
# micropterus salmoides            linear-svc     0.007229   0.010973
# lepomis macrochirus              linear-svc     0.046800  -0.104916
# ictalurus punctatus              logistic-reg   0.066534   0.014101
#
# x_var                                          WTEMP_v2_1  WetIndexCat  \
# species                          estimator
# etheostoma mariae                logistic-reg    0.044199     0.000000
#                                  linear-svc      0.012964     0.031952
# percina rex                      logistic-reg    0.058006     0.043846
# moxostoma ariommum               logistic-reg    0.053324     0.002524
# etheostoma longimanum            logistic-reg    0.004879    -0.076470
# percina rex                      linear-svc      0.043475     0.027531
# moxostoma ariommum               linear-svc      0.019237     0.000529
# etheostoma longimanum            linear-svc     -0.011278    -0.139375
# hypentelium roanokense           logistic-reg    0.088067    -0.074326
# etheostoma collis                logistic-reg   -0.036529     0.405901
# hypentelium roanokense           linear-svc      0.025159    -0.258594
# etheostoma kanawhae              logistic-reg    0.019575     0.108473
# fundulus rathbuni                logistic-reg   -0.054038    -0.283817
# etheostoma collis                linear-svc     -0.035131     0.206269
# etheostoma kanawhae              linear-svc      0.054593     0.147930
# oncorhynchus clarkii pleuriticus logistic-reg    0.052012    -0.047804
# catostomus discobolus            logistic-reg   -0.044492    -0.446849
# oncorhynchus clarkii pleuriticus linear-svc      0.016285     0.070442
# catostomus discobolus            linear-svc     -0.043610    -0.227958
# rhinichthys osculus              logistic-reg   -0.024141     0.061832
# catostomus platyrhynchus         logistic-reg    0.135505     0.095533
# zzzno fish                       logistic-reg   -0.084743     0.317802
# rhinichthys osculus              linear-svc     -0.108166     0.073640
# oncorhynchus clarkii             logistic-reg    0.000000    -0.015186
# zzzno fish                       linear-svc     -0.221952     0.483158
# catostomus platyrhynchus         linear-svc      0.839434     0.015451
# catostomus clarkii               logistic-reg    0.008520    -0.053285
#                                  linear-svc      0.014906    -0.022082
# oncorhynchus clarkii             linear-svc      0.466070    -0.039461
# cyprinella lutrensis             logistic-reg    0.042775     0.020430
# lepomis microlophus              logistic-reg    0.066944     0.202529
# cyprinella lutrensis             linear-svc     -0.340289    -0.008352
# salvelinus fontinalis            logistic-reg   -0.141130     0.030892
# salmo trutta                     logistic-reg    0.062420     0.032306
# ameiurus melas                   logistic-reg   -0.049940    -0.032252
# pimephales promelas              logistic-reg    0.093229     0.104830
# lepomis cyanellus                logistic-reg    0.001929     0.094400
# pylodictis olivaris              logistic-reg    0.066304     0.005838
# lepomis microlophus              linear-svc      0.058573     0.085395
# salvelinus fontinalis            linear-svc     -1.452642     0.015512
# ameiurus melas                   linear-svc     -0.621397    -0.029612
# pylodictis olivaris              linear-svc     -0.203557    -0.015357
# pimephales promelas              linear-svc      0.159322     0.044470
# micropterus salmoides            logistic-reg    0.021574     0.083494
# salmo trutta                     linear-svc      0.062586     0.011622
# lepomis cyanellus                linear-svc      0.095000     0.038134
# micropterus dolomieu             logistic-reg   -0.135856    -0.083465
# lepomis macrochirus              logistic-reg    0.014304     0.040747
# micropterus dolomieu             linear-svc     -0.263072    -0.021219
# micropterus salmoides            linear-svc      0.331513     0.034157
# lepomis macrochirus              linear-svc     -0.093845     0.045076
# ictalurus punctatus              logistic-reg    0.010969    -0.023488
#
# x_var                                          WetIndexWs  WtDepCat   WtDepWs  \
# species                          estimator
# etheostoma mariae                logistic-reg    0.000000  0.000000  0.000000
#                                  linear-svc     -0.013743 -0.038190  0.006929
# percina rex                      logistic-reg   -0.009259 -0.012038  0.019325
# moxostoma ariommum               logistic-reg   -0.078718 -0.088940  0.028450
# etheostoma longimanum            logistic-reg   -0.016866  0.027475 -0.005754
# percina rex                      linear-svc     -0.023318 -0.037778  0.018419
# moxostoma ariommum               linear-svc     -0.046439 -0.075355 -0.005486
# etheostoma longimanum            linear-svc     -0.066344  0.053139 -0.034939
# hypentelium roanokense           logistic-reg   -0.003065  0.045346  0.062410
# etheostoma collis                logistic-reg    0.442856 -0.174109 -0.226075
# hypentelium roanokense           linear-svc      0.074376  0.103387 -0.034671
# etheostoma kanawhae              logistic-reg    0.124181  0.061557  0.014210
# fundulus rathbuni                logistic-reg   -0.171545  0.236813  0.188890
# etheostoma collis                linear-svc      0.362711 -0.174233 -0.173570
# etheostoma kanawhae              linear-svc      0.090813  0.031678 -0.056350
# oncorhynchus clarkii pleuriticus logistic-reg   -0.256234 -0.037642 -0.173233
# catostomus discobolus            logistic-reg    0.334995 -0.389822  0.613788
# oncorhynchus clarkii pleuriticus linear-svc     -0.194883  0.060377 -0.150162
# catostomus discobolus            linear-svc      0.194105 -0.179719  0.434183
# rhinichthys osculus              logistic-reg   -0.133364  0.083901 -0.169444
# catostomus platyrhynchus         logistic-reg   -0.435639  0.351433 -0.070169
# zzzno fish                       logistic-reg    0.646214  0.151860  0.245549
# rhinichthys osculus              linear-svc     -0.117641  0.036840 -0.046269
# oncorhynchus clarkii             logistic-reg   -0.287743  0.000000  0.000000
# zzzno fish                       linear-svc      0.813493 -0.353562  0.941650
# catostomus platyrhynchus         linear-svc     -0.280833  0.175168  0.081958
# catostomus clarkii               logistic-reg   -0.007769  0.078033  0.041918
#                                  linear-svc     -0.001425  0.073006  0.048538
# oncorhynchus clarkii             linear-svc     -0.206481  0.032439 -0.048159
# cyprinella lutrensis             logistic-reg   -0.158342 -0.007353 -0.226345
# lepomis microlophus              logistic-reg    0.056928 -0.120625 -0.197632
# cyprinella lutrensis             linear-svc     -0.050678  0.010291 -0.082858
# salvelinus fontinalis            logistic-reg   -0.048689  0.151540  0.070326
# salmo trutta                     logistic-reg   -0.033555  0.093566  0.308709
# ameiurus melas                   logistic-reg    0.228788 -0.052394  0.006420
# pimephales promelas              logistic-reg    0.145600 -0.111801  0.161386
# lepomis cyanellus                logistic-reg   -0.021189  0.017363 -0.197755
# pylodictis olivaris              logistic-reg   -0.005424 -0.148881 -0.018023
# lepomis microlophus              linear-svc      0.029465 -0.051514 -0.065083
# salvelinus fontinalis            linear-svc     -0.030334  0.063232  0.005946
# ameiurus melas                   linear-svc      0.076367 -0.014720  0.006836
# pylodictis olivaris              linear-svc     -0.039877 -0.055844  0.013031
# pimephales promelas              linear-svc      0.019887  0.003495  0.035544
# micropterus salmoides            logistic-reg    0.057598 -0.036456  0.010253
# salmo trutta                     linear-svc      0.010077  0.023237  0.153775
# lepomis cyanellus                linear-svc     -0.011867  0.015150 -0.081975
# micropterus dolomieu             logistic-reg   -0.235921  0.027426 -0.150460
# lepomis macrochirus              logistic-reg   -0.001792 -0.004310 -0.040375
# micropterus dolomieu             linear-svc     -0.109589  0.003832 -0.067796
# micropterus salmoides            linear-svc      0.052156 -0.016480  0.002869
# lepomis macrochirus              linear-svc      0.000370 -0.000145 -0.042658
# ictalurus punctatus              logistic-reg   -0.202434 -0.109575 -0.096699
#
# x_var                                          prG_BMMI
# species                          estimator
# etheostoma mariae                logistic-reg  0.042857
#                                  linear-svc    0.024805
# percina rex                      logistic-reg  0.139921
# moxostoma ariommum               logistic-reg  0.357351
# etheostoma longimanum            logistic-reg  0.274901
# percina rex                      linear-svc    0.126972
# moxostoma ariommum               linear-svc    0.118274
# etheostoma longimanum            linear-svc    0.136934
# hypentelium roanokense           logistic-reg  0.112579
# etheostoma collis                logistic-reg  0.035839
# hypentelium roanokense           linear-svc    0.115202
# etheostoma kanawhae              logistic-reg  0.806570
# fundulus rathbuni                logistic-reg -0.109812
# etheostoma collis                linear-svc   -0.002840
# etheostoma kanawhae              linear-svc    0.308850
# oncorhynchus clarkii pleuriticus logistic-reg  0.176176
# catostomus discobolus            logistic-reg  0.188485
# oncorhynchus clarkii pleuriticus linear-svc    0.085625
# catostomus discobolus            linear-svc    0.056240
# rhinichthys osculus              logistic-reg -0.131563
# catostomus platyrhynchus         logistic-reg -0.068664
# zzzno fish                       logistic-reg -0.915067
# rhinichthys osculus              linear-svc   -0.042464
# oncorhynchus clarkii             logistic-reg  0.002473
# zzzno fish                       linear-svc   -0.746892
# catostomus platyrhynchus         linear-svc   -0.076710
# catostomus clarkii               logistic-reg -0.010573
#                                  linear-svc   -0.078299
# oncorhynchus clarkii             linear-svc    0.091271
# cyprinella lutrensis             logistic-reg  0.233476
# lepomis microlophus              logistic-reg -0.102099
# cyprinella lutrensis             linear-svc    0.072375
# salvelinus fontinalis            logistic-reg -0.241491
# salmo trutta                     logistic-reg  0.255730
# ameiurus melas                   logistic-reg  0.081137
# pimephales promelas              logistic-reg  0.010627
# lepomis cyanellus                logistic-reg  0.017669
# pylodictis olivaris              logistic-reg  0.119528
# lepomis microlophus              linear-svc   -0.069685
# salvelinus fontinalis            linear-svc   -0.082336
# ameiurus melas                   linear-svc    0.044989
# pylodictis olivaris              linear-svc   -0.014936
# pimephales promelas              linear-svc   -0.001270
# micropterus salmoides            logistic-reg  0.024822
# salmo trutta                     linear-svc    0.104189
# lepomis cyanellus                linear-svc    0.011565
# micropterus dolomieu             logistic-reg  0.394216
# lepomis macrochirus              logistic-reg  0.016031
# micropterus dolomieu             linear-svc    0.151157
# micropterus salmoides            linear-svc    0.021236
# lepomis macrochirus              linear-svc    0.027092
# ictalurus punctatus              logistic-reg  0.180790
#
# [52 rows x 270 columns]

# %%
assert False,'halt'

# %%
from pi_results import PiResults

# %%
pr=PiResults()

# %%
from pi_db_tool import DBTool

# %%
import numpy as np

# %%
from datagen import dataGenerator

# %%
dbt=DBTool()

# %%
hash_id_list = list(dbt.resultsDBdict().keys())

# %%
a_model_dict=dbt.resultsDBdict()[hash_id_list[1]]

# %%
#data=dataGenerator(a_model_dict['data_gen'])

# %%
#del a_model_dict['model']['estimator'][0].est

# %%
coef_df=pr.get_cv_coef_df(a_model_dict)

# %%
coef_df

# %%
coef_df.mean(axis=1,level='x_var')

# %%
mean_coef=coef_df.mean(axis=1)

# %%
sorted=np.argsort(mean_coef.abs(),axis=0)

# %%
sorted_mean_coef=mean_coef.iloc[sorted[::-1]]

# %%
sorted_mean_coef.head(30)

# %%
pr.fit_est_list

# %%
est0=pr.fit_est_list[0]

# %%
est0.predict()

# %%
est0
