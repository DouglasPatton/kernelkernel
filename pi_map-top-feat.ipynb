# %%
from pi_map import Mapper

# %%
import pandas as pd
import numpy as np

# %%
mpr=Mapper()

# %%
mpr.plot_top_features(rebuild=0)

# %%
-
# Out:
#   File "<ipython-input-5-60215a10e730>", line 1
#     -
#      ^
# SyntaxError: invalid syntax

# %%
mpr.cvscor_norm_coef_df.index,mpr.abs_diffscor.index

# %%
cvscor_norm_coef_df_a,abs_diffscor_a=mpr.cvscor_norm_coef_df.align(
            mpr.abs_diffscor,axis=0,join='inner',broadcast_axis=0)#level=['species','estimator'])

# %%
mpr.abs_diffscor

# %%
mpr.cvscor_norm_coef_df

# %%
np.argsort(mpr.big_top_wtd_coef_df,axis=1).iloc[:,::-1]

# %%
mpr.big_top_sort_idx

# %%
assert False,'halt'

# %%
mpr=Mapper()

# %%
comid_cvscor_norm_coef_df=mpr.build_wt_comid_feature_importance(rebuild=0,fit_scorer='f1_micro')

# %%
build_wt_comid_feature_importance

# %%
mpr.norm_spec_est_fitscor_df.

# %%
coef_a,fitscor_a=mpr.coef_df.align(mpr.norm_spec_est_fitscor_df,axis=0,join='inner')
coef_aa,fitscor_aa=coef_a.align(fitscor_a,axis=1,level='cv_i')

# %%
coef_aa.multiply(fitscor_aa,axis=0).sum(axis=1,level='x_var')

# %%
for col in mpr.coef_df.columns:
    if col[1]=='cv_10':
        print(col)

# %%
mpr.pr.scor_est_spec_dict

# %%
coef=mpr.cvscor_norm_coef_df
coef.shape

# %%
mpr.cvscor_norm_coef_df_a

# %%
diffscor=mpr.abs_diffscor_a

# %%
diffscor.shape

# %%
c_a,d_a=coef.align(diffscor,axis=0)

# %%
c_a

# %%
diffscor*c_a

# %%
d_a

# %%
wts=mpr.abs_diffscor_normalized_weights
wts.to_numpy()

# %%
mpr.cvscor_norm_coef_df_a.multiply(wts,axis=0)

# %%
assert False,'halt'

# %%
mpr.spec_est_fitscor_df

# %%
norm_spec_est_fitscor_df=mpr.spec_est_fitscor_df.divide(mpr.spec_est_fitscor_df.sum(axis=1),axis=0).copy()
norm_spec_est_fitscor_df.shape

# %%
coef_df=mpr.coef_df.copy()

#coef_df.columns=coef_df.columns.swaplevel(0,1)
#coef_dfT=coef_df.T
#coef_dfT.index=coef_dfT.index.swaplevel(0,1)
#coef_dfT

# %%
coef_df

# %%
coef_df,norm_spec_est_fitscor_df=coef_df.align(
            norm_spec_est_fitscor_df,axis=0,join='inner')

# %%
idx=norm_spec_est_fitscor_df.columns
multi_col_tuplist=[(i,) for i in idx]
multi_cols=pd.MultiIndex.from_tuples(multi_col_tuplist,names=['cv_i'])
norm_spec_est_fitscor_df.columns=multi_cols

# %%
idx

# %%
#cvscor_wtd_coef_df=coef_df.multiply(norm_spec_est_fitscor_df,axis=0)

# %%
#coef_df.columns

# %%
coef_df.loc[slice(None),(slice(None),'cv_0')].head()

# %%
norm_spec_est_fitscor_df.loc[slice(None),('cv_0',)]

# %%
fitscore_wt_coef=coef_df.copy()
for cv_i in norm_spec_est_fitscor_df.columns: #iterating over cv_i's
    fitscore_wt_coef.loc[slice(None),(slice(None),cv_i)]=coef_df.loc[slice(None),(slice(None),cv_i)]*norm_spec_est_fitscor_df.loc[slice(None),cv_i].to_numpy()[:,None]

# %%
fitscore_wt_coef.sum(axis=1,level='x_var')

# %%
'''norm_spec_est_fitscor_dfT=norm_spec_est_fitscor_df.T
#norm_spec_est_fitscor_dfT.index=norm_spec_est_fitscor_dfT.index.swaplevel(0,1)
norm_spec_est_fitscor_dfT'''

# %%
coef_df.columns

# %%
fitscor_aT,coef_aT=norm_spec_est_fitscor_df.T.align(coef_df.T,axis=0,broadcast_axis=0)
#fitscor_a,coef_a=norm_spec_est_fitscor_df.align(coef_df,axis=1,broadcast_axis=1)
#mrg=norm_spec_est_fitscor_df.T.join(coef_df.T,on='cv_i',)

# %%
coef_a

# %%
fitscor_a.dropna(axis=1)

# %%
cvscor_norm_coef_df_nosum=coef_df.multiply(norm_spec_est_fitscor_df,axis=0)
#.sum(axis=1)

# %%
mpr.diff

# %%
mpr.y_a

# %%
mpr.yhat_a

# %%
#----------------------------
assert False,'old stuff below'

# %%
mpr=Mapper()

# %%
norm_scor_X_abs_diff_comid_wts_df=mpr.make_comid_weights(cv_mean=True)

# %%
norm_scor_X_abs_diff_comid_wts_df

# %%
mpr._scor

# %%
mpr.diff_a

# %%
mpr._scor_a

# %%
mpr.norm_divisor

# %%
mpr._scor_X_abs_diff_scor.shape

# %%
mpr._scor_X_abs_diff_scor.divide(mpr.norm_divisor)

# %%
mpr.norm_scor_X_abs_diff_comid_wts

# %%
mpr._scor_X_abs_diff_scor.head(20)

# %%
mpr.norm_scor_X_abs_diff_comid_wts.head(20)

# %%
mpr.make_comid_weights(rebuild=0,norm_index='HUC12')

# %%
mpr.norm_divisor.head(20)

# %%
mpr.mean_scor_X_mean_abs_diff_scor.sum(axis=0,level='HUC12').head(20)

# %%
mpr.norm_scor_X_abs_diff_comid_wts.head(20)

# %%
wtd_coef_df=mpr.build_wt_comid_feature_importance(rebuild=0)

# %%
wtd_coef_df.head(40)

# %%
mpr.comid_wts_h12_norm

# %%
mpr.combo2.shape

# %%
mpr.combo.shape

# %%
c=mpr.combo

# %%
c.iloc[:,:-1].mul(c.iloc[:,-1],axis=0)

# %%
c

# %%
#wtd_coef=mpr.coef_a.multiply(mpr.wts_a.loc[:,mpr.wts_a.columns[0]])
#mpr.wts_a.index[0],mpr.coef_a.index[0]

# %%
a=mpr.coef_a
b=mpr.wts_a

# %%
b.shape

# %%
a

# %%
a.mul(b,axis=0)

# %%
a.iloc[:,0]*b.iloc[:,0]

# %%
mpr.wts_a

# %%
type(mpr.wts_a_0)

# %%
assert False, ''

# %%
from pi_map import Mapper

# %%
mpr=Mapper()

# %%
comid_norm_wts=mpr.make_comid_weights(rebuild=0)

# %%
comid_norm_wts

# %%
one_comid=pd.DataFrame(comid_norm_wts).loc[(slice(None),slice(None),'6778513',slice(None)),:]
one_comid

# %% [markdown]
# print(one_comid.shape)
# one_comid.sum()

# %%
comid_norm_wts.memory_usage()

# %%
comid_norm_wts

# %%
comid_norm_wts.index.levels

# %%
mpr.diff_a.abs().mean(axis=1)

# %%
mpr.spec_est_scor_df_a

# %%
#mpr.draw_huc12_truefalse(rebuild=0)
