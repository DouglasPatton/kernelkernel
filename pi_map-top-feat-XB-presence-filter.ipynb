# %%
from pi_map import Mapper

# %%
import pandas as pd
import numpy as np

# %%
mpr=Mapper()

# %%
#mpr.plot_top_features(rebuild=0,filter_vars=True,spec_wt=None,fit_scorer='f1_micro',top_n=10,scale_by_X=False)

# %%
mpr.plot_top_features(presence_filter=True,rebuild=0,scale_by_X=False,filter_vars=True,spec_wt=None,fit_scorer='roc_auc_score_micro',top_n=10)
# Out:
# starting 14 procs
# multiprocessing complete
# concatenating dflist

# %%
mpr.wtd_coef_dfs
# Out:
# [var           AgKffactCat  AgKffactWs  Al2O3Cat   Al2O3Ws    BFICat     BFIWs  \
#  HUC12
#  010200050706    -0.089174   -0.001810 -0.013096 -0.029925 -0.015889  0.000671
#  010500020604    -0.041414    0.086742  0.008852  0.009407  0.035696 -0.007260
#  010300031602     0.061885    0.026564 -0.000773 -0.032027 -0.003874 -0.061018
#  010300032404    -0.006450    0.034273  0.015222 -0.000207  0.000488 -0.016816
#  010300030904     0.000627    0.063950  0.014282 -0.004472  0.008394 -0.051501
#  ...                   ...         ...       ...       ...       ...       ...
#  180901020207     0.000168   -0.005975  0.043201 -0.020167  0.014297  0.224375
#  180901020209     0.016525    0.040245  0.003239  0.005683  0.096198  0.157987
#  180703020502    -0.030297    0.008186  0.043357 -0.229870  0.059298 -0.449602
#  180701030107     0.002961    0.047446  0.001995 -0.021464  0.056378  0.024578
#  180703030402    -0.180353    0.180308  0.085770 -0.080724  0.412198 -0.041158
#
# ...

# %%
#mpr.plot_top_features(rebuild=0,scale_by_X=True,filter_vars=True,spec_wt='even',fit_scorer='f1_micro',top_n=10)

# %%
#coef_df_1=mpr.coef_df

# %%
#coef_df_2=mpr.coef_df

# %%
for df in mpr.wtd_coef_dfs:
    print(df.shape)
# Out:
# (11841, 238)
# (11766, 238)

# %%
cols
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-530388441d18> in <module>
# ----> 1 cols
#
# NameError: name 'cols' is not defined
