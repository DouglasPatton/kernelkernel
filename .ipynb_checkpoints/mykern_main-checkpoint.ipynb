# %% [markdown]
# ### kernel density estimation and kernel regression for prediction
# This notebook is my first attempt to write down the ddiff and dddiff models that I have been working on

# %% [markdown]
# mixed recursive/iterative approach (rather than vectorized approach that is harder to generalize
# - create separate submodules for KDE and KDreg
#     - develop a system for storing differenced but unweighted data and the appropriate mask to lessen memory usage.
#         -1's or 0's depending on i/j/k/l/.... values
#     - figure out the deepest level requested by the user and levels that are less deep are just slices of the deeper model.
#         -scout out the tree to build the differenced dataset.
#
#
#  plot and compare
# on synthetic data, 1, 2, 3+ mixed distributions
# 1d - Ndiff vs gaussian kernel vs kernel_tunneling
# 2d -
#
#
# multidimensional x problem
# e.g., parameter treatment
# "product kernel approach" vs l2 "el two" (radial basis?)distance

# %% [markdown]
# #### generate a simple linear dataset y=xb+e
# ##### store validation data from same dataset too

# %% [markdown]
# ### create modeldict
# - 'Ndiff_type': refers to the mathematical form of Ndiff
#   - 'product'-Ndiff1 multiplied by Ndiff2
#   - 'recursive'-Ndiff1's bw is Ndiff 2
# - max_bw_Ndiff: is the depth of Ndiffs applied in estimating the bandwidth.
# - 'normalize_Ndiffwtsum':
#   - 'across' means sum across own level of kernelized-Ndiffs and divide by that sum (CDF approach)
#   - 'own_n' means for (n+k)diff where n+K=max_bw_Ndiff
# - Ndiff_bw_kern:
#   - rbfkern means use the radial basis function kernel
#   - 'product' means use product kernel like as in liu and yang eq1.
# - 'regression_model':
#   - 'NW' means use nadaraya-watson kernel regression
#   - 'full_logit' means local logit with all variables entering linearly
#   - 'rbf_logit' means local logit with 1 parameters: scaled l2 norm centered on zero
#  (globally or by i?). Is this a new idea?
# - outer_x_bw_form: if x is separated into blocks of rvars that are combined within a block using rbf kernel,
#   - 'one_for_all' - use same hx bw for all blocks
#   - 'one_per_block' - each block or rvars gets an hx
# - ykern_grid
#   - if int, then create int evnely spaced values from -3 to 3 (standard normal middle ~99%)
#   - 'no' means use original data points (self is masked when predicting self)
# - xkern_grid
#   - much like ykern_grid, but used less frequently since x's are typically pre-specified
# - product_kern_norm: when multiplying kernels across random variables, this parameter determines if each random variable has its kernels normalized before the product or not
#   - 'self' means each random variable has its kernels divided by the sum of kernels across the nout axis (the number of possibile values y is averaged over, whose probabilities sum to 1)
#   - 'own_n' means same as self, but divided by count of non-masked items in second to last, nout lenght dimension
#   - 'none' means no normalization prior to taking products across rvar kernels
# - hyper_param_form_dict is a nested dictionary
#   - Ndiff_exponent is the exponent wrapped around typically a sum of kernels for each Ndiff level
# after level 1 (i.e., (i-j) or centered, obvious/conventional level.)
#   - x_bandscale is the parameter specific to each variable (each x in X) used for prediction (y)
#   - Ndiff_depth_bw is used as the kernel's bandwidth (h) at each level of Ndiff including at level 1
#   - outer_x_bw vanilla bandwidth for the rbf or product kernel
#   - outer_y_bw vanilla bandwidth for y

# %%
import kernelcompare as kc
#from importlib import reload
test=kc.KernelCompare()

# %%
#test.run_kernel_list()

# %%
Ndiff_type_variations=('modeldict:Ndiff_type',['recursive','product'])
max_bw_Ndiff_variations=('modeldict:max_bw_Ndiff',[2])
Ndiff_start_variations=('modeldict:Ndiff_start',[0])

product_kern_norm_variations=('modeldict:product_kern_norm',['self','own_n'])#include None too?
normalize_Ndiffwtsum_variations=('modeldict:normalize_Ndiffwtsum',['own_n','across'])
optdict_variation_list=[Ndiff_type_variations,max_bw_Ndiff_variations,Ndiff_start_variations]

# %%
#a reminder of the options:
#datagen_dict={'train_n':60,'n':200, 'param_count':param_count,'seed':1, 'ftype':'linear', 'evar':1}
#datagen_variation_list=[test.build_quadratic_datagen_dict_override()] 

train_n_variations=('train_n',[30])#so I don't crash my 10 year old laptop at home
#train_n_variations=('train_n:',[30,45,60])
ftype_variations=('ftype',['linear,quadratic'])
param_count_variations=('param_count',[1,2])
#need to add block capability to datagen so we can repeat optimization with new training data.

datagen_variation_list=[train_n_variations,ftype_variations,param_count_variations]

# %%
#print(os.getcwd())
try:test.open_condense_resave('model_save',verbose=0)
except:pass
try:test.open_condense_resave('condensed_model_save',verbose=0)
except:pass

# %%
from os import getcwd
thisdir=getcwd()
test.merge_and_condense_saved_models(merge_directory=thisdir,save_directory=thisdir,condense=1,verbose=0)

# %%
testrun=test.prep_model_list(optdict_variation_list=optdict_variation_list,datagen_variation_list=datagen_variation_list)
print(f'len(testrun){len(testrun)}')
print(f'testrun[0]{testrun[0]}')
print(f'testrun[-1]{testrun[-1]}')
# Out:
# len(datagen_dict_list):24
# len(testrun)576
# testrun[0]{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.01, 'fatol': 0.1, 'adaptive': True}, 'mse_threshold': 2, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.3, 0.3]), 'x_bandscale': array([1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.5])}, 'modeldict': {'Ndiff_type': 'recursive', 'param_count': 2, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}}, 'datagen_dict': {'train_n': 30, 'n': 200, 'param_count': 2, 'seed': 1, 'ftype': 'linear', 'evar': 1}}
# testrun[-1]{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.01, 'fatol': 0.1, 'adaptive': True}, 'mse_threshold': 2, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.3, 0.3]), 'x_bandscale': array([1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.5])}, 'modeldict': {'Ndiff_type': 'recursive', 'param_count': 2, 'Ndiff_start': 0, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}}, 'datagen_dict': {'train_n': 30, 'n': 200, 'param_count': 2, 'seed': 1, 'ftype': 'linear,quadratic', 'evar': 1}}

# %%
import traceback
runlist=[2,3]
#a_rundict=testrun[100]#this produced the Ndiff_exponent error for recursive Ndiff
for idx in range(575,0,-15):
    print(f'~~~~~~~run number:{idx}`~~~~~~~')
    a_rundict=testrun[idx]
    print(f'a_rundict{a_rundict}')
    optimizedict=a_rundict['optimizedict']
    datagen_dict=a_rundict['datagen_dict']

    try:
        test.do_monte_opt(optimizedict,datagen_dict,force_start_params=0)
        test.open_condense_resave('model_save',verbose=0)
        test.merge_and_condense_saved_models(merge_directory=None,save_directory=None,condense=None,verbose=None)
    except:
        print('traceback for run',idx)
        print(traceback.format_exc())
# Out:
# ~~~~~~~run number:0`~~~~~~~
# a_rundict{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.01, 'fatol': 0.1, 'adaptive': True}, 'mse_threshold': 2, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.3, 0.3]), 'x_bandscale': array([1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.5])}, 'modeldict': {'Ndiff_type': 'recursive', 'param_count': 2, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}}, 'datagen_dict': {'train_n': 30, 'n': 200, 'param_count': 2, 'seed': 1, 'ftype': 'linear', 'evar': 1}}
# in saved_filename:condensed_model_save, len(doubledict_list):19,len(saved_dict_list):19
#
# optimization dict with lowest mse:22.22276594243215, n:30was last saved20191117-181345
# best_dict:{'mse': 22.22276594243215, 'xdata': array([[-2.5563435 , -3.64593724],
#        [ 0.23081526, -6.10307739],
#        [ 1.98962353, -3.0224138 ],
#        [-0.86192181, -1.99874075],
#        [ 1.42421587, -5.62028142],
#        [-2.14483441, -2.26810871],
#        [ 0.76753888, -3.69978253],
#        [-1.84485642, -3.25571684],
#        [-1.41557251, -0.33436957],
#        [-3.70123835,  0.78944742],
#        [ 0.30318144, -0.49501132],
#        [ 0.3017119 , -2.86745572],
#        [-1.74578045, -3.37153887],
#        [-2.03577616, -0.43928907],
#        [-2.8833215 , -2.29350705],
#        [-2.8743454 , -3.19041128],
#        [-2.84249226, -1.5253292 ],
#        [-3.7346207 , -1.0311686 ],
#        [ 1.81960435, -0.01591168],
#        [-1.8836711 , -3.27525793],
#        [-2.99431659,  1.8849092 ],
#        [-1.39838449, -2.77399129],
#        [-1.11816903,  2.70051027],
#        [-1.2596821 , -0.26559378],
#        [-0.89965936, -2.20449969],
#        [-3.7850364 , -2.19868544],
#        [-1.91778847, -0.32675362],
#        [ 0.17796683,  0.36220416],
#        [-0.92882535,  0.27028233],
#        [-3.00879588,  1.00573631]]), 'ydata': array([-24.62107866, -32.92393465, -12.57809272, -11.62982371,
#        -31.01572349, -16.72848994, -18.21200149, -20.11983952,
#         -3.11909872,   1.39056333,   1.39654418, -14.661963  ,
#        -24.13429711,  -6.48485309, -18.30554416, -21.77531739,
#        -12.52668742, -13.75050084,   5.31497281, -19.8055284 ,
#          6.94601735, -18.19068636,  18.02134768,  -2.05951734,
#        -13.50547398, -18.4120183 ,  -3.77893391,   4.10001635,
#          2.9724996 ,   3.1325279 ]), 'params': {'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 4)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (4, 6)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (6, 7)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 8)}, 'y_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (8, 9)}, 'free_params': array([0.32268365, 0.30334207, 1.02683083, 1.00956598, 0.5027271 ,
#        0.53737641, 2.46187337, 2.18456474, 1.51873978]), 'fixed_params': array([], dtype=float64)}, 'modeldict': {'Ndiff_type': 'recursive', 'param_count': 2, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}, 'when_saved': '20191117-181345', 'datagen_dict': {'train_n': 30, 'n': 200, 'param_count': 2, 'seed': 1, 'ftype': 'linear', 'evar': 1}}
# overriding start parameters with saved parameters
# param_valdict:{'Ndiff_exponent': array([0.32268365, 0.30334207]), 'x_bandscale': array([1.02683083, 1.00956598]), 'outer_x_bw': array([2.46187337]), 'outer_y_bw': array([2.18456474]), 'Ndiff_depth_bw': array([0.5027271 , 0.53737641]), 'y_bandscale': array([1.51873978])}
# setup_fixed_or_free_paramdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 4)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (4, 6)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (6, 7)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 8)}, 'y_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (8, 9)}, 'free_params': 'outside', 'fixed_params': array([], dtype=float64)}
# modeldict:{'Ndiff_type': 'recursive', 'param_count': 2, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}
# saved to model_save at about 20191117-185033 with mse=22.222765942432762
# saved to model_save at about 20191117-185038 with mse=22.222765942432762
# save_interval changed to 9
# saved to model_save at about 20191117-185115 with mse=22.222765942432762
# saved to model_save at about 20191117-185203 with mse=22.222765942432762
# saved to model_save at about 20191117-185251 with mse=23.826905983093866
# saved to model_save at about 20191117-185338 with mse=22.222765942432762
# saved to model_save at about 20191117-185426 with mse=22.222765942432762
# saved to model_save at about 20191117-185514 with mse=22.222765942432762
# saved to model_save at about 20191117-185601 with mse=22.222765942432762
# saved to model_save at about 20191117-185649 with mse=22.222765942432762
# saved to model_save at about 20191117-185737 with mse=22.222765942432762
# saved to model_save at about 20191117-185824 with mse=22.222765942432762
# saved to model_save at about 20191117-185912 with mse=22.222765942432762
# saved to model_save at about 20191117-185959 with mse=22.22276594243245
# saved to model_save at about 20191117-190047 with mse=22.22276594243245
# saved to model_save at about 20191117-190135 with mse=22.222765942432762
# saved to model_save at about 20191117-190223 with mse=22.222765942432762
# saved to model_save at about 20191117-190310 with mse=22.222765942432762
# saved to model_save at about 20191117-190358 with mse=23.335904573356927
# saved to model_save at about 20191117-190445 with mse=23.423321321604455
# saved to model_save at about 20191117-190533 with mse=23.41933823480272
# saved to model_save at about 20191117-190620 with mse=22.222765942432762
# saved to model_save at about 20191117-190708 with mse=22.222765942432762
# saved to model_save at about 20191117-190756 with mse=22.222765942432762
# saved to model_save at about 20191117-190843 with mse=22.222765942432762
# saved to model_save at about 20191117-190931 with mse=22.222765942432762
# saved to model_save at about 20191117-191019 with mse=22.222765942432762
# saved to model_save at about 20191117-191106 with mse=22.222765942432762
# saved to model_save at about 20191117-191154 with mse=22.222765942432762
# saved to model_save at about 20191117-191241 with mse=22.222765942432762
# saved to model_save at about 20191117-191329 with mse=22.222765942432762
# saved to model_save at about 20191117-191416 with mse=22.222765942432762
# saved to model_save at about 20191117-191504 with mse=22.222765942432762
# saved to model_save at about 20191117-191551 with mse=22.222765942432762
# saved to model_save at about 20191117-191640 with mse=22.222765942432762
# saved to model_save at about 20191117-191728 with mse=22.222765942432762
# saved to model_save at about 20191117-191816 with mse=22.222765942432762
# saved to model_save at about 20191117-191903 with mse=22.222765942432762
# saved to model_save at about 20191117-191951 with mse=22.221820090467762
# saved to model_save at about 20191117-192038 with mse=22.221795036888853
# saved to model_save at about 20191117-192127 with mse=22.221137889919785
# saved to model_save at about 20191117-192214 with mse=22.221137889919785
# saved to model_save at about 20191117-192302 with mse=22.221181912743535
# saved to model_save at about 20191117-192350 with mse=22.220750808315064
# saved to model_save at about 20191117-192439 with mse=22.220750808315064
# saved to model_save at about 20191117-192527 with mse=22.220493680904177
# saved to model_save at about 20191117-192614 with mse=22.220493680904177
# saved to model_save at about 20191117-192701 with mse=22.22034398752091
# saved to model_save at about 20191117-192749 with mse=22.22034398752091
# saved to model_save at about 20191117-192836 with mse=22.22034398752091
# saved to model_save at about 20191117-192924 with mse=22.220242667156278
# saved to model_save at about 20191117-193012 with mse=22.220242667156278
# saved to model_save at about 20191117-193059 with mse=22.220185289789704
# saved to model_save at about 20191117-193147 with mse=22.220185289789704
# saved to model_save at about 20191117-193235 with mse=22.220185289789704
# saved to model_save at about 20191117-193322 with mse=22.220144994014202
# saved to model_save at about 20191117-193410 with mse=22.220144994014202
# saved to model_save at about 20191117-193458 with mse=22.220123290946496
# saved to model_save at about 20191117-193545 with mse=22.220123290946496
# saved to model_save at about 20191117-193633 with mse=22.220122701114065
# saved to model_save at about 20191117-193720 with mse=22.22010750022147
# saved to model_save at about 20191117-193808 with mse=22.22010750022147
# saved to model_save at about 20191117-193855 with mse=22.220098661532973
# saved to model_save at about 20191117-193943 with mse=22.220098661532973
# saved to model_save at about 20191117-194031 with mse=22.22009876198408
# saved to model_save at about 20191117-194118 with mse=22.22009262355018
# saved to model_save at about 20191117-194206 with mse=22.22009262355018
# saved to model_save at about 20191117-194254 with mse=22.220089273320713
# saved to model_save at about 20191117-194341 with mse=22.220089228618153
# saved to model_save at about 20191117-194428 with mse=22.220089228618153
# saved to model_save at about 20191117-194516 with mse=22.220086881030557
# saved to model_save at about 20191117-194604 with mse=22.22001860618296
# saved to model_save at about 20191117-194651 with mse=22.22001860618296
# saved to model_save at about 20191117-194739 with mse=22.22006975861465
# saved to model_save at about 20191117-194826 with mse=22.22006303636908
# saved to model_save at about 20191117-194914 with mse=22.22006303636908
# saved to model_save at about 20191117-195001 with mse=22.220057278984775
# saved to model_save at about 20191117-195049 with mse=22.220052333525988
# saved to model_save at about 20191117-195115 with mse=22.220249795205117
# saved to final_model_save at about 20191117-195115 with mse=22.22001860618296
# lastparamdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 4)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (4, 6)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (6, 7)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 8)}, 'y_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (8, 9)}, 'free_params': array([0.322691  , 0.30334152, 1.02682976, 1.00955425, 0.50272753,
#        0.54825703, 2.46192946, 2.18805554, 1.51877438]), 'fixed_params': array([], dtype=float64)}
# ~~~~~~~run number:11`~~~~~~~
# a_rundict{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.01, 'fatol': 0.1, 'adaptive': True}, 'mse_threshold': 2, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.32268365, 0.30334207]), 'x_bandscale': array([1.02683083, 1.00956598]), 'outer_x_bw': array([2.46187337]), 'outer_y_bw': array([2.18456474]), 'Ndiff_depth_bw': array([0.5027271 , 0.53737641]), 'y_bandscale': array([1.51873978])}, 'modeldict': {'Ndiff_type': 'recursive', 'param_count': 2, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}}, 'datagen_dict': {'train_n': 30, 'n': 200, 'param_count': 2, 'seed': 1, 'ftype': 'linear', 'evar': 1}}
# in saved_filename:condensed_model_save, len(doubledict_list):83,len(saved_dict_list):83
#
# optimization dict with lowest mse:22.22001860618296, n:30was last saved20191117-194651
# best_dict:{'mse': 22.22001860618296, 'xdata': array([[-2.5563435 , -3.64593724],
#        [ 0.23081526, -6.10307739],
#        [ 1.98962353, -3.0224138 ],
#        [-0.86192181, -1.99874075],
#        [ 1.42421587, -5.62028142],
#        [-2.14483441, -2.26810871],
#        [ 0.76753888, -3.69978253],
#        [-1.84485642, -3.25571684],
#        [-1.41557251, -0.33436957],
#        [-3.70123835,  0.78944742],
#        [ 0.30318144, -0.49501132],
#        [ 0.3017119 , -2.86745572],
#        [-1.74578045, -3.37153887],
#        [-2.03577616, -0.43928907],
#        [-2.8833215 , -2.29350705],
#        [-2.8743454 , -3.19041128],
#        [-2.84249226, -1.5253292 ],
#        [-3.7346207 , -1.0311686 ],
#        [ 1.81960435, -0.01591168],
#        [-1.8836711 , -3.27525793],
#        [-2.99431659,  1.8849092 ],
#        [-1.39838449, -2.77399129],
#        [-1.11816903,  2.70051027],
#        [-1.2596821 , -0.26559378],
#        [-0.89965936, -2.20449969],
#        [-3.7850364 , -2.19868544],
#        [-1.91778847, -0.32675362],
#        [ 0.17796683,  0.36220416],
#        [-0.92882535,  0.27028233],
#        [-3.00879588,  1.00573631]]), 'ydata': array([-24.62107866, -32.92393465, -12.57809272, -11.62982371,
#        -31.01572349, -16.72848994, -18.21200149, -20.11983952,
#         -3.11909872,   1.39056333,   1.39654418, -14.661963  ,
#        -24.13429711,  -6.48485309, -18.30554416, -21.77531739,
#        -12.52668742, -13.75050084,   5.31497281, -19.8055284 ,
#          6.94601735, -18.19068636,  18.02134768,  -2.05951734,
#        -13.50547398, -18.4120183 ,  -3.77893391,   4.10001635,
#          2.9724996 ,   3.1325279 ]), 'params': {'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 4)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (4, 6)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (6, 7)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 8)}, 'y_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (8, 9)}, 'free_params': array([0.32269042, 0.30334124, 1.02682819, 1.00957414, 0.5027243 ,
#        0.54825606, 2.46192502, 2.18805161, 1.51877164]), 'fixed_params': array([], dtype=float64)}, 'modeldict': {'Ndiff_type': 'recursive', 'param_count': 2, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}, 'when_saved': '20191117-194651', 'datagen_dict': {'train_n': 30, 'n': 200, 'param_count': 2, 'seed': 1, 'ftype': 'linear', 'evar': 1}}
# overriding start parameters with saved parameters
# param_valdict:{'Ndiff_exponent': array([0.32269042, 0.30334124]), 'x_bandscale': array([1.02682819, 1.00957414]), 'outer_x_bw': array([2.46192502]), 'outer_y_bw': array([2.18805161]), 'Ndiff_depth_bw': array([0.5027243 , 0.54825606]), 'y_bandscale': array([1.51877164])}
# setup_fixed_or_free_paramdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 4)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (4, 6)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (6, 7)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 8)}, 'y_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (8, 9)}, 'free_params': 'outside', 'fixed_params': array([], dtype=float64)}
# modeldict:{'Ndiff_type': 'recursive', 'param_count': 2, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}
# saved to model_save at about 20191117-195121 with mse=22.22001860618296
# saved to model_save at about 20191117-195126 with mse=22.22001860618296
# save_interval changed to 8
# saved to model_save at about 20191117-195158 with mse=22.22001860618296
# saved to model_save at about 20191117-195240 with mse=22.22001860618296
# saved to model_save at about 20191117-195323 with mse=23.70464711089629
# saved to model_save at about 20191117-195406 with mse=23.958550947435292
# saved to model_save at about 20191117-195448 with mse=22.22001860618296
# saved to model_save at about 20191117-195531 with mse=22.22001860618296
# saved to model_save at about 20191117-195613 with mse=22.22001860618296
# saved to model_save at about 20191117-195655 with mse=22.22001860618296
# saved to model_save at about 20191117-195737 with mse=22.22001860618296
# saved to model_save at about 20191117-195819 with mse=22.22001860618296
# saved to model_save at about 20191117-195902 with mse=22.22001860618296
# saved to model_save at about 20191117-195944 with mse=22.22001860618296
# saved to model_save at about 20191117-200026 with mse=22.22001860618296
# saved to model_save at about 20191117-200109 with mse=22.22001860618296
# saved to model_save at about 20191117-200151 with mse=22.22001860618296
# saved to model_save at about 20191117-200233 with mse=22.22001860618296
# saved to model_save at about 20191117-200319 with mse=22.22001860618296
# saved to model_save at about 20191117-200402 with mse=22.22001860618296
# saved to model_save at about 20191117-200445 with mse=23.336121685420967
# saved to model_save at about 20191117-200527 with mse=23.424197901887798
# saved to model_save at about 20191117-200609 with mse=23.42028996105959
# saved to model_save at about 20191117-200651 with mse=22.22001860618296
# saved to model_save at about 20191117-200734 with mse=22.22001860618296
# saved to model_save at about 20191117-200816 with mse=22.22001860618296
# saved to model_save at about 20191117-200858 with mse=22.22001860618296
# saved to model_save at about 20191117-200940 with mse=22.22001860618296
# saved to model_save at about 20191117-201022 with mse=22.22001860618296
# saved to model_save at about 20191117-201104 with mse=22.22001860618296
# saved to model_save at about 20191117-201146 with mse=22.22001860618296
# saved to model_save at about 20191117-201228 with mse=22.22001860618296
# saved to model_save at about 20191117-201310 with mse=22.22001860618296
# saved to model_save at about 20191117-201353 with mse=22.22001860618296
# saved to model_save at about 20191117-201435 with mse=22.22001860618296
# saved to model_save at about 20191117-201517 with mse=22.22001860618296
# saved to model_save at about 20191117-201600 with mse=22.22001860618296
# saved to model_save at about 20191117-201642 with mse=22.22001860618296
# saved to model_save at about 20191117-201724 with mse=22.22001860618296
# saved to model_save at about 20191117-201806 with mse=22.22001860618296
# saved to model_save at about 20191117-201848 with mse=22.22001860618296
# saved to model_save at about 20191117-201931 with mse=22.22001860618296
# saved to model_save at about 20191117-202013 with mse=22.22001860618296
# saved to model_save at about 20191117-202055 with mse=22.22001860618296
# saved to model_save at about 20191117-202137 with mse=22.22001860618296
# saved to model_save at about 20191117-202220 with mse=22.22001860618296
# saved to model_save at about 20191117-202302 with mse=22.22001860618296
# saved to model_save at about 20191117-202344 with mse=22.22001860618296
# saved to model_save at about 20191117-202426 with mse=22.22001860618296
# saved to model_save at about 20191117-202509 with mse=22.22001860618296
# saved to model_save at about 20191117-202551 with mse=22.22001860618296
# saved to model_save at about 20191117-202633 with mse=22.22001860618296
# saved to model_save at about 20191117-202715 with mse=22.22001860618296
# saved to model_save at about 20191117-202757 with mse=22.22001860618296
# saved to model_save at about 20191117-202840 with mse=22.22001860618296
# saved to model_save at about 20191117-202922 with mse=22.22001860618296
# saved to model_save at about 20191117-203004 with mse=22.22001860618296
# saved to model_save at about 20191117-203046 with mse=22.22001860618296
# saved to model_save at about 20191117-203128 with mse=22.22001860618296
# saved to model_save at about 20191117-203211 with mse=22.22001860618296
# saved to model_save at about 20191117-203253 with mse=22.22001860618296
# saved to model_save at about 20191117-203335 with mse=22.22001860618296
# saved to model_save at about 20191117-203418 with mse=22.22001860618296
# saved to model_save at about 20191117-203500 with mse=22.22001860618296
# saved to model_save at about 20191117-203542 with mse=22.22001860618296
# saved to model_save at about 20191117-203624 with mse=22.22001860618296
# saved to model_save at about 20191117-203707 with mse=22.22001860618296
# saved to model_save at about 20191117-203749 with mse=22.22001860618296
# saved to model_save at about 20191117-203831 with mse=22.22001860618296
# saved to model_save at about 20191117-203913 with mse=22.22001860618296
# saved to model_save at about 20191117-203955 with mse=22.22001860618296
# saved to model_save at about 20191117-204037 with mse=22.22001860618296
# saved to model_save at about 20191117-204119 with mse=22.22001860618296
# saved to model_save at about 20191117-204202 with mse=22.22001860618296
# saved to model_save at about 20191117-204244 with mse=22.22001860618296
# saved to model_save at about 20191117-204326 with mse=22.22001860618296
# saved to model_save at about 20191117-204408 with mse=22.22001860618296
# saved to model_save at about 20191117-204451 with mse=22.22001860618296
# saved to model_save at about 20191117-204533 with mse=22.22001860618296
# saved to model_save at about 20191117-204615 with mse=22.220016754397523
# saved to model_save at about 20191117-204658 with mse=22.220016754397523
# saved to model_save at about 20191117-204740 with mse=22.220016904812844
# saved to model_save at about 20191117-204822 with mse=22.220015706457527
# saved to model_save at about 20191117-204904 with mse=22.220015706457527
# saved to model_save at about 20191117-204947 with mse=22.220015704553465
# saved to model_save at about 20191117-205029 with mse=22.22001496857264
# saved to model_save at about 20191117-205112 with mse=22.22001496857264
# saved to model_save at about 20191117-205154 with mse=22.22001496857264
# saved to model_save at about 20191117-205236 with mse=22.220014571648804
# saved to model_save at about 20191117-205319 with mse=22.220014560598088
# saved to model_save at about 20191117-205401 with mse=22.22001428295762
# saved to model_save at about 20191117-205443 with mse=22.22001428295762
# saved to model_save at about 20191117-205525 with mse=22.220014302589608
# saved to model_save at about 20191117-205608 with mse=22.220014120928614
# saved to model_save at about 20191117-205650 with mse=22.220014120928614
# saved to model_save at about 20191117-205732 with mse=22.220014120928614
# saved to model_save at about 20191117-205814 with mse=22.22001401087029
# saved to model_save at about 20191117-205857 with mse=22.22001401087029
# saved to model_save at about 20191117-205939 with mse=22.220014020167884
# saved to model_save at about 20191117-210021 with mse=22.220013949184803
# saved to model_save at about 20191117-210104 with mse=22.22001394875043
# saved to model_save at about 20191117-210146 with mse=22.22001390546726
# saved to model_save at about 20191117-210229 with mse=22.22001390546726
# saved to model_save at about 20191117-210311 with mse=22.22001390546726
# saved to model_save at about 20191117-210353 with mse=22.22001388173647
# saved to model_save at about 20191117-210436 with mse=22.220013881289894
# saved to model_save at about 20191117-210518 with mse=22.220013881289894
# saved to model_save at about 20191117-210600 with mse=22.22001386466765
# saved to model_save at about 20191117-210642 with mse=22.22001386466765
# saved to model_save at about 20191117-210725 with mse=22.220013865995238
# saved to model_save at about 20191117-210807 with mse=22.220013855222543
# saved to model_save at about 20191117-210849 with mse=22.220013855222543
# saved to model_save at about 20191117-210931 with mse=22.220013848589893
# saved to model_save at about 20191117-211014 with mse=22.220013848589893
# saved to model_save at about 20191117-211056 with mse=22.220013849244445
# saved to model_save at about 20191117-211138 with mse=22.220013845030433
# saved to model_save at about 20191117-211221 with mse=22.220013845030433
# saved to model_save at about 20191117-211303 with mse=22.220013844922335
# saved to model_save at about 20191117-211345 with mse=22.220013842433378
# saved to model_save at about 20191117-211428 with mse=22.22001133933217
# saved to model_save at about 20191117-211510 with mse=22.22001133933217
# saved to model_save at about 20191117-211552 with mse=22.220013315232816
# saved to model_save at about 20191117-211634 with mse=22.22001309426621
# saved to model_save at about 20191117-211717 with mse=22.220012898149815
# saved to model_save at about 20191117-211759 with mse=22.220012898149815
# saved to model_save at about 20191117-211841 with mse=22.220012724059856
# saved to model_save at about 20191117-211924 with mse=22.22001256949999
# saved to model_save at about 20191117-212006 with mse=22.220012432260415
# saved to model_save at about 20191117-212048 with mse=22.220012432260415
# saved to model_save at about 20191117-212131 with mse=22.220012310385748
# saved to model_save at about 20191117-212213 with mse=22.22001220214493
# saved to model_save at about 20191117-212255 with mse=22.22001220214493
# saved to model_save at about 20191117-212337 with mse=22.220012106003498
# saved to model_save at about 20191117-212419 with mse=22.22001202060187
# saved to model_save at about 20191117-212502 with mse=22.22001194473411
# saved to model_save at about 20191117-212544 with mse=22.22001194473411
# saved to model_save at about 20191117-212626 with mse=22.220011877332677
# saved to model_save at about 20191117-212654 with mse=22.220014656913236
# saved to final_model_save at about 20191117-212654 with mse=22.22001133933217
# lastparamdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 4)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (4, 6)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (6, 7)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 8)}, 'y_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (8, 9)}, 'free_params': array([0.32269068, 0.30334121, 1.02682811, 1.00957415, 0.50272425,
#        0.5482565 , 2.46192699, 2.18820009, 1.51877286]), 'fixed_params': array([], dtype=float64)}
# ~~~~~~~run number:22`~~~~~~~
# a_rundict{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.01, 'fatol': 0.1, 'adaptive': True}, 'mse_threshold': 2, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.32269042, 0.30334124]), 'x_bandscale': array([1.02682819, 1.00957414]), 'outer_x_bw': array([2.46192502]), 'outer_y_bw': array([2.18805161]), 'Ndiff_depth_bw': array([0.5027243 , 0.54825606]), 'y_bandscale': array([1.51877164])}, 'modeldict': {'Ndiff_type': 'product', 'param_count': 2, 'Ndiff_start': 0, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}}, 'datagen_dict': {'train_n': 30, 'n': 200, 'param_count': 2, 'seed': 1, 'ftype': 'linear', 'evar': 1}}
# in saved_filename:condensed_model_save, len(doubledict_list):278,len(saved_dict_list):278
# --------------------------------help_start is triggered---------------------------
# --------------help_start with partial match triggered----------------
# --------------no matching models found----------
# param_valdict:{'Ndiff_exponent': array([0.32269042, 0.30334124]), 'x_bandscale': array([1.02682819, 1.00957414]), 'outer_x_bw': array([2.46192502]), 'outer_y_bw': array([2.18805161]), 'Ndiff_depth_bw': array([0.5027243 , 0.54825606]), 'y_bandscale': array([1.51877164])}
# setup_fixed_or_free_paramdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 4)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (4, 6)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (6, 7)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 8)}, 'y_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (8, 9)}, 'free_params': 'outside', 'fixed_params': array([], dtype=float64)}
# modeldict:{'Ndiff_type': 'product', 'param_count': 2, 'Ndiff_start': 0, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}
# traceback for run 22
# Traceback (most recent call last):
#   File "<ipython-input-8-9ebd2882269d>", line 12, in <module>
#     test.do_monte_opt(optimizedict,datagen_dict,force_start_params=0)
#   File "/home/douglas/gits/kernelkernel/kernelcompare.py", line 39, in do_monte_opt
#     mk.optimize_free_params(y,x,optimizedict)
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 691, in __init__
#     self.minimize_obj=minimize(self.MY_KDEpredictMSE, free_params, args=args_tuple, method=method, options=opt_method_options)
#   File "/home/douglas/anaconda3/lib/python3.7/site-packages/scipy/optimize/_minimize.py", line 591, in minimize
#     return _minimize_neldermead(fun, x0, args, callback, **options)
#   File "/home/douglas/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 552, in _minimize_neldermead
#     fsim[k] = func(sim[k])
#   File "/home/douglas/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 293, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 464, in MY_KDEpredictMSE
#     yhat_un_std=self.MY_KDEpredict(yin,yout,xin,xpr,modeldict,fixed_or_free_paramdict)
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 561, in MY_KDEpredict
#     xbw = self.BWmaker(max_bw_Ndiff, fixed_or_free_paramdict, diffdict, modeldict,'x')
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 128, in BWmaker
#     if Ndiff_type=='product':this_depth_bw_param=Ndiff_depth_bw_params[param_idx]
# IndexError: index 2 is out of bounds for axis 0 with size 2
#
# ~~~~~~~run number:33`~~~~~~~
# a_rundict{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.01, 'fatol': 0.1, 'adaptive': True}, 'mse_threshold': 2, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.3, 0.3]), 'x_bandscale': array([1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.5])}, 'modeldict': {'Ndiff_type': 'product', 'param_count': 2, 'Ndiff_start': 0, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}}, 'datagen_dict': {'train_n': 30, 'n': 200, 'param_count': 2, 'seed': 1, 'ftype': 'linear,quadratic', 'evar': 1}}
# in saved_filename:condensed_model_save, len(doubledict_list):278,len(saved_dict_list):278
# --------------------------------help_start is triggered---------------------------
# --------------help_start with partial match triggered----------------
# --------------no matching models found----------
# param_valdict:{'Ndiff_exponent': array([0.3, 0.3]), 'x_bandscale': array([1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.5])}
# setup_fixed_or_free_paramdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 4)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (4, 6)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (6, 7)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 8)}, 'y_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (8, 9)}, 'free_params': 'outside', 'fixed_params': array([], dtype=float64)}
# modeldict:{'Ndiff_type': 'product', 'param_count': 2, 'Ndiff_start': 0, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}
# traceback for run 33
# Traceback (most recent call last):
#   File "<ipython-input-8-9ebd2882269d>", line 12, in <module>
#     test.do_monte_opt(optimizedict,datagen_dict,force_start_params=0)
#   File "/home/douglas/gits/kernelkernel/kernelcompare.py", line 39, in do_monte_opt
#     mk.optimize_free_params(y,x,optimizedict)
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 691, in __init__
#     self.minimize_obj=minimize(self.MY_KDEpredictMSE, free_params, args=args_tuple, method=method, options=opt_method_options)
#   File "/home/douglas/anaconda3/lib/python3.7/site-packages/scipy/optimize/_minimize.py", line 591, in minimize
#     return _minimize_neldermead(fun, x0, args, callback, **options)
#   File "/home/douglas/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 552, in _minimize_neldermead
#     fsim[k] = func(sim[k])
#   File "/home/douglas/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 293, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 464, in MY_KDEpredictMSE
#     yhat_un_std=self.MY_KDEpredict(yin,yout,xin,xpr,modeldict,fixed_or_free_paramdict)
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 561, in MY_KDEpredict
#     xbw = self.BWmaker(max_bw_Ndiff, fixed_or_free_paramdict, diffdict, modeldict,'x')
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 128, in BWmaker
#     if Ndiff_type=='product':this_depth_bw_param=Ndiff_depth_bw_params[param_idx]
# IndexError: index 2 is out of bounds for axis 0 with size 2
#
# ~~~~~~~run number:44`~~~~~~~
# a_rundict{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.01, 'fatol': 0.1, 'adaptive': True}, 'mse_threshold': 2, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.3, 0.3]), 'x_bandscale': array([1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.5])}, 'modeldict': {'Ndiff_type': 'product', 'param_count': 2, 'Ndiff_start': 0, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}}, 'datagen_dict': {'train_n': 30, 'n': 200, 'param_count': 2, 'seed': 1, 'ftype': 'linear,quadratic', 'evar': 1}}
# in saved_filename:condensed_model_save, len(doubledict_list):278,len(saved_dict_list):278
# --------------------------------help_start is triggered---------------------------
# --------------help_start with partial match triggered----------------
# --------------no matching models found----------
# param_valdict:{'Ndiff_exponent': array([0.3, 0.3]), 'x_bandscale': array([1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.5])}
# setup_fixed_or_free_paramdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 4)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (4, 6)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (6, 7)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 8)}, 'y_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (8, 9)}, 'free_params': 'outside', 'fixed_params': array([], dtype=float64)}
# modeldict:{'Ndiff_type': 'product', 'param_count': 2, 'Ndiff_start': 0, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}
# traceback for run 44
# Traceback (most recent call last):
#   File "<ipython-input-8-9ebd2882269d>", line 12, in <module>
#     test.do_monte_opt(optimizedict,datagen_dict,force_start_params=0)
#   File "/home/douglas/gits/kernelkernel/kernelcompare.py", line 39, in do_monte_opt
#     mk.optimize_free_params(y,x,optimizedict)
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 691, in __init__
#     self.minimize_obj=minimize(self.MY_KDEpredictMSE, free_params, args=args_tuple, method=method, options=opt_method_options)
#   File "/home/douglas/anaconda3/lib/python3.7/site-packages/scipy/optimize/_minimize.py", line 591, in minimize
#     return _minimize_neldermead(fun, x0, args, callback, **options)
#   File "/home/douglas/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 552, in _minimize_neldermead
#     fsim[k] = func(sim[k])
#   File "/home/douglas/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 293, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 464, in MY_KDEpredictMSE
#     yhat_un_std=self.MY_KDEpredict(yin,yout,xin,xpr,modeldict,fixed_or_free_paramdict)
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 561, in MY_KDEpredict
#     xbw = self.BWmaker(max_bw_Ndiff, fixed_or_free_paramdict, diffdict, modeldict,'x')
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 128, in BWmaker
#     if Ndiff_type=='product':this_depth_bw_param=Ndiff_depth_bw_params[param_idx]
# IndexError: index 2 is out of bounds for axis 0 with size 2
#
# ~~~~~~~run number:55`~~~~~~~
# a_rundict{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.01, 'fatol': 0.1, 'adaptive': True}, 'mse_threshold': 2, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.3, 0.3]), 'x_bandscale': array([1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.5])}, 'modeldict': {'Ndiff_type': 'product', 'param_count': 1, 'Ndiff_start': 0, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}}, 'datagen_dict': {'train_n': 30, 'n': 200, 'param_count': 1, 'seed': 1, 'ftype': 'linear,quadratic', 'evar': 1}}
# in saved_filename:condensed_model_save, len(doubledict_list):278,len(saved_dict_list):278
# --------------------------------help_start is triggered---------------------------
# --------------help_start with partial match triggered----------------
# --------------no matching models found----------
# param_valdict:{'Ndiff_exponent': array([0.3, 0.3]), 'x_bandscale': array([1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.5])}
# setup_fixed_or_free_paramdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 3)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (3, 5)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (5, 6)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (6, 7)}, 'y_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 8)}, 'free_params': 'outside', 'fixed_params': array([], dtype=float64)}
# modeldict:{'Ndiff_type': 'product', 'param_count': 1, 'Ndiff_start': 0, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}
# traceback for run 55
# Traceback (most recent call last):
#   File "<ipython-input-8-9ebd2882269d>", line 12, in <module>
#     test.do_monte_opt(optimizedict,datagen_dict,force_start_params=0)
#   File "/home/douglas/gits/kernelkernel/kernelcompare.py", line 39, in do_monte_opt
#     mk.optimize_free_params(y,x,optimizedict)
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 691, in __init__
#     self.minimize_obj=minimize(self.MY_KDEpredictMSE, free_params, args=args_tuple, method=method, options=opt_method_options)
#   File "/home/douglas/anaconda3/lib/python3.7/site-packages/scipy/optimize/_minimize.py", line 591, in minimize
#     return _minimize_neldermead(fun, x0, args, callback, **options)
#   File "/home/douglas/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 552, in _minimize_neldermead
#     fsim[k] = func(sim[k])
#   File "/home/douglas/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 293, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 464, in MY_KDEpredictMSE
#     yhat_un_std=self.MY_KDEpredict(yin,yout,xin,xpr,modeldict,fixed_or_free_paramdict)
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 561, in MY_KDEpredict
#     xbw = self.BWmaker(max_bw_Ndiff, fixed_or_free_paramdict, diffdict, modeldict,'x')
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 128, in BWmaker
#     if Ndiff_type=='product':this_depth_bw_param=Ndiff_depth_bw_params[param_idx]
# IndexError: index 2 is out of bounds for axis 0 with size 2
#
# ~~~~~~~run number:66`~~~~~~~
# a_rundict{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.01, 'fatol': 0.1, 'adaptive': True}, 'mse_threshold': 2, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.3, 0.3]), 'x_bandscale': array([1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.5])}, 'modeldict': {'Ndiff_type': 'recursive', 'param_count': 1, 'Ndiff_start': 0, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}}, 'datagen_dict': {'train_n': 30, 'n': 200, 'param_count': 1, 'seed': 1, 'ftype': 'linear,quadratic', 'evar': 1}}
# in saved_filename:condensed_model_save, len(doubledict_list):278,len(saved_dict_list):278
# --------------------------------help_start is triggered---------------------------
# --------------help_start with partial match triggered----------------
# --------------no matching models found----------
# param_valdict:{'Ndiff_exponent': array([0.3, 0.3]), 'x_bandscale': array([1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.5])}
# setup_fixed_or_free_paramdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 3)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (3, 5)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (5, 6)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (6, 7)}, 'y_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 8)}, 'free_params': 'outside', 'fixed_params': array([], dtype=float64)}
# ...
# traceback for run 66
# Traceback (most recent call last):
#   File "<ipython-input-8-9ebd2882269d>", line 12, in <module>
#     test.do_monte_opt(optimizedict,datagen_dict,force_start_params=0)
#   File "/home/douglas/gits/kernelkernel/kernelcompare.py", line 39, in do_monte_opt
#     mk.optimize_free_params(y,x,optimizedict)
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 691, in __init__
#     self.minimize_obj=minimize(self.MY_KDEpredictMSE, free_params, args=args_tuple, method=method, options=opt_method_options)
#   File "/home/douglas/anaconda3/lib/python3.7/site-packages/scipy/optimize/_minimize.py", line 591, in minimize
#     return _minimize_neldermead(fun, x0, args, callback, **options)
#   File "/home/douglas/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 552, in _minimize_neldermead
#     fsim[k] = func(sim[k])
#   File "/home/douglas/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py", line 293, in function_wrapper
#     return function(*(wrapper_args + args))
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 464, in MY_KDEpredictMSE
#     yhat_un_std=self.MY_KDEpredict(yin,yout,xin,xpr,modeldict,fixed_or_free_paramdict)
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 561, in MY_KDEpredict
#     xbw = self.BWmaker(max_bw_Ndiff, fixed_or_free_paramdict, diffdict, modeldict,'x')
#   File "/home/douglas/gits/kernelkernel/mykern.py", line 130, in BWmaker
#     this_depth_exponent=Ndiff_exponent_params[param_idx]
# IndexError: index 2 is out of bounds for axis 0 with size 2
#
# ~~~~~~~run number:77`~~~~~~~
# a_rundict{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.01, 'fatol': 0.1, 'adaptive': True}, 'mse_threshold': 2, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.3, 0.3]), 'x_bandscale': array([1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.5])}, 'modeldict': {'Ndiff_type': 'product', 'param_count': 1, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}}, 'datagen_dict': {'train_n': 30, 'n': 200, 'param_count': 1, 'seed': 1, 'ftype': 'linear', 'evar': 1}}
# in saved_filename:condensed_model_save, len(doubledict_list):278,len(saved_dict_list):278
#
# optimization dict with lowest mse:0.6262267847199882, n:30was last saved20191117-180609
# best_dict:{'mse': 0.6262267847199882, 'xdata': array([[-4.70344201],
#        [-4.45565914],
#        [-0.53300831],
#        [-1.12312679],
#        [-2.42937265],
#        [ 0.22365423],
#        [-6.80852396],
#        [ 0.80452983],
#        [-1.10671318],
#        [-4.5904283 ],
#        [-1.67620817],
#        [ 0.20447864],
#        [-0.14553199],
#        [-1.71375685],
#        [-0.04945187],
#        [ 0.36977831],
#        [ 0.73659395],
#        [-1.38877362],
#        [-0.74668673],
#        [-0.74772996],
#        [-1.82838154],
#        [-1.6690869 ],
#        [ 0.36311632],
#        [ 1.91386994],
#        [-3.28382752],
#        [ 1.97119306],
#        [-2.76221666],
#        [-3.31468671],
#        [-0.75049605],
#        [-2.44676551]]), 'ydata': array([-36.319493  , -32.83804048,  -2.65249486,  -8.35084634,
#        -16.1155224 ,   2.78381719, -52.92784341,   8.64971312,
#         -7.08983112, -36.43014166, -12.68737662,   2.94635041,
#          0.86393548, -12.13453651,   1.78035098,   3.89942004,
#          7.60718332, -10.31204781,  -5.10966336,  -3.05376768,
#        -12.53302308,  -9.84508357,   6.03345354,  17.43864784,
#        -24.34204696,  17.19025971, -19.60073028, -23.38057472,
#         -3.26114389, -16.5887201 ]), 'params': {'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 3)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (3, 5)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (5, 6)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (6, 7)}, 'y_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 8)}, 'free_params': array([ 1.403123  ,  0.02654983, -2.55449984,  1.34389893,  0.71859149,
#         7.71714637,  0.2536322 , -1.05012283]), 'fixed_params': array([], dtype=float64)}, 'modeldict': {'Ndiff_type': 'product', 'param_count': 1, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}, 'when_saved': '20191117-180609', 'datagen_dict': {'train_n': 30, 'n': 200, 'param_count': 1, 'seed': 1, 'ftype': 'linear', 'evar': 1}}
# overriding start parameters with saved parameters
# param_valdict:{'Ndiff_exponent': array([1.403123  , 0.02654983]), 'x_bandscale': array([-2.55449984]), 'outer_x_bw': array([7.71714637]), 'outer_y_bw': array([0.2536322]), 'Ndiff_depth_bw': array([1.34389893, 0.71859149]), 'y_bandscale': array([-1.05012283])}
# setup_fixed_or_free_paramdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 3)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (3, 5)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (5, 6)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (6, 7)}, 'y_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 8)}, 'free_params': 'outside', 'fixed_params': array([], dtype=float64)}
# modeldict:{'Ndiff_type': 'product', 'param_count': 1, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}
# saved to model_save at about 20191117-212703 with mse=0.6262267847199882
# saved to model_save at about 20191117-212712 with mse=0.6262267847199882
# save_interval changed to 3
# saved to model_save at about 20191117-212721 with mse=0.6262267847199882
# saved to model_save at about 20191117-212746 with mse=0.6245901075576968
# saved to model_save at about 20191117-212812 with mse=0.6245901075576968
# saved to model_save at about 20191117-212837 with mse=0.6262321491470316
# saved to model_save at about 20191117-212903 with mse=5.9776898803744505
# saved to model_save at about 20191117-212929 with mse=5.699855910404667
# saved to model_save at about 20191117-212955 with mse=2.8514163176642024
# saved to model_save at about 20191117-213020 with mse=1.5420842342860455
# saved to model_save at about 20191117-213046 with mse=1.1100463205888529
# saved to model_save at about 20191117-213111 with mse=0.9836911845962976
# saved to model_save at about 20191117-213136 with mse=0.9836911845962976
# saved to model_save at about 20191117-213201 with mse=0.8014010372761328
# saved to model_save at about 20191117-213225 with mse=0.7697603841006139
# saved to model_save at about 20191117-213250 with mse=0.6881427732289115
# saved to model_save at about 20191117-213315 with mse=0.6844332730183919
# saved to model_save at about 20191117-213340 with mse=0.6696452394717161
# saved to model_save at about 20191117-213405 with mse=0.6488278779344765
# saved to model_save at about 20191117-213430 with mse=0.6488278779344765
# saved to model_save at about 20191117-213455 with mse=0.6443340190267536
# saved to model_save at about 20191117-213520 with mse=0.637209981990816
# saved to model_save at about 20191117-213545 with mse=0.6356049553721406
# saved to model_save at about 20191117-213610 with mse=0.6329443977293945
# saved to model_save at about 20191117-213635 with mse=0.6324206958629427
# saved to model_save at about 20191117-213700 with mse=0.629021868458521
# saved to model_save at about 20191117-213725 with mse=0.6287758969952922
# saved to model_save at about 20191117-213750 with mse=0.6278662685611086
# saved to model_save at about 20191117-213815 with mse=0.6266568345469008
# saved to model_save at about 20191117-213839 with mse=0.626144834262232
# saved to model_save at about 20191117-213904 with mse=0.6260244559761637
# saved to model_save at about 20191117-213929 with mse=0.6251966331478306
# saved to model_save at about 20191117-213954 with mse=0.6251966331478306
# saved to model_save at about 20191117-214019 with mse=0.6251627888451396
# saved to model_save at about 20191117-214044 with mse=0.6249939923459095
# saved to model_save at about 20191117-214109 with mse=0.6249137144830964
# saved to model_save at about 20191117-214133 with mse=0.624767278767584
# saved to model_save at about 20191117-214158 with mse=0.6241965555171037
# saved to model_save at about 20191117-214223 with mse=0.62372564915469
# saved to model_save at about 20191117-214248 with mse=0.6231928512312623
# saved to model_save at about 20191117-214313 with mse=0.6231928512312623
# saved to model_save at about 20191117-214338 with mse=0.6239821054231988
# saved to model_save at about 20191117-214403 with mse=0.6230304492568085
# saved to model_save at about 20191117-214428 with mse=0.6226515007808094
# saved to model_save at about 20191117-214453 with mse=0.6225239635545866
# saved to model_save at about 20191117-214517 with mse=0.6225239635545866
# saved to model_save at about 20191117-214542 with mse=0.6218702646593738
# saved to model_save at about 20191117-214607 with mse=0.6216995865750569
# saved to model_save at about 20191117-214632 with mse=0.6216995865750569
# saved to model_save at about 20191117-214657 with mse=0.6214960916283129
# saved to model_save at about 20191117-214722 with mse=0.6209016981720615
# saved to model_save at about 20191117-214747 with mse=0.6207511071029114
# saved to model_save at about 20191117-214812 with mse=0.6207511071029114
# saved to model_save at about 20191117-214837 with mse=0.6208448390486622
# saved to model_save at about 20191117-214902 with mse=0.6204087734087583
# saved to model_save at about 20191117-214927 with mse=0.6204087734087583
# saved to model_save at about 20191117-214952 with mse=0.6201446842385294
# saved to model_save at about 20191117-215016 with mse=0.6200312704726723
# saved to model_save at about 20191117-215041 with mse=0.6199530903497525
# saved to model_save at about 20191117-215106 with mse=0.6199530903497525
# saved to model_save at about 20191117-215131 with mse=0.6196656106841301
# saved to model_save at about 20191117-215156 with mse=0.6194739917971163
# saved to model_save at about 20191117-215221 with mse=0.6194140031194224
# saved to model_save at about 20191117-215246 with mse=0.6193223535337345
# saved to model_save at about 20191117-215311 with mse=0.6192262136796667
# saved to model_save at about 20191117-215336 with mse=0.6190851498180271
# saved to model_save at about 20191117-215401 with mse=0.6188934044702054
# saved to model_save at about 20191117-215426 with mse=0.6188372427116707
# saved to model_save at about 20191117-215451 with mse=0.6187584883890314
# saved to model_save at about 20191117-215516 with mse=0.6186527020063362
# saved to model_save at about 20191117-215541 with mse=0.6186527020063362
# saved to model_save at about 20191117-215606 with mse=0.618591834250996
# saved to model_save at about 20191117-215630 with mse=0.6184457340571743
# saved to model_save at about 20191117-215655 with mse=0.6184457340571743
# saved to model_save at about 20191117-215720 with mse=0.6183452479628015
# saved to model_save at about 20191117-215745 with mse=0.6183262776118236
# saved to model_save at about 20191117-215810 with mse=0.6183262776118236
# saved to model_save at about 20191117-215835 with mse=0.6183058926521848
# saved to model_save at about 20191117-215900 with mse=0.6183058926521848
# saved to model_save at about 20191117-215925 with mse=0.6183577336894771
# saved to model_save at about 20191117-215950 with mse=0.6182672328145054
# saved to model_save at about 20191117-220015 with mse=0.6181637272291491
# saved to model_save at about 20191117-220040 with mse=0.6181637272291491
# saved to model_save at about 20191117-220105 with mse=0.6182586323578111
# saved to model_save at about 20191117-220129 with mse=0.6182367885514943
# saved to model_save at about 20191117-220155 with mse=0.6181013631552607
# saved to model_save at about 20191117-220220 with mse=0.6181013631552607
# saved to model_save at about 20191117-220245 with mse=0.6181282345505468
# saved to model_save at about 20191117-220310 with mse=0.61810587277698
# saved to model_save at about 20191117-220334 with mse=0.6180320523002237
# saved to model_save at about 20191117-220359 with mse=0.6180320523002237
# saved to model_save at about 20191117-220424 with mse=0.6180450826792774
# saved to model_save at about 20191117-220449 with mse=0.617992619232045
# saved to model_save at about 20191117-220514 with mse=0.6179833384176153
# saved to model_save at about 20191117-220539 with mse=0.6178859549147331
# saved to model_save at about 20191117-220604 with mse=0.6178859549147331
# saved to model_save at about 20191117-220629 with mse=0.617828759143844
# saved to model_save at about 20191117-220654 with mse=0.6178066079319297
# saved to model_save at about 20191117-220719 with mse=0.6177147312745513
# saved to model_save at about 20191117-220744 with mse=0.6177147312745513
# saved to model_save at about 20191117-220809 with mse=0.6176687026363459
# saved to model_save at about 20191117-220833 with mse=0.6176423243932391
# saved to model_save at about 20191117-220858 with mse=0.6175108670191568
# saved to model_save at about 20191117-220923 with mse=0.6174757853486285
# saved to model_save at about 20191117-220948 with mse=0.617439946429786
# saved to model_save at about 20191117-221013 with mse=0.6173287799031238
# saved to model_save at about 20191117-221038 with mse=0.6172771896413966
# saved to model_save at about 20191117-221103 with mse=0.6172073233621173
# saved to model_save at about 20191117-221128 with mse=0.6171342498663087
# saved to model_save at about 20191117-221153 with mse=0.6170450317708877
# saved to model_save at about 20191117-221218 with mse=0.616934024780115
# saved to model_save at about 20191117-221243 with mse=0.6168877993233787
# saved to model_save at about 20191117-221308 with mse=0.6167768806913483
# saved to model_save at about 20191117-221332 with mse=0.6166589135462562
# saved to model_save at about 20191117-221357 with mse=0.6165365421566555
# saved to model_save at about 20191117-221422 with mse=0.6164512220900366
# saved to model_save at about 20191117-221447 with mse=0.6163144628727417
# saved to model_save at about 20191117-221512 with mse=0.6161844772192498
# saved to model_save at about 20191117-221537 with mse=0.6161239916587596
# saved to model_save at about 20191117-221602 with mse=0.6158768669995229
# saved to model_save at about 20191117-221627 with mse=0.6158128366023231
# saved to model_save at about 20191117-221652 with mse=0.6156887682227598
# saved to model_save at about 20191117-221717 with mse=0.6155291709241233
# saved to model_save at about 20191117-221742 with mse=0.61536434076486
# saved to model_save at about 20191117-221808 with mse=0.61536434076486
# saved to model_save at about 20191117-221834 with mse=0.6153182235028005
# saved to model_save at about 20191117-221900 with mse=0.6153182235028005

# %% [markdown]
# #-----------------Calibrate/Optimize--------

# %%
'''import myreg
x=test.train_x
y=test.train_y
xfull=np.concatenate([np.ones([x.shape[0],1]),x],axis=1)
just_linreg=myreg.reg(y,xfull)
just_linreg.myreg()
print('linreg_mse:',just_linreg.mse)'''

# %%
from bokeh.io import show, output_notebook#,curdoc,save, output_file
from bokeh.plotting import figure
#from bokeh.models import ColumnDataSource, Range1d, BBoxTileSource
#from bokeh.layouts import row
output_notebook()

# %%
#xgrid=np.linspace(1,n,n)
x=quad_misspec.train_x
y=quad_misspec.train_y


xgrid=x[:,0]
yhat=quad_misspec.optimize_obj.yhat_un_std
p=figure(title='y and yhat', plot_width=900, plot_height=500)
p.xaxis.axis_label = 'observations'
p.scatter(xgrid,y,size=10,color='blue',alpha=0.4,legend='y')
#p.line(xgrid,precip,color='blue',alpha=0.6,legend='precipitation')
p.scatter(xgrid,yhat,size=5,color='green',alpha=0.9,legend='yhat')
p.circle(xgrid,just_linreg.yhat,color='red',legend='just lin reg yhat')
p.line(xgrid,np.mean(y))
p.legend.location = "top_left"
#p.yaxis.visible=False
show(p)

# %%
print(yhat)
print(y)

# %%
ypredict=optimized_Ndiff_kernel.predict_tool(xvalidate,optimized_Ndiff_kernel.fixed_or_free_paramdict,modeldict1)
prediction_err=yvalidate-ypredict
prediction_mse=np.mean(prediction_err**2)

# %%
np.ma.count_masked(yhat)

# %% [markdown]
# ## class toolcompare(object):
