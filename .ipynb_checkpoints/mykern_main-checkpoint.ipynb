# %% [markdown]
# ### kernel density estimation and kernel regression for prediction
# This notebook is my first attempt to write down the ddiff and dddiff models that I have been working on

# %% [markdown]
# mixed recursive/iterative approach (rather than vectorized approach that is harder to generalize
# - create separate submodules for KDE and KDreg
#     - develop a system for storing differenced but unweighted data and the appropriate mask to lessen memory usage.
#         -1's or 0's depending on i/j/k/l/.... values
#     - figure out the deepest level requested by the user and levels that are less deep are just slices of the deeper model.
#         -scout out the tree to build the differenced dataset.
#
#
#  plot and compare
# on synthetic data, 1, 2, 3+ mixed distributions
# 1d - Ndiff vs gaussian kernel vs kernel_tunneling
# 2d -
#
#
# multidimensional x problem
# e.g., parameter treatment
# "product kernel approach" vs l2 "el two" (radial basis?)distance

# %%
import numpy as np

# %% [markdown]
# #### generate a simple linear dataset y=xb+e
# ##### store validation data from same dataset too

# %%
import data_gen as dg
data1=dg.data_gen(data_shape=(500,2),seed=1)
#xdata=data1.x[:,:-1]#drop last x
size=30
xdata=data1.x[0:size,:]
ydata=data1.y[0:size]
y=ydata
xfull=xdata
x=xdata[:,1:] #drop first column of x (all 1's)
e=data1.e
n,p=x.shape


xvalidate=data1.x[100:500,1:]
yvalidate=data1.y[100:500]

# %% [markdown]
# ### create modeldict
# - 'Ndiff_type': refers to the mathematical form of Ndiff
#   - 'product'-Ndiff1 multiplied by Ndiff2
#   - 'recursive'-Ndiff1's bw is Ndiff 2
# - max_bw_Ndiff: is the depth of Ndiffs applied in estimating the bandwidth.
# - 'normalize_Ndiffwtsum':
#   - 'across' means sum across own level of kernelized-Ndiffs and divide by that sum (CDF approach)
#   - 'own_n' means for (n+k)diff where n+K=max_bw_Ndiff
# - Ndiff_bw_kern:
#   - rbfkern means use the radial basis function kernel
#   - 'product' means use product kernel like as in liu and yang eq1.
# - 'regression_model':
#   - 'NW' means use nadaraya-watson kernel regression
#   - 'full_logit' means local logit with all variables entering linearly
#   - 'rbf_logit' means local logit with 1 parameters: scaled l2 norm centered on zero
#  (globally or by i?). Is this a new idea?
# - outer_x_bw_form: if x is separated into blocks of rvars that are combined within a block using rbf kernel,
#   - 'one_for_all' - use same hx bw for all blocks
#   - 'one_per_block' - each block or rvars gets an hx
# - ykern_grid
#   - if int, then create int evnely spaced values from -3 to 3 (standard normal middle ~99%)
#   - 'no' means use original data points (self is masked when predicting self)
# - xkern_grid
#   - much like ykern_grid, but used less frequently since x's are typically pre-specified
# - product_kern_norm: when multiplying kernels across random variables, this parameter determines if each random variable has its kernels normalized before the product or not
#   - 'self' means each random variable has its kernels divided by the sum of kernels across the nout axis (the number of possibile values y is averaged over, whose probabilities sum to 1)
#   - 'own_n' means same as self, but divided by count of non-masked items in second to last, nout lenght dimension
#   - 'none' means no normalization prior to taking products across rvar kernels
# - hyper_param_form_dict is a nested dictionary
#   - Ndiff_exponent is the exponent wrapped around typically a sum of kernels for each Ndiff level
# after level 1 (i.e., (i-j) or centered, obvious/conventional level.)
#   - x_bandscale is the parameter specific to each variable (each x in X) used for prediction (y)
#   - Ndiff_depth_bw is used as the kernel's bandwidth (h) at each level of Ndiff including at level 1
#   - outer_x_bw vanilla bandwidth for the rbf or product kernel
#   - outer_y_bw vanilla bandwidth for y

# %%
max_bw_Ndiff=3
Ndiff_start=2
Ndiff_param_count=max_bw_Ndiff-(Ndiff_start-1)
modeldict1={
    'Ndiff_type':'product',
    'Ndiff_start':Ndiff_start,
    'max_bw_Ndiff':max_bw_Ndiff,
    'normalize_Ndiffwtsum':'own_n',
    'xkern_grid':'no',
    'ykern_grid':'no',
    'outer_kern':'gaussian',
    'Ndiff_bw_kern':'rbfkern',
    'outer_x_bw_form':'one_for_all',
    'regression_model':'NW',
    'product_kern_norm':'self',
    'hyper_param_form_dict':{
        'Ndiff_exponent':'free',
        'x_bandscale':'non-neg',
        'Ndiff_depth_bw':'non-neg',
        'outer_x_bw':'non-neg',
        'outer_y_bw':'non-neg',
        'y_bandscale':'non-neg'
        }
    }

modeldict1['ykern_grid']=20#override
#modeldict1['product_kern_norm']='none'

#set starting or fixed values for hyper parameters

#if max_bw_Ndiff>0:onethenzeros[0]=1
hyper_paramdict1={
    'Ndiff_exponent':np.zeros([Ndiff_param_count,])+.05,
    'x_bandscale':.1*np.ones([p,]),
    'outer_x_bw':np.array([0.3,]),
    'outer_y_bw':np.array([0.3,]),
    'Ndiff_depth_bw':np.ones([Ndiff_param_count,])*0.3,
    'y_bandscale':.9*np.ones([1,])
    }


#assert len(hyper_paramdict1['Ndiff_exponent'])==modeldict1['max_bw_Ndiff'],'Ndiff_exponent does not match ' \
#                                                                            'depth of max_bw_Ndiff'
#assert len(hyper_paramdict1['Ndiff_depth_bw'])==modeldict1['max_bw_Ndiff'],'Ndiff_depth_bw does not match ' \
#                                                                             'depth of max_bw_Ndiff'
#create optimization dictionary
optimizedict1={
    'method':'Nelder-Mead',
    'hyper_param_dict':hyper_paramdict1,
    'model_dict':modeldict1
    }

# %%
print(Ndiff_param_count)
# Out:
# 2

# %% [markdown]
# #-----------------Calibrate/Optimize--------

# %%
import mykern as mk

# %%
import myreg
just_linreg=myreg.reg(y,xfull)
just_linreg.myreg()
print('linreg_mse:',just_linreg.mse)
# Out:
# linreg_mse: 1.2196448949583982

# %%
##### y=np.linspace(0,10000,n)#what happens if y has no relationship to x
optimized_Ndiff_kernel=mk.optimize_free_params(y,x,optimizedict1)
print(optimized_Ndiff_kernel.mselist[-1])
# Out:
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:2,mse:4429.4906107532515
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:3,mse:4439.711885381564
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:4,mse:4429.742578919563
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:5,mse:4448.195923898811
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:6,mse:4445.7271027924135
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.37025931 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3702593109569967,Ndiff_depth_bw_params:[1.37025931 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.37025931 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.37025931 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3702593109569967,Ndiff_depth_bw_params:[1.37025931 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.37025931 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:7,mse:4433.063125272933
# depth:3,param_idx:1,this_depth_bw_param1.3702593109569967,Ndiff_depth_bw_params:[1.34985881 1.37025931]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.37025931]
# depth:1,param_idx:-1,this_depth_bw_param1.3702593109569967,Ndiff_depth_bw_params:[1.34985881 1.37025931]
# depth:3,param_idx:1,this_depth_bw_param1.3702593109569967,Ndiff_depth_bw_params:[1.34985881 1.37025931]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.37025931]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3702593109569967,Ndiff_depth_bw_params:[1.34985881 1.37025931]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:8,mse:4429.793431963128
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:9,mse:4406.632419540473
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:10,mse:4396.5979671814885
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:11,mse:4591.6237922894325
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:12,mse:4128.386602773859
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:13,mse:4046.3844572735925
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:14,mse:4591.6237922894325
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:15,mse:4607.682566389314
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:16,mse:4128.386602773859
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:17,mse:4046.3844572735925
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:18,mse:4591.6237922894325
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:19,mse:4607.682566389314
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:20,mse:4128.386602773859
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:21,mse:4046.3844572735925
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:22,mse:4591.6237922894325
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:23,mse:4607.682566389314
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:24,mse:4128.386602773859
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:25,mse:4046.3844572735925
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:26,mse:4591.6237922894325
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:27,mse:4607.682566389314
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:28,mse:4128.386602773859
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:29,mse:4046.3844572735925
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:30,mse:4591.6237922894325
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:31,mse:4607.682566389314
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:32,mse:4128.386602773859
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:33,mse:4046.3844572735925
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:34,mse:4591.6237922894325
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:35,mse:4607.682566389314
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:36,mse:4128.386602773859
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:37,mse:4046.3844572735925
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:38,mse:4591.6237922894325
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:39,mse:4607.682566389314
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:40,mse:4128.386602773859
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:41,mse:4046.3844572735925
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:42,mse:4591.6237922894325
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:43,mse:4607.682566389314
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:44,mse:4128.386602773859
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:45,mse:4046.3844572735925
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:46,mse:4591.6237922894325
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:47,mse:4607.682566389314
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:48,mse:4128.386602773859
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:49,mse:4046.3844572735925
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:50,mse:4591.6237922894325
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:51,mse:4607.682566389314
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:52,mse:4128.386602773859
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:53,mse:4046.3844572735925
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:54,mse:4591.6237922894325
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:55,mse:4607.682566389314
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:56,mse:4128.386602773859
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# ...
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:455,mse:4607.682566389314
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:456,mse:4128.386602773859
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:457,mse:4046.3844572735925
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:458,mse:4591.6237922894325
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:459,mse:4607.682566389314
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:460,mse:4128.386602773859
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:461,mse:4046.3844572735925
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:462,mse:4591.6237922894325
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:463,mse:4607.682566389314
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:464,mse:4128.386602773859
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:465,mse:4046.3844572735925
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,param_idx:1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3498588075760032,Ndiff_depth_bw_params:[1.34985881 1.34985881]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:466,mse:4591.6237922894325
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,param_idx:1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.349358952440973,Ndiff_depth_bw_params:[1.34935895 1.34935895]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:467,mse:4607.682566389314
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,param_idx:1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:2,param_idx:0,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:2,ytup(12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# depth:1,param_idx:-1,this_depth_bw_param1.3543658444895974,Ndiff_depth_bw_params:[1.35436584 1.35436584]
# depth:1,ytup(12, 12, 13, 12),onediffs_shape(12, 13, 12)
# (12, 13, 12) (12, 12)
# iter:468,mse:4128.386602773859
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:2,param_idx:0,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:1,param_idx:-1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,param_idx:1,this_depth_bw_param1.3548675543725404,Ndiff_depth_bw_params:[1.35486755 1.35486755]
# depth:3,ytup(12, 12, 12, 12, 13, 12),onediffs_shape(12, 13, 12)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-6fae111681c1> in <module>
#       1 ##### y=np.linspace(0,10000,n)#what happens if y has no relationship to x
# ----> 2 optimized_Ndiff_kernel=mk.optimize_free_params(y,x,optimizedict1)
#       3 print(optimized_Ndiff_kernel.mselist[-1])
#
# ~\gits\kernelkernel\mykern.py in __init__(self, ydata, xdata, optimizedict)
#     757             'adaptive':True
#     758         }
# --> 759         self.mse=minimize(self.MY_KDEpredictMSE,free_params,args=args_tuple,method=method, options=optiondict)
#     760
#     761
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     586                       callback=callback, **options)
#     587     elif meth == 'nelder-mead':
# --> 588         return _minimize_neldermead(fun, x0, args, callback, **options)
#     589     elif meth == 'powell':
#     590         return _minimize_powell(fun, x0, args, callback, **options)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     604         if fxr < fsim[0]:
#     605             xe = (1 + rho * chi) * xbar - rho * chi * sim[-1]
# --> 606             fxe = func(xe)
#     607
#     608             if fxe < fxr:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     324     def function_wrapper(*wrapper_args):
#     325         ncalls[0] += 1
# --> 326         return function(*(wrapper_args + args))
#     327
#     328     return ncalls, function_wrapper
#
# ~\gits\kernelkernel\mykern.py in MY_KDEpredictMSE(self, free_params, yin, yout, xin, xpr, modeldict, fixed_or_free_paramdict)
#     535
#     536
# --> 537         yhat_un_std=self.MY_KDEpredict(yin,yout,xin,xpr,modeldict,fixed_or_free_paramdict)
#     538         y_err=self.ydata-yhat_un_std
#     539         mse= np.mean(np.power(y_err,2))
#
# ~\gits\kernelkernel\mykern.py in MY_KDEpredict(self, yin, yout, xin, xpr, modeldict, fixed_or_free_paramdict)
#     598         if modeldict['Ndiff_type'] == 'product':
#     599             xbw = self.product_BWmaker(max_bw_Ndiff, fixed_or_free_paramdict, diffdict, modeldict,'x')
# --> 600             ybw = self.product_BWmaker(max_bw_Ndiff, fixed_or_free_paramdict, diffdict['ydiffdict'],modeldict,'y')
#     601         if modeldict['Ndiff_type'] == 'recursive':
#     602             xbw = self.recursive_BWmaker(max_bw_Ndiff, self.Ndiff_list_of_masks_x, fixed_or_free_paramdict, diffdict, modeldict,'x')
#
# ~\gits\kernelkernel\mykern.py in product_BWmaker(self, max_bw_Ndiff, fixed_or_free_paramdict, diffdict, modeldict, x_or_y)
#     148                                 np.ma.array(this_depth_data,mask=this_depth_mask),
#     149                                 this_depth_bw_param
# --> 150                                 )*deeper_depth_bw,
#     151                             normalize
#     152                             ),
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\ma\core.py in __mul__(self, other)
#    4096         if self._delegate_binop(other):
#    4097             return NotImplemented
# -> 4098         return multiply(self, other)
#    4099
#    4100     def __rmul__(self, other):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\ma\core.py in __call__(self, a, b, *args, **kwargs)
#    1016         with np.errstate():
#    1017             np.seterr(divide='ignore', invalid='ignore')
# -> 1018             result = self.f(da, db, *args, **kwargs)
#    1019         # Get the mask for the result
#    1020         (ma, mb) = (getmask(a), getmask(b))
#
# KeyboardInterrupt:

# %%
from bokeh.io import show, output_notebook#,curdoc,save, output_file
from bokeh.plotting import figure
#from bokeh.models import ColumnDataSource, Range1d, BBoxTileSource
#from bokeh.layouts import row
output_notebook()

# %%
#xgrid=np.linspace(1,n,n)

xgrid=x[:,0]
yhat=optimized_Ndiff_kernel.yhat_un_std
p=figure(title='y and yhat', plot_width=900, plot_height=500)
p.xaxis.axis_label = 'observations'
p.scatter(xgrid,y,size=10,color='blue',alpha=0.4,legend='y')
#p.line(xgrid,precip,color='blue',alpha=0.6,legend='precipitation')
p.scatter(xgrid,yhat,size=5,color='green',alpha=0.9,legend='yhat')
p.circle(xgrid,just_linreg.yhat,color='red',legend='just lin reg yhat')
p.line(xgrid,np.mean(y))
p.legend.location = "top_left"
p.yaxis.visible=False
show(p)

# %%
yhat.shape
print(data1.b)

# %%
print(yhat)

# %%
print(y)

# %%
ypredict=optimized_Ndiff_kernel.predict_tool(xvalidate,optimized_Ndiff_kernel.fixed_or_free_paramdict,modeldict1)
prediction_err=yvalidate-ypredict
prediction_mse=np.mean(prediction_err**2)

# %%
np.ma.count_masked(yhat)
