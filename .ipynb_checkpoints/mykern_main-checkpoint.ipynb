# %% [markdown]
# ### kernel density estimation and kernel regression for prediction
# This notebook is my first attempt to write down the ddiff and dddiff models that I have been working on

# %% [markdown]
# mixed recursive/iterative approach (rather than vectorized approach that is harder to generalize
# - create separate submodules for KDE and KDreg
#     - develop a system for storing differenced but unweighted data and the appropriate mask to lessen memory usage.
#         -1's or 0's depending on i/j/k/l/.... values
#     - figure out the deepest level requested by the user and levels that are less deep are just slices of the deeper model.
#         -scout out the tree to build the differenced dataset.
#
#
#  plot and compare
# on synthetic data, 1, 2, 3+ mixed distributions
# 1d - Ndiff vs gaussian kernel vs kernel_tunneling
# 2d -
#
#
# multidimensional x problem
# e.g., parameter treatment
# "product kernel approach" vs l2 "el two" (radial basis?)distance

# %% [markdown]
# #### generate a simple linear dataset y=xb+e
# ##### store validation data from same dataset too

# %% [markdown]
# ### create modeldict
# - 'Ndiff_type': refers to the mathematical form of Ndiff
#   - 'product'-Ndiff1 multiplied by Ndiff2
#   - 'recursive'-Ndiff1's bw is Ndiff 2
# - max_bw_Ndiff: is the depth of Ndiffs applied in estimating the bandwidth.
# - 'normalize_Ndiffwtsum':
#   - 'across' means sum across own level of kernelized-Ndiffs and divide by that sum (CDF approach)
#   - 'own_n' means for (n+k)diff where n+K=max_bw_Ndiff
# - Ndiff_bw_kern:
#   - rbfkern means use the radial basis function kernel
#   - 'product' means use product kernel like as in liu and yang eq1.
# - 'regression_model':
#   - 'NW' means use nadaraya-watson kernel regression
#   - 'full_logit' means local logit with all variables entering linearly
#   - 'rbf_logit' means local logit with 1 parameters: scaled l2 norm centered on zero
#  (globally or by i?). Is this a new idea?
# - outer_x_bw_form: if x is separated into blocks of rvars that are combined within a block using rbf kernel,
#   - 'one_for_all' - use same hx bw for all blocks
#   - 'one_per_block' - each block or rvars gets an hx
# - ykern_grid
#   - if int, then create int evnely spaced values from -3 to 3 (standard normal middle ~99%)
#   - 'no' means use original data points (self is masked when predicting self)
# - xkern_grid
#   - much like ykern_grid, but used less frequently since x's are typically pre-specified
# - product_kern_norm: when multiplying kernels across random variables, this parameter determines if each random variable has its kernels normalized before the product or not
#   - 'self' means each random variable has its kernels divided by the sum of kernels across the nout axis (the number of possibile values y is averaged over, whose probabilities sum to 1)
#   - 'own_n' means same as self, but divided by count of non-masked items in second to last, nout lenght dimension
#   - 'none' means no normalization prior to taking products across rvar kernels
# - hyper_param_form_dict is a nested dictionary
#   - Ndiff_exponent is the exponent wrapped around typically a sum of kernels for each Ndiff level
# after level 1 (i.e., (i-j) or centered, obvious/conventional level.)
#   - x_bandscale is the parameter specific to each variable (each x in X) used for prediction (y)
#   - Ndiff_depth_bw is used as the kernel's bandwidth (h) at each level of Ndiff including at level 1
#   - outer_x_bw vanilla bandwidth for the rbf or product kernel
#   - outer_y_bw vanilla bandwidth for y

# %%
import kernelcompare as kc
#from importlib import reload
test=kc.KernelCompare()

# %%
#test.run_kernel_list()

# %%
Ndiff_type_variations=('modeldict:Ndiff_type',['recursive','product'])
max_bw_Ndiff_variations=('modeldict:max_bw_Ndiff',[2])
Ndiff_start_variations=('modeldict:Ndiff_start',[0])

product_kern_norm_variations=('modeldict:product_kern_norm',['self','own_n'])#include None too?
normalize_Ndiffwtsum_variations=('modeldict:normalize_Ndiffwtsum',['own_n','across'])
optdict_variation_list=[Ndiff_type_variations,max_bw_Ndiff_variations,Ndiff_start_variations]

# %%
#a reminder of the options:
#datagen_dict={'train_n':60,'n':200, 'param_count':param_count,'seed':1, 'ftype':'linear', 'evar':1}
#datagen_variation_list=[test.build_quadratic_datagen_dict_override()] 

train_n_variations=('train_n',[30])#so I don't crash my 10 year old laptop at home
#train_n_variations=('train_n:',[30,45,60])
ftype_variations=('ftype',['linear,quadratic'])
param_count_variations=('param_count',[1,2])
#need to add block capability to datagen so we can repeat optimization with new training data.

datagen_variation_list=[train_n_variations,ftype_variations,param_count_variations]

# %%
#print(os.getcwd())
#test.open_condense_resave('model_save',verbose=0)
#test.open_condense_resave('condensed_model_save',verbose=1)

# %%
from os import getcwd
thisdir=getcwd()
test.merge_and_condense_saved_models(merge_directory=thisdir,save_directory=thisdir,condense=1,verbose=1)
# Out:
# here ['model_save', 'condensed_model_save', 'final_model_save']
# file_i:model_save has 10 saved model(s)
# 0.0%,5.2631578947368425%,10.526315789473685%,15.789473684210526%,21.05263157894737%,26.31578947368421%,31.57894736842105%,36.8421052631579%,42.10526315789474%,47.36842105263158%,52.63157894736842%,57.89473684210526%,63.1578947368421%,68.42105263157895%,73.6842105263158%,78.94736842105263%,84.21052631578948%,89.47368421052632%,94.73684210526316%,len(final_keep_list):4
# file_i:condensed_model_save has 20 saved model(s)
# 0.0%,2.5641025641025643%,5.128205128205129%,7.6923076923076925%,10.256410256410257%,12.820512820512821%,15.384615384615385%,17.94871794871795%,20.512820512820515%,23.076923076923077%,25.641025641025642%,28.205128205128204%,30.76923076923077%,33.333333333333336%,35.8974358974359%,38.46153846153846%,41.02564102564103%,43.58974358974359%,46.15384615384615%,48.717948717948715%,51.282051282051285%,53.84615384615385%,56.41025641025641%,58.97435897435897%,61.53846153846154%,64.1025641025641%,66.66666666666667%,69.23076923076923%,71.7948717948718%,74.35897435897436%,76.92307692307692%,79.48717948717949%,82.05128205128206%,84.61538461538461%,87.17948717948718%,89.74358974358974%,92.3076923076923%,94.87179487179488%,97.43589743589743%,len(final_keep_list):4
# file_i:final_model_save has 16 saved model(s)
# 0.0%,33.333333333333336%,66.66666666666667%,len(final_keep_list):3
# 0.0%,2.5641025641025643%,5.128205128205129%,7.6923076923076925%,10.256410256410257%,12.820512820512821%,15.384615384615385%,17.94871794871795%,20.512820512820515%,23.076923076923077%,25.641025641025642%,28.205128205128204%,30.76923076923077%,33.333333333333336%,35.8974358974359%,38.46153846153846%,41.02564102564103%,43.58974358974359%,46.15384615384615%,48.717948717948715%,51.282051282051285%,53.84615384615385%,56.41025641025641%,58.97435897435897%,61.53846153846154%,64.1025641025641%,66.66666666666667%,69.23076923076923%,71.7948717948718%,74.35897435897436%,76.92307692307692%,79.48717948717949%,82.05128205128206%,84.61538461538461%,87.17948717948718%,89.74358974358974%,92.3076923076923%,94.87179487179488%,97.43589743589743%,len(final_keep_list):4

# %%
testrun=test.prep_model_list(optdict_variation_list=optdict_variation_list,datagen_variation_list=datagen_variation_list)
print(f'len(testrun){len(testrun)}')
print(f'testrun[0]{testrun[0]}')
print(f'testrun[-1]{testrun[-1]}')
# Out:
# len(datagen_dict_list):24
# len(testrun)576
# testrun[0]{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.01, 'fatol': 0.1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.3, 0.3]), 'x_bandscale': array([1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.5])}, 'modeldict': {'Ndiff_type': 'recursive', 'param_count': 2, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}}, 'datagen_dict': {'train_n': 30, 'n': 200, 'param_count': 2, 'seed': 1, 'ftype': 'linear', 'evar': 1}}
# testrun[-1]{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.01, 'fatol': 0.1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.3, 0.3]), 'x_bandscale': array([1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.5])}, 'modeldict': {'Ndiff_type': 'recursive', 'param_count': 2, 'Ndiff_start': 0, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}}, 'datagen_dict': {'train_n': 30, 'n': 200, 'param_count': 2, 'seed': 1, 'ftype': 'linear,quadratic', 'evar': 1}}

# %%
runlist=[2,3]
#a_rundict=testrun[100]#this produced the Ndiff_exponent error for recursive Ndiff
for idx in range(0,300,10):
    print(f'run number:{idx}')
    a_rundict=testrun[idx]
    print(f'a_rundict{a_rundict}')
    optimizedict=a_rundict['optimizedict']
    datagen_dict=a_rundict['datagen_dict']

    try:
        test.do_monte_opt(optimizedict,datagen_dict,force_start_params=0)
        test.merge_and_condense_saved_models(merge_directory=None,save_directory=None,condense=None,verbose=None)
    except:pass
# Out:
# a_rundict{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.01, 'fatol': 0.1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.3, 0.3]), 'x_bandscale': array([1., 1.]), 'outer_x_bw': array([2.7]), 'outer_y_bw': array([2.2]), 'Ndiff_depth_bw': array([0.5, 0.5]), 'y_bandscale': array([1.5])}, 'modeldict': {'Ndiff_type': 'recursive', 'param_count': 2, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}}, 'datagen_dict': {'train_n': 30, 'n': 200, 'param_count': 2, 'seed': 1, 'ftype': 'linear', 'evar': 1}}
# in saved_filename:condensed_model_save, len(doubledict_list):39,len(saved_dict_list):39
# --------------------------------help_start is triggered---------------------------
# --------------help_start with partial match triggered----------------
# -----partial match is looking for a partial match------
# 9 partial matches found only after substituting {'datagen_dict': {'train_n': 30}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# optimization dict with lowest mse:26.479610401899272, n:25was last saved20191116-084923
# best_dict:{'mse': 26.479610401899272, 'xdata': array([[-2.5563435 , -3.64593724],
#        [ 0.23081526, -6.10307739],
#        [ 1.98962353, -3.0224138 ],
#        [-0.86192181, -1.99874075],
#        [ 1.42421587, -5.62028142],
#        [-2.14483441, -2.26810871],
#        [ 0.76753888, -3.69978253],
#        [-1.84485642, -3.25571684],
#        [-1.41557251, -0.33436957],
#        [-3.70123835,  0.78944742],
#        [ 0.30318144, -0.49501132],
#        [ 0.3017119 , -2.86745572],
#        [-1.74578045, -3.37153887],
#        [-2.03577616, -0.43928907],
#        [-2.8833215 , -2.29350705],
#        [-2.8743454 , -3.19041128],
#        [-2.84249226, -1.5253292 ],
#        [-3.7346207 , -1.0311686 ],
#        [ 1.81960435, -0.01591168],
#        [-1.8836711 , -3.27525793],
#        [-2.99431659,  1.8849092 ],
#        [-1.39838449, -2.77399129],
#        [-1.11816903,  2.70051027],
#        [-1.2596821 , -0.26559378],
#        [-0.89965936, -2.20449969]]), 'ydata': array([-24.62107866, -32.92393465, -12.57809272, -11.62982371,
#        -31.01572349, -16.72848994, -18.21200149, -20.11983952,
#         -3.11909872,   1.39056333,   1.39654418, -14.661963  ,
#        -24.13429711,  -6.48485309, -18.30554416, -21.77531739,
#        -12.52668742, -13.75050084,   5.31497281, -19.8055284 ,
#          6.94601735, -18.19068636,  18.02134768,  -2.05951734,
#        -13.50547398]), 'params': {'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 4)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (4, 6)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (6, 7)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 8)}, 'y_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (8, 9)}, 'free_params': array([0.31139312, 0.30183229, 0.9799569 , 1.1128355 , 0.46087039,
#        0.45444189, 2.76012313, 2.0338125 , 1.9307416 ]), 'fixed_params': array([], dtype=float64)}, 'modeldict': {'Ndiff_type': 'recursive', 'param_count': 2, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}, 'when_saved': '20191116-084923', 'datagen_dict': {'train_n': 25, 'n': 200, 'param_count': 2, 'seed': 1, 'ftype': 'linear', 'evar': 1}}
# overriding start parameters with saved parameters
# param_valdict:{'Ndiff_exponent': array([0.31139312, 0.30183229]), 'x_bandscale': array([0.9799569, 1.1128355]), 'outer_x_bw': array([2.76012313]), 'outer_y_bw': array([2.0338125]), 'Ndiff_depth_bw': array([0.46087039, 0.45444189]), 'y_bandscale': array([1.9307416])}
# setup_fixed_or_free_paramdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 4)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (4, 6)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (6, 7)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 8)}, 'y_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (8, 9)}, 'free_params': 'outside', 'fixed_params': array([], dtype=float64)}
# modeldict:{'Ndiff_type': 'recursive', 'param_count': 2, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}
# saved to model_save at about 20191117-104827 with mse=68.4036981327531
# saved to model_save at about 20191117-104833 with mse=68.4036981327531
# save_interval changed to 9
# saved to model_save at about 20191117-104912 with mse=52.71312062574626
# saved to model_save at about 20191117-105002 with mse=47.85214745623339
# saved to model_save at about 20191117-105051 with mse=38.06173459182511
# saved to model_save at about 20191117-105140 with mse=25.787544130771586
# saved to model_save at about 20191117-105230 with mse=25.625145388408193
# saved to model_save at about 20191117-105319 with mse=25.148823109086106
# saved to model_save at about 20191117-105408 with mse=25.148823109086106
# saved to model_save at about 20191117-105457 with mse=25.3503868005112
# saved to model_save at about 20191117-105547 with mse=24.938823456273322
# saved to model_save at about 20191117-105636 with mse=24.938823456273322
# saved to model_save at about 20191117-105726 with mse=25.129396642798895
# saved to model_save at about 20191117-105815 with mse=25.048356524942857
# saved to model_save at about 20191117-105904 with mse=25.048356524942857
# saved to model_save at about 20191117-105953 with mse=25.091378253260757
# saved to model_save at about 20191117-110043 with mse=25.08779662349587
# saved to model_save at about 20191117-110132 with mse=25.07161440266268
# saved to model_save at about 20191117-110222 with mse=25.063233407917817
# saved to model_save at about 20191117-110312 with mse=25.03197790067335
# saved to model_save at about 20191117-110401 with mse=25.03197790067335
# saved to model_save at about 20191117-110451 with mse=25.05538457616281
# saved to model_save at about 20191117-110540 with mse=25.047493899260992
# saved to model_save at about 20191117-110630 with mse=25.047493899260992
# saved to model_save at about 20191117-110720 with mse=25.054559137246944
# saved to model_save at about 20191117-110809 with mse=25.548109761396645
# saved to model_save at about 20191117-110859 with mse=25.202434238543596
# saved to model_save at about 20191117-110948 with mse=25.202434238543596
# saved to model_save at about 20191117-111038 with mse=25.222950628834514
# saved to model_save at about 20191117-111128 with mse=25.222950628834514
# saved to model_save at about 20191117-111217 with mse=25.22444537625519
# saved to model_save at about 20191117-111307 with mse=25.22444537625519
# saved to model_save at about 20191117-111356 with mse=25.240977532642724
# saved to model_save at about 20191117-111446 with mse=24.877412917826874
# saved to model_save at about 20191117-111536 with mse=24.877412917826874
# saved to model_save at about 20191117-111626 with mse=24.92549274980218
# saved to model_save at about 20191117-111715 with mse=24.919986259799835
# saved to model_save at about 20191117-111805 with mse=24.91512611988911
# saved to model_save at about 20191117-111855 with mse=24.910833257440764
# saved to model_save at about 20191117-111944 with mse=24.90703891199609
# saved to model_save at about 20191117-112034 with mse=24.90703891199609
# saved to model_save at about 20191117-112124 with mse=24.90368316807537
# saved to model_save at about 20191117-112213 with mse=24.900713718787916
# saved to model_save at about 20191117-112302 with mse=24.898084820261104
# saved to model_save at about 20191117-112352 with mse=24.895756404419537
# saved to model_save at about 20191117-112442 with mse=24.893693323602744
# saved to model_save at about 20191117-112532 with mse=24.893693323602744
# saved to model_save at about 20191117-112621 with mse=24.89186470537535
# saved to model_save at about 20191117-112711 with mse=24.89024339974093
# saved to model_save at about 20191117-112801 with mse=24.8888055041341
# saved to model_save at about 20191117-112852 with mse=24.887529954105396
# saved to model_save at about 20191117-112942 with mse=24.887529954105396
# saved to model_save at about 20191117-113032 with mse=24.886398169677417
# saved to model_save at about 20191117-113122 with mse=24.885393749046944
# saved to model_save at about 20191117-113212 with mse=24.874936524691563
# saved to model_save at about 20191117-113257 with mse=24.89482270970932
# saved to final_model_save at about 20191117-113257 with mse=24.872247588735586
# lastparamdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 4)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (4, 6)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (6, 7)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 8)}, 'y_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (8, 9)}, 'free_params': array([0.29049234, 0.30420858, 0.96291888, 1.16194233, 0.46622015,
#        0.46739998, 2.80012102, 2.28620733, 1.72543812]), 'fixed_params': array([], dtype=float64)}
# here ['model_save', 'condensed_model_save', 'final_model_save']
# a_rundict{'optimizedict': {'opt_settings_dict': {'method': 'Nelder-Mead', 'options': {'xatol': 0.01, 'fatol': 0.1, 'adaptive': True}, 'help_start': 1, 'partial_match': 1}, 'hyper_param_dict': {'Ndiff_exponent': array([0.31139312, 0.30183229]), 'x_bandscale': array([0.9799569, 1.1128355]), 'outer_x_bw': array([2.76012313]), 'outer_y_bw': array([2.0338125]), 'Ndiff_depth_bw': array([0.46087039, 0.45444189]), 'y_bandscale': array([1.9307416])}, 'modeldict': {'Ndiff_type': 'product', 'param_count': 2, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}}, 'datagen_dict': {'train_n': 30, 'n': 200, 'param_count': 2, 'seed': 1, 'ftype': 'linear', 'evar': 1}}
# in saved_filename:condensed_model_save, len(doubledict_list):319,len(saved_dict_list):319
# --------------------------------help_start is triggered---------------------------
# --------------help_start with partial match triggered----------------
# -----partial match is looking for a partial match------
# 46 partial matches found only after substituting {'datagen_dict': {'train_n': 30}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# ...
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# -----partial match is looking for a partial match------
# 1 partial matches found only after substituting {'datagen_dict': {'seed': 1}}
# optimization dict with lowest mse:1.324128444437071, n:25was last saved20191117-041517
# best_dict:{'mse': 1.324128444437071, 'xdata': array([[-2.5563435 , -3.64593724],
#        [ 0.23081526, -6.10307739],
#        [ 1.98962353, -3.0224138 ],
#        [-0.86192181, -1.99874075],
#        [ 1.42421587, -5.62028142],
#        [-2.14483441, -2.26810871],
#        [ 0.76753888, -3.69978253],
#        [-1.84485642, -3.25571684],
#        [-1.41557251, -0.33436957],
#        [-3.70123835,  0.78944742],
#        [ 0.30318144, -0.49501132],
#        [ 0.3017119 , -2.86745572],
#        [-1.74578045, -3.37153887],
#        [-2.03577616, -0.43928907],
#        [-2.8833215 , -2.29350705],
#        [-2.8743454 , -3.19041128],
#        [-2.84249226, -1.5253292 ],
#        [-3.7346207 , -1.0311686 ],
#        [ 1.81960435, -0.01591168],
#        [-1.8836711 , -3.27525793],
#        [-2.99431659,  1.8849092 ],
#        [-1.39838449, -2.77399129],
#        [-1.11816903,  2.70051027],
#        [-1.2596821 , -0.26559378],
#        [-0.89965936, -2.20449969]]), 'ydata': array([-24.62107866, -32.92393465, -12.57809272, -11.62982371,
#        -31.01572349, -16.72848994, -18.21200149, -20.11983952,
#         -3.11909872,   1.39056333,   1.39654418, -14.661963  ,
#        -24.13429711,  -6.48485309, -18.30554416, -21.77531739,
#        -12.52668742, -13.75050084,   5.31497281, -19.8055284 ,
#          6.94601735, -18.19068636,  18.02134768,  -2.05951734,
#        -13.50547398]), 'params': {'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 4)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (4, 6)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (6, 7)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 8)}, 'y_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (8, 9)}, 'free_params': array([ 0.47874021,  0.27987918,  1.73121777, -0.01937305,  0.92632233,
#         0.55584019,  5.03487151,  0.04369755, -0.12274784]), 'fixed_params': array([], dtype=float64)}, 'modeldict': {'Ndiff_type': 'product', 'param_count': 2, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}, 'when_saved': '20191117-041517', 'datagen_dict': {'train_n': 25, 'n': 200, 'param_count': 2, 'seed': 1, 'ftype': 'linear', 'evar': 1}, 'minimize_obj':  final_simplex: (array([[ 0.4780403 ,  0.27961658,  1.73391689, -0.02330972,  0.92635013,
#          0.55562796,  5.0428011 ,  0.04494543, -0.12102529],
#        [ 0.47874021,  0.27987918,  1.73121777, -0.01937305,  0.92632233,
#          0.55584019,  5.03487151,  0.04369755, -0.12274784],
#        [ 0.47942471,  0.28029198,  1.7330896 , -0.02311532,  0.92701004,
#          0.55565403,  5.04888235,  0.03767993, -0.12730435],
#        [ 0.47803282,  0.27940435,  1.73383572, -0.0235738 ,  0.92530076,
#          0.55455733,  5.04406639,  0.05175618, -0.11733172],
#        [ 0.4788122 ,  0.28026093,  1.73294253, -0.02257514,  0.925657  ,
#          0.55493079,  5.04683076,  0.0452856 , -0.12288543],
#        [ 0.47914566,  0.28023911,  1.7338827 , -0.02501729,  0.92600282,
#          0.55418048,  5.05248356,  0.04590379, -0.12267732],
#        [ 0.47841974,  0.27936909,  1.73341385, -0.02619261,  0.92785672,
#          0.55561513,  5.03374078,  0.05088971, -0.11851697],
#        [ 0.47881036,  0.27974238,  1.73426544, -0.02784336,  0.92739055,
#          0.55510284,  5.04304046,  0.04924241, -0.12029276],
#        [ 0.47959922,  0.280726  ,  1.73009763, -0.02057398,  0.92473081,
#          0.55466866,  5.04744068,  0.04504963, -0.12444596],
#        [ 0.48011685,  0.28088116,  1.7290571 , -0.01912569,  0.92631609,
#          0.55546333,  5.03975123,  0.04159729, -0.12676987]]), array([1.32412844, 1.3244884 , 1.32450054, 1.3248532 , 1.32496975,
#        1.32497088, 1.32509045, 1.32519177, 1.32519212, 1.32520613]))
#            fun: 1.324128444437071
#        message: 'Optimization terminated successfully.'
#           nfev: 914
#            nit: 594
#         status: 0
#        success: True
#              x: array([ 0.4780403 ,  0.27961658,  1.73391689, -0.02330972,  0.92635013,
#         0.55562796,  5.0428011 ,  0.04494543, -0.12102529])}
# overriding start parameters with saved parameters
# param_valdict:{'Ndiff_exponent': array([0.47874021, 0.27987918]), 'x_bandscale': array([ 1.73121777, -0.01937305]), 'outer_x_bw': array([5.03487151]), 'outer_y_bw': array([0.04369755]), 'Ndiff_depth_bw': array([0.92632233, 0.55584019]), 'y_bandscale': array([-0.12274784])}
# setup_fixed_or_free_paramdict:{'Ndiff_exponent': {'fixed_or_free': 'free', 'const': 'free', 'location_idx': (0, 2)}, 'x_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (2, 4)}, 'Ndiff_depth_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (4, 6)}, 'outer_x_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (6, 7)}, 'outer_y_bw': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (7, 8)}, 'y_bandscale': {'fixed_or_free': 'free', 'const': 'non-neg', 'location_idx': (8, 9)}, 'free_params': 'outside', 'fixed_params': array([], dtype=float64)}
# modeldict:{'Ndiff_type': 'product', 'param_count': 2, 'Ndiff_start': 1, 'max_bw_Ndiff': 2, 'normalize_Ndiffwtsum': 'own_n', 'xkern_grid': 'no', 'ykern_grid': 61, 'outer_kern': 'gaussian', 'Ndiff_bw_kern': 'rbfkern', 'outer_x_bw_form': 'one_for_all', 'regression_model': 'NW', 'product_kern_norm': 'self', 'hyper_param_form_dict': {'Ndiff_exponent': 'free', 'x_bandscale': 'non-neg', 'Ndiff_depth_bw': 'non-neg', 'outer_x_bw': 'non-neg', 'outer_y_bw': 'non-neg', 'y_bandscale': 'non-neg'}}
# saved to model_save at about 20191117-113305 with mse=1.871791465438139
# saved to model_save at about 20191117-113312 with mse=1.871791465438139
# save_interval changed to 4
# saved to model_save at about 20191117-113327 with mse=1.871791465438139
# saved to model_save at about 20191117-113356 with mse=1.7496227700198166
# saved to model_save at about 20191117-113426 with mse=1.7496227700198166
# saved to model_save at about 20191117-113455 with mse=1.8400229479161383
# saved to model_save at about 20191117-113524 with mse=2.2454561067560195
# saved to model_save at about 20191117-113552 with mse=2.048049905814735
# saved to model_save at about 20191117-113621 with mse=1.9760576973011363
# saved to model_save at about 20191117-113649 with mse=1.8459353775815797
# saved to model_save at about 20191117-113718 with mse=1.8457949431680265
# saved to model_save at about 20191117-113746 with mse=1.7191592902232025
# saved to model_save at about 20191117-113815 with mse=1.7191592902232025
# saved to model_save at about 20191117-113843 with mse=1.7308981913135333
# saved to model_save at about 20191117-113911 with mse=1.737270302915749
# saved to model_save at about 20191117-113940 with mse=1.7159689746777993
# saved to model_save at about 20191117-114008 with mse=1.7159689746777993
# saved to model_save at about 20191117-114037 with mse=1.6628509149579578
# saved to model_save at about 20191117-114105 with mse=1.6612267757399652
# saved to model_save at about 20191117-114133 with mse=1.6612267757399652
# saved to model_save at about 20191117-114202 with mse=1.6500896248783294
# saved to model_save at about 20191117-114230 with mse=1.6500896248783294
# saved to model_save at about 20191117-114258 with mse=1.6353702846071398
# saved to model_save at about 20191117-114327 with mse=1.6353702846071398
# saved to model_save at about 20191117-114355 with mse=1.6382775091741402
# saved to model_save at about 20191117-114424 with mse=1.6353274349615625
# saved to model_save at about 20191117-114452 with mse=1.6353274349615625
# saved to model_save at about 20191117-114520 with mse=1.6013910167069338
# saved to model_save at about 20191117-114549 with mse=1.5993221438752543
# saved to model_save at about 20191117-114617 with mse=1.5993221438752543
# saved to model_save at about 20191117-114646 with mse=1.6149042969624383
# saved to model_save at about 20191117-114714 with mse=1.6007355206977503
# saved to model_save at about 20191117-114743 with mse=1.5940983327282654
# saved to model_save at about 20191117-114813 with mse=1.5940983327282654
# saved to model_save at about 20191117-114842 with mse=1.6051760914015645
# saved to model_save at about 20191117-114911 with mse=1.592575747934237
# saved to model_save at about 20191117-114940 with mse=1.592575747934237
# saved to model_save at about 20191117-115008 with mse=1.593426557307088
# saved to model_save at about 20191117-115037 with mse=1.5816916749706882
# saved to model_save at about 20191117-115105 with mse=1.5816916749706882
# saved to model_save at about 20191117-115133 with mse=1.5823251695853422
# saved to model_save at about 20191117-115202 with mse=1.5793916757249247
# saved to model_save at about 20191117-115230 with mse=1.5753091068794474
# saved to model_save at about 20191117-115258 with mse=1.5743332930792997
# saved to model_save at about 20191117-115327 with mse=1.5743332930792997
# saved to model_save at about 20191117-115356 with mse=1.568514796141069
# saved to model_save at about 20191117-115425 with mse=1.5653938295817909
# saved to model_save at about 20191117-115453 with mse=1.5614084837163384
# saved to model_save at about 20191117-115522 with mse=1.5581610724551147
# saved to model_save at about 20191117-115550 with mse=1.5577768297484635
# saved to model_save at about 20191117-115619 with mse=1.552725835394347
# saved to model_save at about 20191117-115647 with mse=1.5505101289549907
# saved to model_save at about 20191117-115715 with mse=1.5505101289549907
# saved to model_save at about 20191117-115744 with mse=1.547140639287087
# saved to model_save at about 20191117-115812 with mse=1.546380999001109
# saved to model_save at about 20191117-115841 with mse=1.5401564384068795
# saved to model_save at about 20191117-115909 with mse=1.5387675213492116
# saved to model_save at about 20191117-115937 with mse=1.5381770530382461
# saved to model_save at about 20191117-120006 with mse=1.5362137814428671
# saved to model_save at about 20191117-120034 with mse=1.5353942220667345
# saved to model_save at about 20191117-120103 with mse=1.532083680128386
# saved to model_save at about 20191117-120131 with mse=1.531992939828336
# saved to model_save at about 20191117-120200 with mse=1.531992939828336
# saved to model_save at about 20191117-120228 with mse=1.5325630995845183
# saved to model_save at about 20191117-120257 with mse=1.5338258708345505
# saved to model_save at about 20191117-120325 with mse=1.5312443851186954
# saved to model_save at about 20191117-120354 with mse=1.5312443851186954
# saved to model_save at about 20191117-120422 with mse=1.5305224601074066
# saved to model_save at about 20191117-120451 with mse=1.5305224601074066
# saved to model_save at about 20191117-120519 with mse=1.5307649754203578
# saved to model_save at about 20191117-120548 with mse=1.5301335548885826
# saved to model_save at about 20191117-120616 with mse=1.5301335548885826
# saved to model_save at about 20191117-120645 with mse=1.5275915014743375
# saved to model_save at about 20191117-120713 with mse=1.5275915014743375
# saved to model_save at about 20191117-120742 with mse=1.5275186674042696
# saved to model_save at about 20191117-120811 with mse=1.527125893129965
# saved to model_save at about 20191117-120839 with mse=1.5260162451965678
# saved to model_save at about 20191117-120908 with mse=1.5240735567308912
# saved to model_save at about 20191117-120936 with mse=1.5228461993199551
# saved to model_save at about 20191117-121005 with mse=1.5212731678967988
# saved to model_save at about 20191117-121033 with mse=1.5208883603949352
# saved to model_save at about 20191117-121102 with mse=1.5191717935522673
# saved to model_save at about 20191117-121130 with mse=1.5181208799792636
# saved to model_save at about 20191117-121159 with mse=1.515691736981601
# saved to model_save at about 20191117-121227 with mse=1.5145395186108561
# saved to model_save at about 20191117-121257 with mse=1.5141010167401714
# saved to model_save at about 20191117-121326 with mse=1.5114365754675234
# saved to model_save at about 20191117-121354 with mse=1.5114365754675234
# saved to model_save at about 20191117-121421 with mse=1.5096266617259793
# saved to model_save at about 20191117-121448 with mse=1.5096266617259793
# saved to model_save at about 20191117-121516 with mse=1.5068575103593047
# saved to model_save at about 20191117-121544 with mse=1.5068575103593047
# saved to model_save at about 20191117-121611 with mse=1.5046348160291616
# saved to model_save at about 20191117-121639 with mse=1.5036045326948582
# saved to model_save at about 20191117-121706 with mse=1.5036045326948582
# saved to model_save at about 20191117-121733 with mse=1.5018575052506695
# saved to model_save at about 20191117-121801 with mse=1.5005481438930326
# saved to model_save at about 20191117-121829 with mse=1.499734370843678
# saved to model_save at about 20191117-121857 with mse=1.4978986151142235
# saved to model_save at about 20191117-121925 with mse=1.4965918487906626
# saved to model_save at about 20191117-121952 with mse=1.4954324807539237
# saved to model_save at about 20191117-122020 with mse=1.4924920912005812
# saved to model_save at about 20191117-122047 with mse=1.4914408084579807
# saved to model_save at about 20191117-122115 with mse=1.490907802745852
# saved to model_save at about 20191117-122142 with mse=1.4904880485635492
# saved to model_save at about 20191117-122210 with mse=1.4877365276341086
# saved to model_save at about 20191117-122237 with mse=1.4877365276341086
# saved to model_save at about 20191117-122305 with mse=1.4842274038523802
# saved to model_save at about 20191117-122333 with mse=1.4838599362958624
# saved to model_save at about 20191117-122401 with mse=1.4818710606505658
# saved to model_save at about 20191117-122429 with mse=1.4783521788839167
# saved to model_save at about 20191117-122456 with mse=1.4783521788839167
# saved to model_save at about 20191117-122524 with mse=1.4777802937619373
# saved to model_save at about 20191117-122552 with mse=1.4752164449293226
# saved to model_save at about 20191117-122620 with mse=1.4732911474676418
# saved to model_save at about 20191117-122648 with mse=1.4717639004983525
# saved to model_save at about 20191117-122716 with mse=1.4689763186226084
# saved to model_save at about 20191117-122743 with mse=1.4689763186226084
# saved to model_save at about 20191117-122812 with mse=1.4668872899165846
# saved to model_save at about 20191117-122839 with mse=1.4645922113534158
# saved to model_save at about 20191117-122907 with mse=1.4645922113534158
# saved to model_save at about 20191117-122936 with mse=1.462679515598996
# saved to model_save at about 20191117-123005 with mse=1.4614686244011417
# saved to model_save at about 20191117-123034 with mse=1.4589521146954445
# saved to model_save at about 20191117-123103 with mse=1.4586630970035563

# %% [markdown]
# #-----------------Calibrate/Optimize--------

# %%
'''import myreg
x=test.train_x
y=test.train_y
xfull=np.concatenate([np.ones([x.shape[0],1]),x],axis=1)
just_linreg=myreg.reg(y,xfull)
just_linreg.myreg()
print('linreg_mse:',just_linreg.mse)'''

# %%
from bokeh.io import show, output_notebook#,curdoc,save, output_file
from bokeh.plotting import figure
#from bokeh.models import ColumnDataSource, Range1d, BBoxTileSource
#from bokeh.layouts import row
output_notebook()

# %%
#xgrid=np.linspace(1,n,n)
x=quad_misspec.train_x
y=quad_misspec.train_y


xgrid=x[:,0]
yhat=quad_misspec.optimize_obj.yhat_un_std
p=figure(title='y and yhat', plot_width=900, plot_height=500)
p.xaxis.axis_label = 'observations'
p.scatter(xgrid,y,size=10,color='blue',alpha=0.4,legend='y')
#p.line(xgrid,precip,color='blue',alpha=0.6,legend='precipitation')
p.scatter(xgrid,yhat,size=5,color='green',alpha=0.9,legend='yhat')
p.circle(xgrid,just_linreg.yhat,color='red',legend='just lin reg yhat')
p.line(xgrid,np.mean(y))
p.legend.location = "top_left"
#p.yaxis.visible=False
show(p)

# %%
print(yhat)
print(y)

# %%
ypredict=optimized_Ndiff_kernel.predict_tool(xvalidate,optimized_Ndiff_kernel.fixed_or_free_paramdict,modeldict1)
prediction_err=yvalidate-ypredict
prediction_mse=np.mean(prediction_err**2)

# %%
np.ma.count_masked(yhat)

# %% [markdown]
# ## class toolcompare(object):
