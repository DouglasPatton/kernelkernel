# %% [markdown]
# ### kernel density estimation and kernel regression for prediction
# This notebook is my first attempt to write down the ddiff and dddiff models that I have been working on

# %% [markdown]
# mixed recursive/iterative approach (rather than vectorized approach that is harder to generalize
# - create separate submodules for KDE and KDreg
#     - develop a system for storing differenced but unweighted data and the appropriate mask to lessen memory usage.
#         -1's or 0's depending on i/j/k/l/.... values
#     - figure out the deepest level requested by the user and levels that are less deep are just slices of the deeper model.
#         -scout out the tree to build the differenced dataset.
#
#
#  plot and compare
# on synthetic data, 1, 2, 3+ mixed distributions
# 1d - Ndiff vs gaussian kernel vs kernel_tunneling
# 2d -
#
#
# multidimensional x problem
# e.g., parameter treatment
# "product kernel approach" vs l2 "el two" (radial basis?)distance

# %%
import numpy as np

# %% [markdown]
# #### generate a simple linear dataset y=xb+e
# ##### store validation data from same dataset too

# %%
import data_gen as dg
data1=dg.data_gen(data_shape=(500,2),seed=1)
#xdata=data1.x[:,:-1]#drop last x
size=57
xdata=data1.x[0:size,:]
ydata=data1.y[0:size]
y=ydata
xfull=xdata
x=xdata[:,1:] #drop first column of x (all 1's)
e=data1.e
n,p=x.shape


xvalidate=data1.x[100:500,1:]
yvalidate=data1.y[100:500]

# %% [markdown]
# ### create modeldict
# - 'Ndiff_type': refers to the mathematical form of Ndiff
#   - 'product'-Ndiff1 multiplied by Ndiff2
#   - 'recursive'-Ndiff1's bw is Ndiff 2
# - max_bw_Ndiff: is the depth of Ndiffs applied in estimating the bandwidth.
# - 'normalize_Ndiffwtsum':
#   - 'across' means sum across own level of kernelized-Ndiffs and divide by that sum (CDF approach)
#   - 'own_n' means for (n+k)diff where n+K=max_bw_Ndiff
# - Ndiff_bw_kern:
#   - rbfkern means use the radial basis function kernel
#   - 'product' means use product kernel like as in liu and yang eq1.
# - 'regression_model':
#   - 'NW' means use nadaraya-watson kernel regression
#   - 'full_logit' means local logit with all variables entering linearly
#   - 'rbf_logit' means local logit with 1 parameters: scaled l2 norm centered on zero
#  (globally or by i?). Is this a new idea?
# - outer_x_bw_form: if x is separated into blocks of rvars that are combined within a block using rbf kernel,
#   - 'one_for_all' - use same hx bw for all blocks
#   - 'one_per_block' - each block or rvars gets an hx
# - ykern_grid
#   - if int, then create int evnely spaced values from -3 to 3 (standard normal middle ~99%)
#   - 'no' means use original data points (self is masked when predicting self)
# - xkern_grid
#   - much like ykern_grid, but used less frequently since x's are typically pre-specified
# - product_kern_norm: when multiplying kernels across random variables, this parameter determines if each random variable has its kernels normalized before the product or not
#   - 'self' means each random variable has its kernels divided by the sum of kernels across the nout axis (the number of possibile values y is averaged over, whose probabilities sum to 1)
#   - 'own_n' means same as self, but divided by count of non-masked items in second to last, nout lenght dimension
#   - 'none' means no normalization prior to taking products across rvar kernels
# - hyper_param_form_dict is a nested dictionary
#   - Ndiff_exponent is the exponent wrapped around typically a sum of kernels for each Ndiff level
# after level 1 (i.e., (i-j) or centered, obvious/conventional level.)
#   - x_bandscale is the parameter specific to each variable (each x in X) used for prediction (y)
#   - Ndiff_depth_bw is used as the kernel's bandwidth (h) at each level of Ndiff including at level 1
#   - outer_x_bw vanilla bandwidth for the rbf or product kernel
#   - outer_y_bw vanilla bandwidth for y

# %%
max_bw_Ndiff=2
Ndiff_start=2
Ndiff_param_count=max_bw_Ndiff-(Ndiff_start-1)
modeldict1={
    'Ndiff_type':'product',
    'Ndiff_start':Ndiff_start,
    'max_bw_Ndiff':max_bw_Ndiff,
    'normalize_Ndiffwtsum':'own_n',
    'xkern_grid':'no',
    'ykern_grid':'no',
    'outer_kern':'gaussian',
    'Ndiff_bw_kern':'rbfkern',
    'outer_x_bw_form':'one_for_all',
    'regression_model':'NW',
    'product_kern_norm':'self',
    'hyper_param_form_dict':{
        'Ndiff_exponent':'free',
        'x_bandscale':'non-neg',
        'Ndiff_depth_bw':'non-neg',
        'outer_x_bw':'non-neg',
        'outer_y_bw':'non-neg',
        'y_bandscale':'non-neg'
        }
    }

modeldict1['ykern_grid']=40#override
#modeldict1['product_kern_norm']='none'

#set starting or fixed values for hyper parameters

#if max_bw_Ndiff>0:onethenzeros[0]=1
hyper_paramdict1={
    'Ndiff_exponent':np.zeros([Ndiff_param_count,])+.05,
    'x_bandscale':.1*np.ones([p,]),
    'outer_x_bw':np.array([0.3,]),
    'outer_y_bw':np.array([0.3,]),
    'Ndiff_depth_bw':np.ones([Ndiff_param_count,])*0.3,
    'y_bandscale':.9*np.ones([1,])
    }


#assert len(hyper_paramdict1['Ndiff_exponent'])==modeldict1['max_bw_Ndiff'],'Ndiff_exponent does not match ' \
#                                                                            'depth of max_bw_Ndiff'
#assert len(hyper_paramdict1['Ndiff_depth_bw'])==modeldict1['max_bw_Ndiff'],'Ndiff_depth_bw does not match ' \
#                                                                             'depth of max_bw_Ndiff'
#create optimization dictionary
optimizedict1={
    'method':'Nelder-Mead',
    'hyper_param_dict':hyper_paramdict1,
    'model_dict':modeldict1
    }

# %%
print(Ndiff_param_count)
# Out:
# 1

# %% [markdown]
# #-----------------Calibrate/Optimize--------

# %%
import mykern as mk

# %%
import myreg
just_linreg=myreg.reg(y,xfull)
just_linreg.myreg()
print('linreg_mse:',just_linreg.mse)
# Out:
# linreg_mse: 1.7055218728352282

# %%
##### y=np.linspace(0,10000,n)#what happens if y has no relationship to x
optimized_Ndiff_kernel=mk.optimize_free_params(y,x,optimizedict1)
print(optimized_Ndiff_kernel.mselist[-1])
# Out:
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:2,mse:1110.7422624067167
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:3,mse:1117.1406322384553
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:4,mse:1112.6982315085233
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:5,mse:1112.325902513651
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:6,mse:1108.9150437092405
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:7,mse:1108.7291268129586
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter
mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:360,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:361,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:362,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:363,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:364,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:365,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:366,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:367,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:368,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:369,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:370,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:371,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:372,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:373,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:374,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:375,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:376,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:377,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:378,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:379,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:380,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:381,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:382,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:383,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:384,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:385,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:386,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:387,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:388,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:389,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:390,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:391,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:392,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:393,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:394,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:395,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:396,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:397,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:398,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:399,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:400,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:401,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:402,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:403,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:404,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:405,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:406,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:407,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:408,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:409,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:410,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:411,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:412,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:413,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:414,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:415,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:416,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:417,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:418,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:419,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:420,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:421,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:422,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:423,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:424,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:425,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:426,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:427,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:428,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:429,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:430,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:431,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:432,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:433,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:434,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:435,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:436,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:437,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:438,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:439,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:440,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:441,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:442,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:443,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:444,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:445,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:446,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:447,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:448,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:449,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:450,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:451,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:452,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:453,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:454,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:455,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:456,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:457,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:458,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:459,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:460,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:461,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:462,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:463,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:464,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:465,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:466,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:467,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:468,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:469,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:470,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:471,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:472,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:473,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:474,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:475,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:476,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:477,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:478,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:479,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:480,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:481,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:482,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:483,mse:1047.1950872442187
# this_depth_data.ndim:4
# ...
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1088,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1089,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1090,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1091,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1092,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1093,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1094,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1095,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1096,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1097,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1098,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1099,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1100,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1101,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1102,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1103,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1104,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1105,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1106,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1107,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1108,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1109,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1110,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1111,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1112,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1113,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1114,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1115,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1116,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1117,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1118,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1119,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1120,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1121,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1122,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1123,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1124,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1125,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1126,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1127,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1128,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1129,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1130,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1131,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1132,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1133,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1134,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1135,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1136,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1137,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1138,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1139,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1140,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1141,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1142,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1143,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1144,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1145,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1146,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1147,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1148,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1149,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1150,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1151,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1152,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1153,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1154,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1155,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1156,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1157,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1158,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1159,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1160,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1161,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1162,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1163,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1164,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1165,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1166,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1167,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1168,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1169,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1170,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1171,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1172,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1173,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1174,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1175,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1176,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1177,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1178,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1179,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1180,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1181,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1182,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1183,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1184,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1185,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1186,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1187,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1188,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1189,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1190,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1191,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1192,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1193,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1194,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1195,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1196,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1197,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1198,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1199,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1200,mse:1172.2619027018302
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1201,mse:1192.4639819153188
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1202,mse:1059.811656507089
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# iter:1203,mse:1047.1950872442187
# this_depth_data.ndim:4
# this_depth_data.ndim:5
# (17, 40, 17) (17, 17)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-6fae111681c1> in <module>
#       1 ##### y=np.linspace(0,10000,n)#what happens if y has no relationship to x
# ----> 2 optimized_Ndiff_kernel=mk.optimize_free_params(y,x,optimizedict1)
#       3 print(optimized_Ndiff_kernel.mselist[-1])
#
# ~\gits\kernelkernel\mykern.py in __init__(self, ydata, xdata, optimizedict)
#     775             'adaptive':True
#     776         }
# --> 777         self.mse=minimize(self.MY_KDEpredictMSE,free_params,args=args_tuple,method=method, options=optiondict)
#     778
#     779
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     586                       callback=callback, **options)
#     587     elif meth == 'nelder-mead':
# --> 588         return _minimize_neldermead(fun, x0, args, callback, **options)
#     589     elif meth == 'powell':
#     590         return _minimize_powell(fun, x0, args, callback, **options)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     599         xbar = numpy.add.reduce(sim[:-1], 0) / N
#     600         xr = (1 + rho) * xbar - rho * sim[-1]
# --> 601         fxr = func(xr)
#     602         doshrink = 0
#     603
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     324     def function_wrapper(*wrapper_args):
#     325         ncalls[0] += 1
# --> 326         return function(*(wrapper_args + args))
#     327
#     328     return ncalls, function_wrapper
#
# ~\gits\kernelkernel\mykern.py in MY_KDEpredictMSE(self, free_params, yin, yout, xin, xpr, modeldict, fixed_or_free_paramdict)
#     553
#     554
# --> 555         yhat_un_std=self.MY_KDEpredict(yin,yout,xin,xpr,modeldict,fixed_or_free_paramdict)
#     556         y_err=self.ydata-yhat_un_std
#     557         mse= np.mean(np.power(y_err,2))
#
# ~\gits\kernelkernel\mykern.py in MY_KDEpredict(self, yin, yout, xin, xpr, modeldict, fixed_or_free_paramdict)
#     654         prob_x = self.do_KDEsmalln(xonediffs, xbw, modeldict)
#     655
# --> 656         prob_yx = self.do_KDEsmalln(yx_onediffs_endstack, yx_bw_endstack,modeldict)#do_KDEsmalln implements product \\
#     657             #kernel across axis=2, the 3rd dimension after the 2 diensions of onediffs. endstack refers to the fact \\
#     658             #that y and x data are stacked in dimension 2 and do_kdesmall_n collapses them via the product of their kernels.
#
# ~\gits\kernelkernel\mykern.py in do_KDEsmalln(self, diffs, bw, modeldict)
#     522         normalization=modeldict['product_kern_norm']
#     523         if normalization =='self':
# --> 524             allkerns_sum=np.ma.sum(allkerns,axis=second_to_last_axis)#this should be the nout axis
#     525             #print('allkerns_sum.shape:',allkerns_sum.shape,allkerns_sum.max())
#     526             #assert allkerns.ndim==3,"allkerns has ndim:{} but expecting 3 by do_KDEsmalln".format(allkerns.ndim)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\ma\core.py in __call__(self, a, *args, **params)
#    6592             method = getattr(np, method_name)
#    6593
# -> 6594         return method(marr, *args, **params)
#    6595
#    6596
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\ma\core.py in sum(self, axis, dtype, out, keepdims)
#    4999         # No explicit output
#    5000         if out is None:
# -> 5001             result = self.filled(0).sum(axis, dtype=dtype, **kwargs)
#    5002             rndim = getattr(result, 'ndim', 0)
#    5003             if rndim:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial)
#      34 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      35          initial=_NoValue):
# ---> 36     return umr_sum(a, axis, dtype, out, keepdims, initial)
#      37
#      38 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# KeyboardInterrupt:

# %%
from bokeh.io import show, output_notebook#,curdoc,save, output_file
from bokeh.plotting import figure
#from bokeh.models import ColumnDataSource, Range1d, BBoxTileSource
#from bokeh.layouts import row
output_notebook()

# %%
#xgrid=np.linspace(1,n,n)

xgrid=x[:,0]
yhat=optimized_Ndiff_kernel.yhat_un_std
p=figure(title='y and yhat', plot_width=900, plot_height=500)
p.xaxis.axis_label = 'observations'
p.scatter(xgrid,y,size=10,color='blue',alpha=0.4,legend='y')
#p.line(xgrid,precip,color='blue',alpha=0.6,legend='precipitation')
p.scatter(xgrid,yhat,size=5,color='green',alpha=0.9,legend='yhat')
p.circle(xgrid,just_linreg.yhat,color='red',legend='just lin reg yhat')
p.line(xgrid,np.mean(y))
p.legend.location = "top_left"
p.yaxis.visible=False
show(p)

# %%
yhat.shape
print(data1.b)

# %%
print(yhat)

# %%
print(y)

# %%
ypredict=optimized_Ndiff_kernel.predict_tool(xvalidate,optimized_Ndiff_kernel.fixed_or_free_paramdict,modeldict1)
prediction_err=yvalidate-ypredict
prediction_mse=np.mean(prediction_err**2)

# %%
np.ma.count_masked(yhat)
