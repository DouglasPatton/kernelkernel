# %%
import os
import kernelcompare as kc
#from importlib import reload
networkdir='o:/public/dpatton/kernel'
mydir=os.getcwd()
mydir2=os.path.join(mydir,"cluster_test")

test=kc.KernelCompare(directory=mydir2)
# Out:
# handlername:mykern-None.log

# %%
newdict_tup_list=[('modeldict:loss_function','mse')]
newdict_tup_list.append(('modeldict:NWnorm','none'))

test.add_dict(os.path.join(mydir2,"condensed_model_save"),newdict_tup_list,verbose=1,overwrite=0)
test.print_model_save(filename=os.path.join(mydir2,"condensed_model_save-add_dict"))
# Out:
# dict_to_add ('modeldict:loss_function', 'mse')
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# val is dict in modeldict, recursive call
# :val(mse) replaces val(loss_function not in old_dict)
#
# vstring::key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2
# vstring::key(modeldict):key(loss_function):for key:loss_function, val(mse) replaces val(loss_function not in old_dict)
#  and done2

# %%
test.print_model_save(filename=os.path.join(mydir2,"condensed_model_save-add_dict"))
# Out:
# len(model_save_list:179

# %%
#product_kern_norm_overwrite_tup=('modeldict:product_kern_norm','across')
#test.overwrite_savedict('condensed_model_save-overwrite_dict',product_kern_norm_overwrite_tup,verbose=1,overwrite=1)

# %%
#product_kern_norm_overwrite_tup=('modeldict:product_kern_norm','across')
datagen_dict_overwrite_tup=('datagen_dict:ftype','linear')

test.overwrite_savedict('condensed_model_save',datagen_dict_overwrite_tup,verbose=1,overwrite=1,overwrite_condition='linear,quadratic')
test.print_model_save(filename=os.path.join(mydir2,"condensed_model_save"))
# Out:
# linear
# linear
# quadratic
# quadratic
# quadratic
# linear
# quadratic
# quadratic
# quadratic
# linear
# linear
# linear
# linear
# linear
# linear
# quadratic
# linear
# quadratic
# linear
# linear
# quadratic
# quadratic
# quadratic
# linear
# linear
# quadratic
# linear
# linear
# quadratic
# linear
# quadratic
# quadratic
# quadratic
# linear
# linear
# quadratic
# quadratic
# linear
# linear
# quadratic
# quadratic
# linear
# quadratic
# quadratic
# quadratic
# quadratic
# linear
# linear
# linear
# quadratic
# quadratic
# quadratic
# linear
# linear
# quadratic
# quadratic
# quadratic
# quadratic
# quadratic
# quadratic
# quadratic
# linear
# linear
# linear
# linear
# quadratic
# linear
# linear
# quadratic
# quadratic
# quadratic
# linear
# quadratic
# linear
# linear
# quadratic
# quadratic
# quadratic
# quadratic
# linear
# quadratic
# linear
# quadratic
# quadratic
# quadratic
# linear
# linear
# quadratic
# quadratic
# quadratic
# linear
# linear
# quadratic
# quadratic
# quadratic
# quadratic
# linear
# quadratic
# quadratic
# linear
# linear
# quadratic
# linear
# linear
# linear
# linear
# linear
# linear
# linear
# linear
# linear
# linear
# quadratic
# quadratic
# quadratic
# quadratic
# quadratic
# linear
# linear
# quadratic
# linear
# quadratic
# linear
# quadratic
# linear
# linear
# quadratic
# quadratic
# val is dict in datagen_dict, recursive call
# :val(linear) replaces val(linear,quadratic)
#
# vstring::key(ftype):for key:ftype, val(linear) replaces val(linear,quadratic)
#  and done2
# vstring::key(datagen_dict):key(ftype):for key:ftype, val(linear) replaces val(linear,quadratic)
#  and done2
# quadratic
# val is dict in datagen_dict, recursive call
# :val(linear) replaces val(linear,quadratic)
#
# vstring::key(ftype):for key:ftype, val(linear) replaces val(linear,quadratic)
#  and done2
# vstring::key(datagen_dict):key(ftype):for key:ftype, val(linear) replaces val(linear,quadratic)
#  and done2
# val is dict in datagen_dict, recursive call
# :val(linear) replaces val(linear,quadratic)
#
# vstring::key(ftype):for key:ftype, val(linear) replaces val(linear,quadratic)
#  and done2
# vstring::key(datagen_dict):key(ftype):for key:ftype, val(linear) replaces val(linear,quadratic)
#  and done2
# linear
# linear
# linear
# linear
# linear
# linear
# linear
# linear
# quadratic
# quadratic
# quadratic
# quadratic
# linear
# linear
# linear
# linear
# linear
# linear
# linear
# linear
# linear
# quadratic
# quadratic
# quadratic
# quadratic
# linear
# linear
# quadratic
# quadratic
# quadratic
# linear
# linear
# quadratic
# quadratic
# quadratic
# quadratic
# quadratic
# quadratic
# quadratic
# len(model_save_list:171

# %%
test.recursive_merge(mydir2,overwrite=0,verbose=0)

# %%
#test.open_condense_resave('model_save',verbose=0)
test.merge_and_condense_saved_models(merge_directory=mydir2,save_directory=mydir,condense=1,verbose=1)

# %%
test.print_model_save(filename=os.path.join(mydir2,"condensed_model_save"))

# %%
test.open_condense_resave(os.path.join(mydir2,"condensed_model_save"),verbose=1)

# %%
#test.recursive_merge(networkdir,overwrite=0,verbose=1)

# %%
'''from os import getcwd
thisdir=getcwd()
test.merge_and_condense_saved_models(merge_directory=thisdir,save_directory=thisdir,condense=1,verbose=1)'''
